# %%
import pickle

from model_and_circuit import *

from jax.lib import xla_bridge
jax.experimental.enable_x64()
print("JAX Backend:", xla_bridge.get_backend().platform)
# Out:
# JAX Backend: gpu

# %%
#Loading the original cat training data
with open('/home/akashm/PROJECT/qcbm_hiwi/qcbm_project/model_local_no_pretraining/data/4qubit_target_distribution.pkl',"rb") as file1:
    cat_data = pickle.load(file1)
    
# Saving the AntiCat distribution
with open('/home/akashm/PROJECT/qcbm_hiwi/qcbm_project/cat_anticat/data/4qubit_anticat_distribution.pkl',"rb") as file2:
    anticat_data = pickle.load(file2)

# %%
#Visualizing the Cat and AntiCat Distributions

x_array = jnp.arange(0,2**n_qubits)

#I want to plot the cat and anticat distributions with respect to x arrays beside each other
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].plot(x_array, cat_data, color='blue', alpha=0.5, label='Cat')
ax[0].set_title('Cat Distribution')
ax[0].set_xlabel('x')
ax[0].set_ylabel('Probability')
ax[0].legend()

ax[1].plot(x_array, anticat_data, color='red', alpha=0.5, label='AntiCat')
ax[1].set_title('AntiCat Distribution')
ax[1].set_xlabel('x')
ax[1].set_ylabel('Probability')
ax[1].legend()

# %%
qml.draw_mpl(circuit,device='default')(initial_params)
plt.show()

# %%
class MMD:
    def __init__(self,scales,space):
        gammas = 1/(2*(scales**2)).reshape(-1,1,1)
        sq_dists = jnp.abs(space[:,None] - space[None,:])**2
        self.K = jnp.sum(jnp.exp(-gammas * sq_dists), axis=0)/len(scales)
        self.scales = scales
        
    def k_expval(self,px,py):
        return px @ self.K @ py
    
    def __call__(self,px,py):
        pxy = px-py
        return self.k_expval(pxy,pxy)
    
class QCBM:
    def __init__(self,circ,mmd1,mmd2,py1,py2):
        self.circ = circ
        self.mmd1 = mmd1
        self.mmd2 = mmd2
        self.py1 = py1
        self.py2 = py2
    
    def mmd_loss(self,params):
        px = self.circ(params)
        loss1 = self.mmd1(px[0],self.py1)
        loss2 = self.mmd2(px[1],self.py2)
        
        return loss1+loss2, px
    

#Model Training
@jit
def update_step(params,opt_state):
    
    (total_loss_val,qcbm_probs), grads = jax.value_and_grad(qcbm.mmd_loss,has_aux=True)(params)

    updates,opt_state = opt.update(grads,opt_state)
    params = optax.apply_updates(params,updates)
    
    qcbm_probs1 = jnp.asarray(qcbm_probs[0], dtype=jnp.float64)
    qcbm_probs2 = jnp.asarray(qcbm_probs[1], dtype=jnp.float64)
    
    kl_div1 = -jnp.sum(cat_data * jnp.nan_to_num(jnp.log(qcbm_probs1) - jnp.log(cat_data)))
    kl_div2 = -jnp.sum(anticat_data * jnp.nan_to_num(jnp.log(qcbm_probs2) - jnp.log(anticat_data)))
    
    total_kl_div = kl_div1 + kl_div2
    
    return params, opt_state, total_loss_val, total_kl_div

# %%
#Calling MMD class
bandwidth = jnp.array([0.25,60],dtype=jnp.float64)
space = jnp.arange(0,2**n_qubits,dtype=jnp.float64)
mmd1 = MMD(bandwidth,space=space)
mmd2 = MMD(bandwidth,space=space)

#Calling QCBM class to run the previous built circuit with random weights
qcbm = QCBM(circuit,mmd1,mmd2,py1=cat_data,py2=anticat_data)


#Initial parameters
weights = initial_params
# lr = optax.exponential_decay(init_value=0.1,transition_steps=10,decay_rate=0.99,transition_begin=300,end_value=0.01,staircase=True)
lr = 0.01
opt = optax.adam(learning_rate=lr)
opt_state = opt.init(weights)


history = []
divs = []
parameters = []


kl_div = 1
i = 0
# i = start_epoch

# while kl_div > 10^-3:
while i < 1001:
    i+=1
    # current_lr = lr(i)
    current_lr = lr
    start_time = time.time()
    weights, opt_state, loss_val, kl_div = update_step(params=weights,opt_state=opt_state)
    end_time = time.time()
    
    if i%10==0:
        print(f"Step: {i} Loss: {loss_val} KL_div:{kl_div} current_lr:{current_lr} Time taken per iteration: {end_time-start_time}")
    
    history.append(loss_val)
    divs.append(kl_div)
    parameters.append(weights)
# Out:
# Step: 10 Loss: 0.03861429542303085 KL_div:0.6865129470825195 current_lr:0.01 Time taken per iteration: 0.03178143501281738
# Step: 20 Loss: 0.01711815781891346 KL_div:0.3826683759689331 current_lr:0.01 Time taken per iteration: 0.011258363723754883
# Step: 30 Loss: 0.009336200542747974 KL_div:0.24115945398807526 current_lr:0.01 Time taken per iteration: 0.0070514678955078125
# Step: 40 Loss: 0.006235928274691105 KL_div:0.17105340957641602 current_lr:0.01 Time taken per iteration: 0.006763935089111328
# Step: 50 Loss: 0.004283244721591473 KL_div:0.1407402753829956 current_lr:0.01 Time taken per iteration: 0.012757539749145508
# Step: 60 Loss: 0.0031485920771956444 KL_div:0.12130080163478851 current_lr:0.01 Time taken per iteration: 0.006536245346069336
# Step: 70 Loss: 0.0024005139712244272 KL_div:0.10153979808092117 current_lr:0.01 Time taken per iteration: 0.008773565292358398
# Step: 80 Loss: 0.0018432762008160353 KL_div:0.08267450332641602 current_lr:0.01 Time taken per iteration: 0.01145315170288086
# Step: 90 Loss: 0.001413416233845055 KL_div:0.06725184619426727 current_lr:0.01 Time taken per iteration: 0.013065814971923828
# Step: 100 Loss: 0.0010809720261022449 KL_div:0.05535010248422623 current_lr:0.01 Time taken per iteration: 0.022919893264770508
# Step: 110 Loss: 0.0008286837837658823 KL_div:0.04592369869351387 current_lr:0.01 Time taken per iteration: 0.011392593383789062
# Step: 120 Loss: 0.0006395066156983376 KL_div:0.03872562199831009 current_lr:0.01 Time taken per iteration: 0.0067594051361083984
# Step: 130 Loss: 0.0004998277290724218 KL_div:0.0332016795873642 current_lr:0.01 Time taken per iteration: 0.010086297988891602
# Step: 140 Loss: 0.0003969970566686243 KL_div:0.028755132108926773 current_lr:0.01 Time taken per iteration: 0.009624719619750977
# Step: 150 Loss: 0.00032095517963171005 KL_div:0.025151986628770828 current_lr:0.01 Time taken per iteration: 0.011267662048339844
# Step: 160 Loss: 0.0002641302708070725 KL_div:0.022233271971344948 current_lr:0.01 Time taken per iteration: 0.011794805526733398
# Step: 170 Loss: 0.00022101658396422863 KL_div:0.019816899672150612 current_lr:0.01 Time taken per iteration: 0.008896589279174805
# Step: 180 Loss: 0.00018760835519060493 KL_div:0.01777646131813526 current_lr:0.01 Time taken per iteration: 0.010014772415161133
# Step: 190 Loss: 0.00016110407887026668 KL_div:0.016047675162553787 current_lr:0.01 Time taken per iteration: 0.010398387908935547
# Step: 200 Loss: 0.00013958351337350905 KL_div:0.014551268890500069 current_lr:0.01 Time taken per iteration: 0.006522655487060547
# Step: 210 Loss: 0.00012177451571915299 KL_div:0.013253450393676758 current_lr:0.01 Time taken per iteration: 0.00872945785522461
# Step: 220 Loss: 0.00010682530410122126 KL_div:0.01212501060217619 current_lr:0.01 Time taken per iteration: 0.008715391159057617
# Step: 230 Loss: 9.412504732608795e-05 KL_div:0.011129493825137615 current_lr:0.01 Time taken per iteration: 0.007456302642822266
# Step: 240 Loss: 8.325326780322939e-05 KL_div:0.010253805667161942 current_lr:0.01 Time taken per iteration: 0.006861209869384766
# Step: 250 Loss: 7.387882942566648e-05 KL_div:0.009473416954278946 current_lr:0.01 Time taken per iteration: 0.009422063827514648
# Step: 260 Loss: 6.575693259947002e-05 KL_div:0.008776815608143806 current_lr:0.01 Time taken per iteration: 0.009352684020996094
# Step: 270 Loss: 5.8693327446235344e-05 KL_div:0.008154361508786678 current_lr:0.01 Time taken per iteration: 0.011220216751098633
# Step: 280 Loss: 5.25219838891644e-05 KL_div:0.0075906310230493546 current_lr:0.01 Time taken per iteration: 0.00919485092163086
# Step: 290 Loss: 4.7120105591602623e-05 KL_div:0.007084176875650883 current_lr:0.01 Time taken per iteration: 0.013116598129272461
# Step: 300 Loss: 4.2373721953481436e-05 KL_div:0.006623457185924053 current_lr:0.01 Time taken per iteration: 0.007190704345703125
# Step: 310 Loss: 3.819460471277125e-05 KL_div:0.006205057725310326 current_lr:0.01 Time taken per iteration: 0.008823871612548828
# Step: 320 Loss: 3.4506658266764134e-05 KL_div:0.005825125612318516 current_lr:0.01 Time taken per iteration: 0.009137868881225586
# Step: 330 Loss: 3.1242445402313024e-05 KL_div:0.005477164406329393 current_lr:0.01 Time taken per iteration: 0.008390188217163086
# Step: 340 Loss: 2.835045597748831e-05 KL_div:0.0051614027470350266 current_lr:0.01 Time taken per iteration: 0.007953166961669922
# Step: 350 Loss: 2.5777486371225677e-05 KL_div:0.004868925549089909 current_lr:0.01 Time taken per iteration: 0.00943136215209961
# Step: 360 Loss: 2.3486674763262272e-05 KL_div:0.0046017225831747055 current_lr:0.01 Time taken per iteration: 0.009601593017578125
# Step: 370 Loss: 2.1444220692501403e-05 KL_div:0.004358337260782719 current_lr:0.01 Time taken per iteration: 0.007971525192260742
# Step: 380 Loss: 1.961395719263237e-05 KL_div:0.004129877779632807 current_lr:0.01 Time taken per iteration: 0.013363122940063477
# Step: 390 Loss: 1.797623554011807e-05 KL_div:0.003922746516764164 current_lr:0.01 Time taken per iteration: 0.016472816467285156
# Step: 400 Loss: 1.650481681281235e-05 KL_div:0.003730607684701681 current_lr:0.01 Time taken per iteration: 0.016813278198242188
# Step: 410 Loss: 1.5179777619778179e-05 KL_div:0.003551690373569727 current_lr:0.01 Time taken per iteration: 0.031420230865478516
# Step: 420 Loss: 1.3984796169097535e-05 KL_div:0.003385762684047222 current_lr:0.01 Time taken per iteration: 0.014696836471557617
# Step: 430 Loss: 1.2906784832011908e-05 KL_div:0.003234294941648841 current_lr:0.01 Time taken per iteration: 0.008823633193969727
# Step: 440 Loss: 1.1929032552870922e-05 KL_div:0.0030907010659575462 current_lr:0.01 Time taken per iteration: 0.013481616973876953
# Step: 450 Loss: 1.1042207916034386e-05 KL_div:0.0029570881742984056 current_lr:0.01 Time taken per iteration: 0.014054059982299805
# Step: 460 Loss: 1.0236219168291427e-05 KL_div:0.002832189202308655 current_lr:0.01 Time taken per iteration: 0.016192197799682617
# Step: 470 Loss: 9.50404501054436e-06 KL_div:0.0027181573677808046 current_lr:0.01 Time taken per iteration: 0.009133338928222656
# Step: 480 Loss: 8.833907486405224e-06 KL_div:0.002607216825708747 current_lr:0.01 Time taken per iteration: 0.010034799575805664
# Step: 490 Loss: 8.223676559282467e-06 KL_div:0.0025066486559808254 current_lr:0.01 Time taken per iteration: 0.014771461486816406
# Step: 500 Loss: 7.664666554774158e-06 KL_div:0.0024110095109790564 current_lr:0.01 Time taken per iteration: 0.015319108963012695
# Step: 510 Loss: 7.152433227020083e-06 KL_div:0.0023213874083012342 current_lr:0.01 Time taken per iteration: 0.013020992279052734
# Step: 520 Loss: 6.682924322376493e-06 KL_div:0.0022381856106221676 current_lr:0.01 Time taken per iteration: 0.04201459884643555
# Step: 530 Loss: 6.250183560041478e-06 KL_div:0.0021574858110398054 current_lr:0.01 Time taken per iteration: 0.028135061264038086
# Step: 540 Loss: 5.853460152138723e-06 KL_div:0.0020846810657531023 current_lr:0.01 Time taken per iteration: 0.034046173095703125
# Step: 550 Loss: 5.487139333126834e-06 KL_div:0.0020145238377153873 current_lr:0.01 Time taken per iteration: 0.11492252349853516
# Step: 560 Loss: 5.148325271875365e-06 KL_div:0.0019466913072392344 current_lr:0.01 Time taken per iteration: 0.04485154151916504
# Step: 570 Loss: 4.83611711388221e-06 KL_div:0.0018844001460820436 current_lr:0.01 Time taken per iteration: 0.03913545608520508
# Step: 580 Loss: 4.548184278974077e-06 KL_div:0.0018274786416441202 current_lr:0.01 Time taken per iteration: 0.028951406478881836
# Step: 590 Loss: 4.27923532697605e-06 KL_div:0.0017684753984212875 current_lr:0.01 Time taken per iteration: 0.03782963752746582
# Step: 600 Loss: 4.031734988529934e-06 KL_div:0.001717012608423829 current_lr:0.01 Time taken per iteration: 0.0447232723236084
# Step: 610 Loss: 3.80051574211393e-06 KL_div:0.0016644984716549516 current_lr:0.01 Time taken per iteration: 0.051816463470458984
# Step: 620 Loss: 3.586437742342241e-06 KL_div:0.001616581343114376 current_lr:0.01 Time taken per iteration: 0.07314014434814453
# Step: 630 Loss: 3.3871626783366082e-06 KL_div:0.0015707723796367645 current_lr:0.01 Time taken per iteration: 0.019673824310302734
# Step: 640 Loss: 3.202009565939079e-06 KL_div:0.0015282274689525366 current_lr:0.01 Time taken per iteration: 0.013149499893188477
# Step: 650 Loss: 3.0291614621091867e-06 KL_div:0.0014870134182274342 current_lr:0.01 Time taken per iteration: 0.009422779083251953
# Step: 660 Loss: 2.867840066755889e-06 KL_div:0.001447450602427125 current_lr:0.01 Time taken per iteration: 0.010994195938110352
# Step: 670 Loss: 2.717189317991142e-06 KL_div:0.0014097492676228285 current_lr:0.01 Time taken per iteration: 0.014994621276855469
# Step: 680 Loss: 2.5759354684851132e-06 KL_div:0.0013724409509450197 current_lr:0.01 Time taken per iteration: 0.01889824867248535
# Step: 690 Loss: 2.4442654193990165e-06 KL_div:0.001338145462796092 current_lr:0.01 Time taken per iteration: 0.01133418083190918
# Step: 700 Loss: 2.321669171578833e-06 KL_div:0.001307409955188632 current_lr:0.01 Time taken per iteration: 0.011571168899536133
# Step: 710 Loss: 2.205752480222145e-06 KL_div:0.001274849520996213 current_lr:0.01 Time taken per iteration: 0.014823436737060547
# Step: 720 Loss: 2.097677679557819e-06 KL_div:0.0012455352116376162 current_lr:0.01 Time taken per iteration: 0.011844873428344727
# Step: 730 Loss: 1.9961755697295303e-06 KL_div:0.0012172512942925096 current_lr:0.01 Time taken per iteration: 0.011169672012329102
# Step: 740 Loss: 1.899956941997516e-06 KL_div:0.0011870871530845761 current_lr:0.01 Time taken per iteration: 0.010988473892211914
# Step: 750 Loss: 1.8106167090081726e-06 KL_div:0.0011619654251262546 current_lr:0.01 Time taken per iteration: 0.012933492660522461
# Step: 760 Loss: 1.7261021412195987e-06 KL_div:0.0011360861826688051 current_lr:0.01 Time taken per iteration: 0.014054536819458008
# Step: 770 Loss: 1.646944269850792e-06 KL_div:0.0011125511955469847 current_lr:0.01 Time taken per iteration: 0.008824348449707031
# Step: 780 Loss: 1.5720554529252695e-06 KL_div:0.0010887710377573967 current_lr:0.01 Time taken per iteration: 0.014599084854125977
# Step: 790 Loss: 1.5015468761703232e-06 KL_div:0.001066257362253964 current_lr:0.01 Time taken per iteration: 0.013181447982788086
# Step: 800 Loss: 1.4348606782732531e-06 KL_div:0.0010438961908221245 current_lr:0.01 Time taken per iteration: 0.008878946304321289
# Step: 810 Loss: 1.3726340739594889e-06 KL_div:0.0010249121114611626 current_lr:0.01 Time taken per iteration: 0.016610145568847656
# Step: 820 Loss: 1.3129889566698694e-06 KL_div:0.0010034373262897134 current_lr:0.01 Time taken per iteration: 0.02258896827697754
# Step: 830 Loss: 1.2570058061101008e-06 KL_div:0.0009840967832133174 current_lr:0.01 Time taken per iteration: 0.009788990020751953
# Step: 840 Loss: 1.203846295538824e-06 KL_div:0.0009646711405366659 current_lr:0.01 Time taken per iteration: 0.013396978378295898
# Step: 850 Loss: 1.1539231081769685e-06 KL_div:0.0009474488906562328 current_lr:0.01 Time taken per iteration: 0.014688253402709961
# Step: 860 Loss: 1.1063552847190294e-06 KL_div:0.00092940719332546 current_lr:0.01 Time taken per iteration: 0.010977983474731445
# Step: 870 Loss: 1.0614118082230561e-06 KL_div:0.0009126812219619751 current_lr:0.01 Time taken per iteration: 0.012484073638916016
# Step: 880 Loss: 1.01874582014716e-06 KL_div:0.0008961092098616064 current_lr:0.01 Time taken per iteration: 0.0077667236328125
# Step: 890 Loss: 9.782713732420234e-07 KL_div:0.0008802004740573466 current_lr:0.01 Time taken per iteration: 0.01658773422241211
# Step: 900 Loss: 9.399332725479326e-07 KL_div:0.0008651187526993454 current_lr:0.01 Time taken per iteration: 0.021129131317138672
# Step: 910 Loss: 9.032220873450569e-07 KL_div:0.0008491406915709376 current_lr:0.01 Time taken per iteration: 0.008020162582397461
# Step: 920 Loss: 8.687496233505954e-07 KL_div:0.0008355064783245325 current_lr:0.01 Time taken per iteration: 0.007645845413208008
# Step: 930 Loss: 8.358161380783713e-07 KL_div:0.0008215419948101044 current_lr:0.01 Time taken per iteration: 0.009921073913574219
# Step: 940 Loss: 8.040441343837301e-07 KL_div:0.0008060100954025984 current_lr:0.01 Time taken per iteration: 0.013194084167480469
# Step: 950 Loss: 7.748582788735803e-07 KL_div:0.0007955775363370776 current_lr:0.01 Time taken per iteration: 0.011209487915039062
# Step: 960 Loss: 7.462367079824617e-07 KL_div:0.0007818693411536515 current_lr:0.01 Time taken per iteration: 0.011055231094360352
# Step: 970 Loss: 7.191217150648299e-07 KL_div:0.000769267266150564 current_lr:0.01 Time taken per iteration: 0.010538816452026367
# Step: 980 Loss: 6.932808673809632e-07 KL_div:0.0007570290472358465 current_lr:0.01 Time taken per iteration: 0.01108098030090332
# Step: 990 Loss: 6.684013555968704e-07 KL_div:0.0007440546760335565 current_lr:0.01 Time taken per iteration: 0.009984970092773438
# Step: 1000 Loss: 6.454768595176574e-07 KL_div:0.0007352255051955581 current_lr:0.01 Time taken per iteration: 0.009219169616699219

# %%
fig, axs = plt.subplots(1,2,figsize=(15,8))
axs[0].plot(divs)
axs[0].title.set_text('KL Divergence')

axs[1].plot(history)
axs[1].title.set_text('loss')

# %%
optimal_params = parameters[np.argmin(divs)]

qcbm_probs = circuit(optimal_params)
x_array = jnp.arange(0,2**(n_qubits),dtype=jnp.float64)

# %%
plt.bar(x_array,qcbm_probs[0],color='green',alpha=0.5,label='Obtained Distribution')
plt.plot(x_array,cat_data,color='blue',alpha=0.5,label='Target Distribution')
plt.xlabel("Hilbert Space",fontsize=12)
plt.ylabel("Probability",fontsize=12)
plt.legend()
plt.show()

# %%
plt.bar(x_array,qcbm_probs[1],color='green',alpha=0.5,label='Obtained Distribution')
plt.plot(x_array,anticat_data,color='blue',alpha=0.5,label='Leftover Distribution')
plt.xlabel("Hilbert Space",fontsize=12)
plt.ylabel("Probability",fontsize=12)
plt.legend()
plt.show()

# %%
optimal_params = parameters[np.argmin(divs)]

qcbm_probs = circuit(optimal_params)
x_array = jnp.arange(0,2**(n_qubits),dtype=jnp.float64)

fig,axs = plt.subplots(1,2,figsize=(15,8))
axs[0].bar(x_array,qcbm_probs[0],color='green',alpha=0.5,label='Obtained Cat')
axs[0].plot(x_array,cat_data,color='blue',alpha=0.5,label='Original Cat')
axs[0].title.set_text('Cat Distribution')

axs[1].bar(x_array,qcbm_probs[1],color='green',alpha=0.5,label='AntiCat')
axs[1].plot(x_array,anticat_data,color='blue',alpha=0.5,label='Original AntiCat')
axs[1].title.set_text('AntiCat Distribution')

# %%
print(f"Minimum KL Divergence obtained is {np.min(divs)}")
# Out:
# Minimum KL Divergence obtained is 0.0003071989049203694

# %%
cat_pdistribution = pnumber_distribution(qcbm_probs[0],n_qubits)
anticat_pdistribution = pnumber_distribution(qcbm_probs[1],n_qubits)

# %%
x = np.arange(0,n_qubits+1)

fig,axs = plt.subplots(1,2,figsize=(15,8))
axs[0].bar(x,cat_pdistribution, label='Cat')
axs[0].set_title('Cat Particle Number Distribution')
axs[0].set_xlabel('Particle Number')
axs[0].set_ylabel('Probability')
axs[0].legend()

axs[1].bar(x,anticat_pdistribution, label='AntiCat')
axs[1].set_title('AntiCat Particle Number Distribution')
axs[1].set_xlabel('Particle Number')
axs[1].set_ylabel('Probability')
axs[1].legend()

# %%
plt.bar(x,cat_pdistribution+anticat_pdistribution)
plt.title('Total Probability Distribution')
plt.xlabel('Particle Number')
plt.ylabel('Probability')
plt.show()

# %%
# #Save Checkpoint
# checkpoint = {"final_epoch":i,
#               "history":history,
#               "divs":divs,
#               "parameters":parameters}

# with open(f'data/4qubit_model_cat_anticat_distribution.pkl','wb') as file:
#     pickle.dump(checkpoint,file)
    
# print("Model saved successfully")
