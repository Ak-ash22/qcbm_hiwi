# %%
import pickle

from model_and_circuit import *

from jax.lib import xla_bridge
jax.experimental.enable_x64()
print("JAX Backend:", xla_bridge.get_backend().platform)
# Out:
# JAX Backend: gpu

# %%
#Loading the original cat training data
with open('/home/akashm/PROJECT/qcbm_hiwi/qcbm_project/model_local_no_pretraining/data/4qubit_target_distribution.pkl',"rb") as file1:
    cat_data = pickle.load(file1)
    
# Saving the AntiCat distribution
with open('/home/akashm/PROJECT/qcbm_hiwi/qcbm_project/cat_anticat/data/4qubit_anticat_distribution.pkl',"rb") as file2:
    anticat_data = pickle.load(file2)

# %%
#Visualizing the Cat and AntiCat Distributions

x_array = jnp.arange(0,2**n_qubits)

#I want to plot the cat and anticat distributions with respect to x arrays beside each other
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].plot(x_array, cat_data, color='blue', alpha=0.5, label='Cat')
ax[0].set_title('Cat Distribution')
ax[0].set_xlabel('x')
ax[0].set_ylabel('Probability')
ax[0].legend()

ax[1].plot(x_array, anticat_data, color='red', alpha=0.5, label='AntiCat')
ax[1].set_title('AntiCat Distribution')
ax[1].set_xlabel('x')
ax[1].set_ylabel('Probability')
ax[1].legend()

# %%
qml.draw_mpl(circuit,device='default')(initial_params)
plt.show()

# %%
class MMD:
    def __init__(self,scales,space):
        gammas = 1/(2*(scales**2)).reshape(-1,1,1)
        sq_dists = jnp.abs(space[:,None] - space[None,:])**2
        self.K = jnp.sum(jnp.exp(-gammas * sq_dists), axis=0)/len(scales)
        self.scales = scales
        
    def k_expval(self,px,py):
        return px @ self.K @ py
    
    def __call__(self,px,py):
        pxy = px-py
        return self.k_expval(pxy,pxy)
    
class QCBM:
    def __init__(self,circ,mmd1,mmd2,py1,py2):
        self.circ = circ
        self.mmd1 = mmd1
        self.mmd2 = mmd2
        self.py1 = py1
        self.py2 = py2
    
    def mmd_loss(self,params):
        px = self.circ(params)
        loss1 = self.mmd1(px[0],self.py1)
        loss2 = self.mmd2(px[1],self.py2)
        
        return loss1+loss2, px
    

#Model Training
@jit
def update_step(params,opt_state):
    
    (total_loss_val,qcbm_probs), grads = jax.value_and_grad(qcbm.mmd_loss,has_aux=True)(params)

    updates,opt_state = opt.update(grads,opt_state)
    params = optax.apply_updates(params,updates)
    
    qcbm_probs1 = jnp.asarray(qcbm_probs[0], dtype=jnp.float64)
    qcbm_probs2 = jnp.asarray(qcbm_probs[1], dtype=jnp.float64)
    
    kl_div1 = -jnp.sum(cat_data * jnp.nan_to_num(jnp.log(qcbm_probs1) - jnp.log(cat_data)))
    kl_div2 = -jnp.sum(anticat_data * jnp.nan_to_num(jnp.log(qcbm_probs2) - jnp.log(anticat_data)))
    
    total_kl_div = kl_div1 + kl_div2
    
    return params, opt_state, total_loss_val, total_kl_div

# %%
#Calling MMD class
bandwidth = jnp.array([0.25,60],dtype=jnp.float64)
space = jnp.arange(0,2**n_qubits,dtype=jnp.float64)
mmd1 = MMD(bandwidth,space=space)
mmd2 = MMD(bandwidth,space=space)

#Calling QCBM class to run the previous built circuit with random weights
qcbm = QCBM(circuit,mmd1,mmd2,py1=cat_data,py2=anticat_data)


#Initial parameters
weights = initial_params
# lr = optax.exponential_decay(init_value=0.1,transition_steps=10,decay_rate=0.99,transition_begin=300,end_value=0.01,staircase=True)
lr = 0.01
opt = optax.adam(learning_rate=lr)
opt_state = opt.init(weights)


history = []
divs = []
parameters = []


kl_div = 1
i = 0
# i = start_epoch

# while kl_div > 10^-3:
while i < 1001:
    i+=1
    # current_lr = lr(i)
    current_lr = lr
    start_time = time.time()
    weights, opt_state, loss_val, kl_div = update_step(params=weights,opt_state=opt_state)
    end_time = time.time()
    
    if i%10==0:
        print(f"Step: {i} Loss: {loss_val} KL_div:{kl_div} current_lr:{current_lr} Time taken per iteration: {end_time-start_time}")
    
    history.append(loss_val)
    divs.append(kl_div)
    parameters.append(weights)
# Out:
# Step: 10 Loss: 0.01609959453344345 KL_div:0.3239985704421997 current_lr:0.01 Time taken per iteration: 0.024521589279174805
# Step: 20 Loss: 0.003686117008328438 KL_div:0.1016867384314537 current_lr:0.01 Time taken per iteration: 0.013435125350952148
# Step: 30 Loss: 0.0010297219268977642 KL_div:0.055026549845933914 current_lr:0.01 Time taken per iteration: 0.010085105895996094
# Step: 40 Loss: 0.000590623589232564 KL_div:0.04737940803170204 current_lr:0.01 Time taken per iteration: 0.009197235107421875
# Step: 50 Loss: 0.00036257965257391334 KL_div:0.04193510860204697 current_lr:0.01 Time taken per iteration: 0.010423898696899414
# Step: 60 Loss: 0.0002341718936804682 KL_div:0.03219156712293625 current_lr:0.01 Time taken per iteration: 0.0098876953125
# Step: 70 Loss: 0.0001446757378289476 KL_div:0.02451412007212639 current_lr:0.01 Time taken per iteration: 0.014946460723876953
# Step: 80 Loss: 0.00010254669177811593 KL_div:0.019562872126698494 current_lr:0.01 Time taken per iteration: 0.012697458267211914
# Step: 90 Loss: 7.298416312551126e-05 KL_div:0.015918325632810593 current_lr:0.01 Time taken per iteration: 0.01001596450805664
# Step: 100 Loss: 5.551611684495583e-05 KL_div:0.01349705457687378 current_lr:0.01 Time taken per iteration: 0.009566545486450195
# Step: 110 Loss: 4.348061702330597e-05 KL_div:0.011571111157536507 current_lr:0.01 Time taken per iteration: 0.013787984848022461
# Step: 120 Loss: 3.491502866381779e-05 KL_div:0.010032032616436481 current_lr:0.01 Time taken per iteration: 0.015699148178100586
# Step: 130 Loss: 2.843785478034988e-05 KL_div:0.008783362805843353 current_lr:0.01 Time taken per iteration: 0.018376827239990234
# Step: 140 Loss: 2.339117600058671e-05 KL_div:0.007754802703857422 current_lr:0.01 Time taken per iteration: 0.02195143699645996
# Step: 150 Loss: 1.9404007616685703e-05 KL_div:0.006878302898257971 current_lr:0.01 Time taken per iteration: 0.013349056243896484
# Step: 160 Loss: 1.6208145098062232e-05 KL_div:0.006133659742772579 current_lr:0.01 Time taken per iteration: 0.009988546371459961
# Step: 170 Loss: 1.3625268366013188e-05 KL_div:0.005502091720700264 current_lr:0.01 Time taken per iteration: 0.009587287902832031
# Step: 180 Loss: 1.1523320608830545e-05 KL_div:0.004958764649927616 current_lr:0.01 Time taken per iteration: 0.030284404754638672
# Step: 190 Loss: 9.80907952907728e-06 KL_div:0.004495987668633461 current_lr:0.01 Time taken per iteration: 0.012049198150634766
# Step: 200 Loss: 8.400485967285931e-06 KL_div:0.0040960898622870445 current_lr:0.01 Time taken per iteration: 0.008250713348388672
# Step: 210 Loss: 7.236149940581527e-06 KL_div:0.0037504860665649176 current_lr:0.01 Time taken per iteration: 0.01761770248413086
# Step: 220 Loss: 6.265462616283912e-06 KL_div:0.0034472832921892405 current_lr:0.01 Time taken per iteration: 0.008585453033447266
# Step: 230 Loss: 5.450757271319162e-06 KL_div:0.003179769730195403 current_lr:0.01 Time taken per iteration: 0.01241755485534668
# Step: 240 Loss: 4.761956006404944e-06 KL_div:0.0029412147123366594 current_lr:0.01 Time taken per iteration: 0.01111745834350586
# Step: 250 Loss: 4.177344180789078e-06 KL_div:0.0027299406938254833 current_lr:0.01 Time taken per iteration: 0.010957956314086914
# Step: 260 Loss: 3.6778906178369652e-06 KL_div:0.0025403089821338654 current_lr:0.01 Time taken per iteration: 0.01141977310180664
# Step: 270 Loss: 3.2483762879564893e-06 KL_div:0.002367616631090641 current_lr:0.01 Time taken per iteration: 0.009049654006958008
# Step: 280 Loss: 2.8785407266695984e-06 KL_div:0.0022124899551272392 current_lr:0.01 Time taken per iteration: 0.009740114212036133
# Step: 290 Loss: 2.558921551099047e-06 KL_div:0.002072964794933796 current_lr:0.01 Time taken per iteration: 0.012036800384521484
# Step: 300 Loss: 2.280907438034774e-06 KL_div:0.001945077907294035 current_lr:0.01 Time taken per iteration: 0.011923551559448242
# Step: 310 Loss: 2.038807906501461e-06 KL_div:0.001828896114602685 current_lr:0.01 Time taken per iteration: 0.009632110595703125
# Step: 320 Loss: 1.827080041039153e-06 KL_div:0.0017225838964805007 current_lr:0.01 Time taken per iteration: 0.012787342071533203
# Step: 330 Loss: 1.640841787775571e-06 KL_div:0.0016233106143772602 current_lr:0.01 Time taken per iteration: 0.01490640640258789
# Step: 340 Loss: 1.478465264881379e-06 KL_div:0.0015366196166723967 current_lr:0.01 Time taken per iteration: 0.013080358505249023
# Step: 350 Loss: 1.3339674751478015e-06 KL_div:0.001452288357540965 current_lr:0.01 Time taken per iteration: 0.01581263542175293
# Step: 360 Loss: 1.2081277418474201e-06 KL_div:0.0013809794327244163 current_lr:0.01 Time taken per iteration: 0.011774063110351562
# Step: 370 Loss: 1.0953388027701294e-06 KL_div:0.00131049077026546 current_lr:0.01 Time taken per iteration: 0.010423421859741211
# Step: 380 Loss: 9.95764139588573e-07 KL_div:0.0012472992530092597 current_lr:0.01 Time taken per iteration: 0.01218271255493164
# Step: 390 Loss: 9.066180837180582e-07 KL_div:0.0011866926215589046 current_lr:0.01 Time taken per iteration: 0.00961160659790039
# Step: 400 Loss: 8.280579777419916e-07 KL_div:0.0011339474003762007 current_lr:0.01 Time taken per iteration: 0.013352155685424805
# Step: 410 Loss: 7.573808034067042e-07 KL_div:0.0010830131359398365 current_lr:0.01 Time taken per iteration: 0.012798309326171875
# Step: 420 Loss: 6.936740533092234e-07 KL_div:0.0010336318518966436 current_lr:0.01 Time taken per iteration: 0.013715267181396484
# Step: 430 Loss: 6.374893359861744e-07 KL_div:0.0009916216367855668 current_lr:0.01 Time taken per iteration: 0.011420488357543945
# Step: 440 Loss: 5.868534458386421e-07 KL_div:0.0009516896679997444 current_lr:0.01 Time taken per iteration: 0.013836383819580078
# Step: 450 Loss: 5.40929363523901e-07 KL_div:0.0009127649827860296 current_lr:0.01 Time taken per iteration: 0.012172222137451172
# Step: 460 Loss: 4.997680207452504e-07 KL_div:0.0008775536553002894 current_lr:0.01 Time taken per iteration: 0.015480518341064453
# Step: 470 Loss: 4.627643761523359e-07 KL_div:0.0008452683687210083 current_lr:0.01 Time taken per iteration: 0.011659622192382812
# Step: 480 Loss: 4.2891144858003827e-07 KL_div:0.0008132311631925404 current_lr:0.01 Time taken per iteration: 0.01644134521484375
# Step: 490 Loss: 3.982210330377711e-07 KL_div:0.0007830449612811208 current_lr:0.01 Time taken per iteration: 0.016467571258544922
# Step: 500 Loss: 3.710691203195893e-07 KL_div:0.0007581108948215842 current_lr:0.01 Time taken per iteration: 0.011036157608032227
# Step: 510 Loss: 3.458521291577199e-07 KL_div:0.0007320651784539223 current_lr:0.01 Time taken per iteration: 0.012886762619018555
# Step: 520 Loss: 3.230549623367551e-07 KL_div:0.0007082966039888561 current_lr:0.01 Time taken per iteration: 0.01293802261352539
# Step: 530 Loss: 3.020049064161867e-07 KL_div:0.0006845970638096333 current_lr:0.01 Time taken per iteration: 0.016612529754638672
# Step: 540 Loss: 2.831671395142621e-07 KL_div:0.0006642239168286324 current_lr:0.01 Time taken per iteration: 0.010649919509887695
# Step: 550 Loss: 2.65447908986971e-07 KL_div:0.0006425037863664329 current_lr:0.01 Time taken per iteration: 0.012368917465209961
# Step: 560 Loss: 2.4990885094666737e-07 KL_div:0.0006255838670767844 current_lr:0.01 Time taken per iteration: 0.01918768882751465
# Step: 570 Loss: 2.3514155600423692e-07 KL_div:0.0006068490911275148 current_lr:0.01 Time taken per iteration: 0.01837301254272461
# Step: 580 Loss: 2.2183266423780879e-07 KL_div:0.0005904734134674072 current_lr:0.01 Time taken per iteration: 0.013964176177978516
# Step: 590 Loss: 2.094660942475457e-07 KL_div:0.00057432014727965 current_lr:0.01 Time taken per iteration: 0.01608562469482422
# Step: 600 Loss: 1.9822273600311746e-07 KL_div:0.0005598559509962797 current_lr:0.01 Time taken per iteration: 0.010196685791015625
# Step: 610 Loss: 1.8781381072585646e-07 KL_div:0.0005459602107293904 current_lr:0.01 Time taken per iteration: 0.010526418685913086
# Step: 620 Loss: 1.78248583893037e-07 KL_div:0.0005329640116542578 current_lr:0.01 Time taken per iteration: 0.02279520034790039
# Step: 630 Loss: 1.6900781929507502e-07 KL_div:0.0005185013869777322 current_lr:0.01 Time taken per iteration: 0.018526792526245117
# Step: 640 Loss: 1.6104466737942857e-07 KL_div:0.0005080600385554135 current_lr:0.01 Time taken per iteration: 0.015279293060302734
# Step: 650 Loss: 1.5306711986795563e-07 KL_div:0.0004947673878632486 current_lr:0.01 Time taken per iteration: 0.013288259506225586
# Step: 660 Loss: 1.4574436590919504e-07 KL_div:0.00048257160233333707 current_lr:0.01 Time taken per iteration: 0.019071102142333984
# Step: 670 Loss: 1.396652322682712e-07 KL_div:0.0004752860695589334 current_lr:0.01 Time taken per iteration: 0.009779930114746094
# Step: 680 Loss: 1.3352791938814335e-07 KL_div:0.00046544376527890563 current_lr:0.01 Time taken per iteration: 0.015772342681884766
# Step: 690 Loss: 1.276478940326342e-07 KL_div:0.0004551755846478045 current_lr:0.01 Time taken per iteration: 0.009702205657958984
# Step: 700 Loss: 1.2246900382706372e-07 KL_div:0.0004470215644687414 current_lr:0.01 Time taken per iteration: 0.009332656860351562
# Step: 710 Loss: 1.1713765246668117e-07 KL_div:0.00043646193807944655 current_lr:0.01 Time taken per iteration: 0.01537322998046875
# Step: 720 Loss: 1.1295361446173047e-07 KL_div:0.0004312125965952873 current_lr:0.01 Time taken per iteration: 0.01069331169128418
# Step: 730 Loss: 1.0853077014871815e-07 KL_div:0.0004229775513522327 current_lr:0.01 Time taken per iteration: 0.010115861892700195
# Step: 740 Loss: 1.0471943312495569e-07 KL_div:0.00041376028093509376 current_lr:0.01 Time taken per iteration: 0.009580850601196289
# Step: 750 Loss: 2.6642004513632855e-07 KL_div:0.0004076165205333382 current_lr:0.01 Time taken per iteration: 0.010286331176757812
# Step: 760 Loss: 2.1347583242459223e-05 KL_div:0.0005573565140366554 current_lr:0.01 Time taken per iteration: 0.013597249984741211
# Step: 770 Loss: 6.92046796757495e-06 KL_div:0.00044483249075710773 current_lr:0.01 Time taken per iteration: 0.018110036849975586
# Step: 780 Loss: 1.409012270414678e-06 KL_div:0.0003983493079431355 current_lr:0.01 Time taken per iteration: 0.011304140090942383
# Step: 790 Loss: 1.0364955471686699e-07 KL_div:0.0003841232100967318 current_lr:0.01 Time taken per iteration: 0.012821197509765625
# Step: 800 Loss: 1.4064477227293537e-07 KL_div:0.0003807650355156511 current_lr:0.01 Time taken per iteration: 0.009555339813232422
# Step: 810 Loss: 1.385115808716364e-07 KL_div:0.0003735129430424422 current_lr:0.01 Time taken per iteration: 0.012029647827148438
# Step: 820 Loss: 1.0505100789259814e-07 KL_div:0.0003676920023281127 current_lr:0.01 Time taken per iteration: 0.010380744934082031
# Step: 830 Loss: 8.498835768477875e-08 KL_div:0.00036372948670759797 current_lr:0.01 Time taken per iteration: 0.015142202377319336
# Step: 840 Loss: 7.669201806947967e-08 KL_div:0.0003582049976103008 current_lr:0.01 Time taken per iteration: 0.0096588134765625
# Step: 850 Loss: 7.496784348859364e-08 KL_div:0.0003540296165738255 current_lr:0.01 Time taken per iteration: 0.01154017448425293
# Step: 860 Loss: 7.316850059169155e-08 KL_div:0.00035017746267840266 current_lr:0.01 Time taken per iteration: 0.015283584594726562
# Step: 870 Loss: 7.034032734054563e-08 KL_div:0.0003450080403126776 current_lr:0.01 Time taken per iteration: 0.013223648071289062
# Step: 880 Loss: 6.89091237404682e-08 KL_div:0.0003426646289881319 current_lr:0.01 Time taken per iteration: 0.015388011932373047
# Step: 890 Loss: 6.693812082403383e-08 KL_div:0.0003377473331056535 current_lr:0.01 Time taken per iteration: 0.010318756103515625
# Step: 900 Loss: 6.555054454793208e-08 KL_div:0.0003357260429766029 current_lr:0.01 Time taken per iteration: 0.009378433227539062
# Step: 910 Loss: 6.411387687421666e-08 KL_div:0.0003328206075821072 current_lr:0.01 Time taken per iteration: 0.012496232986450195
# Step: 920 Loss: 6.271314845207598e-08 KL_div:0.0003297479706816375 current_lr:0.01 Time taken per iteration: 0.01108407974243164
# Step: 930 Loss: 6.118029460822072e-08 KL_div:0.0003255434276070446 current_lr:0.01 Time taken per iteration: 0.011111736297607422
# Step: 940 Loss: 5.97869984630961e-08 KL_div:0.00032181531423702836 current_lr:0.01 Time taken per iteration: 0.01415109634399414
# Step: 950 Loss: 5.8896588939205685e-08 KL_div:0.0003211202274542302 current_lr:0.01 Time taken per iteration: 0.013862848281860352
# Step: 960 Loss: 5.7910327200261236e-08 KL_div:0.0003182130749337375 current_lr:0.01 Time taken per iteration: 0.008949756622314453
# Step: 970 Loss: 8.700956755092193e-08 KL_div:0.00031483150087296963 current_lr:0.01 Time taken per iteration: 0.009262561798095703
# Step: 980 Loss: 1.125405469792895e-05 KL_div:0.00039422279223799706 current_lr:0.01 Time taken per iteration: 0.01343083381652832
# Step: 990 Loss: 1.0527141057536937e-05 KL_div:0.00038599269464612007 current_lr:0.01 Time taken per iteration: 0.01620197296142578
# Step: 1000 Loss: 2.5370018192916177e-06 KL_div:0.00032481958623975515 current_lr:0.01 Time taken per iteration: 0.015590190887451172

# %%
fig, axs = plt.subplots(1,2,figsize=(15,8))
axs[0].plot(divs)
axs[0].title.set_text('KL Divergence')

axs[1].plot(history)
axs[1].title.set_text('loss')

# %%
optimal_params = parameters[np.argmin(divs)]

qcbm_probs = circuit(optimal_params)
x_array = jnp.arange(0,2**(n_qubits),dtype=jnp.float64)

fig,axs = plt.subplots(1,2,figsize=(15,8))
axs[0].bar(x_array,qcbm_probs[0],color='green',alpha=0.5,label='Obtained Cat')
axs[0].plot(x_array,cat_data,color='blue',alpha=0.5,label='Original Cat')
axs[0].title.set_text('Cat Distribution')

axs[1].bar(x_array,qcbm_probs[1],color='green',alpha=0.5,label='AntiCat')
axs[1].plot(x_array,anticat_data,color='blue',alpha=0.5,label='Original AntiCat')
axs[1].title.set_text('AntiCat Distribution')

# %%
print(f"Minimum KL Divergence obtained is {np.min(divs)}")
# Out:
# Minimum KL Divergence obtained is 0.0003071989049203694

# %%
cat_pdistribution = pnumber_distribution(qcbm_probs[0],n_qubits)
anticat_pdistribution = pnumber_distribution(qcbm_probs[1],n_qubits)

# %%
x = np.arange(0,n_qubits+1)

fig,axs = plt.subplots(1,2,figsize=(15,8))
axs[0].bar(x,cat_pdistribution, label='Cat')
axs[0].set_title('Cat Particle Number Distribution')
axs[0].set_xlabel('Particle Number')
axs[0].set_ylabel('Probability')
axs[0].legend()

axs[1].bar(x,anticat_pdistribution, label='AntiCat')
axs[1].set_title('AntiCat Particle Number Distribution')
axs[1].set_xlabel('Particle Number')
axs[1].set_ylabel('Probability')
axs[1].legend()

# %%
plt.bar(x,cat_pdistribution+anticat_pdistribution)
plt.title('Total Probability Distribution')
plt.xlabel('Particle Number')
plt.ylabel('Probability')
plt.show()

# %%
# #Save Checkpoint
# checkpoint = {"final_epoch":i,
#               "history":history,
#               "divs":divs,
#               "parameters":parameters}

# with open(f'data/4qubit_model_cat_anticat_distribution.pkl','wb') as file:
#     pickle.dump(checkpoint,file)
    
# print("Model saved successfully")
