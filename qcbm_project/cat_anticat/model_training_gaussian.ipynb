# %%
from model_and_circuit import *

# %%
with open("/home/akashm/PROJECT/qcbm_hiwi/qcbm_project/cat_anticat/data/4qubit_target_distribution.pkl", "rb") as f:
    target_distribution = pickle.load(f)
plt.plot(target_distribution)

# %%
qml.draw_mpl(circuit,device='default')(initial_params)
plt.show()

# %%
class MMD:
    def __init__(self,scales,space):
        gammas = 1/(2*(scales**2)).reshape(-1,1,1)
        sq_dists = jnp.abs(space[:,None] - space[None,:])**2
        self.K = jnp.sum(jnp.exp(-gammas * sq_dists), axis=0)/len(scales)
        self.scales = scales
        
    def k_expval(self,px,py):
        return (px @ self.K @ py)
    
    def __call__(self,px,py):
        pxy = px-py
        return self.k_expval(pxy,pxy) 
    
class QCBM:
    def __init__(self,circ,mmd,py):
        self.circ = circ
        self.mmd = mmd
        self.py = py
    
    def mmd_loss(self,params):
        px = self.circ(params)
        loss = (self.mmd(px[0],self.py)) #+ 1*jnp.log10(pnumber_distribution(px[1],n_qubits)[1])**2)
        return loss, px
    

#Model Training
@jit
def update_step(params,opt_state):
    
    (loss_val,qcbm_probs), grads = jax.value_and_grad(qcbm.mmd_loss,has_aux=True)(params)

    updates,opt_state = opt.update(grads,opt_state)
    params = optax.apply_updates(params,updates)
    
    qcbm_probs1 = jnp.asarray(qcbm_probs[0], dtype=jnp.float64)
    qcbm_probs2 = jnp.asarray(qcbm_probs[1], dtype=jnp.float64)
    
    kl_div = (
        -jnp.sum(target_distribution * jnp.nan_to_num(jnp.log(qcbm_probs1) - jnp.log(target_distribution))) 
        #+ 1*jnp.log10(pnumber_distribution(qcbm_probs2,n_qubits)[1])**2
        )
    
    return params, opt_state, loss_val, kl_div

# %%
# #Load the Checkpoint

# with open('/home/akashm/PROJECT/Hiwi_qml/qcbm/model/data_ancilla/model_checkpoint_0.01_13135.pkl', "rb") as file:
#     checkpoint = pickle.load(file)

# start_epoch = checkpoint["final_epoch"] + 1
# weights = checkpoint["parameters"]
# loss_values = checkpoint["history"]
# kl_values = checkpoint["divs"]

# print(f"Resuming training from epoch {start_epoch}...")

# %%
#Calling MMD class
bandwidth = jnp.array([0.25,60],dtype=jnp.float64)
space = jnp.arange(0,2**n_qubits,dtype=jnp.float64)
mmd = MMD(bandwidth,space=space)


#Calling QCBM class to run the previous built circuit with random weights
qcbm = QCBM(circuit,mmd=mmd,py=target_distribution)


#Initial parameters
weights = initial_params
# lr = optax.exponential_decay(init_value=0.1,transition_steps=10,decay_rate=0.99,transition_begin=300,end_value=0.01,staircase=True)
lr = 0.1
opt = optax.adam(learning_rate=lr)
opt_state = opt.init(weights)


history = []
divs = []
parameters = []


kl_div = 1
i = 0 
n_epochs = 2001

# while kl_div > 10^-3:
while i < n_epochs:
    i+=1
    # current_lr = lr(i)
    current_lr = lr
    start_time = time.time()
    weights, opt_state, loss_val, kl_div = update_step(params=weights,opt_state=opt_state)
    end_time = time.time()
    
    if i%10==0:
        print(f"Step: {i} Loss: {loss_val} KL_div:{kl_div} current_lr:{current_lr} Time taken per iteration: {end_time-start_time}")
    
    history.append(loss_val)
    divs.append(kl_div)
    parameters.append(weights)
# Out:
# Step: 10 Loss: 0.008459067903459072 KL_div:0.13222728669643402 current_lr:0.1 Time taken per iteration: 0.00393986701965332
# Step: 20 Loss: 0.0020719009917229414 KL_div:0.07683777809143066 current_lr:0.1 Time taken per iteration: 0.005392789840698242
# Step: 30 Loss: 0.0005635128472931683 KL_div:0.0322156623005867 current_lr:0.1 Time taken per iteration: 0.0029649734497070312
# Step: 40 Loss: 0.000200197275262326 KL_div:0.016273293644189835 current_lr:0.1 Time taken per iteration: 0.004848957061767578
# Step: 50 Loss: 8.391945448238403e-05 KL_div:0.010354817844927311 current_lr:0.1 Time taken per iteration: 0.003217458724975586
# Step: 60 Loss: 5.840981248184107e-05 KL_div:0.00846237875521183 current_lr:0.1 Time taken per iteration: 0.0035200119018554688
# Step: 70 Loss: 4.1043102100957185e-05 KL_div:0.0072824060916900635 current_lr:0.1 Time taken per iteration: 0.003136873245239258
# Step: 80 Loss: 2.9427159461192787e-05 KL_div:0.005475449375808239 current_lr:0.1 Time taken per iteration: 0.0029168128967285156
# Step: 90 Loss: 2.36012401728658e-05 KL_div:0.004414156079292297 current_lr:0.1 Time taken per iteration: 0.005323886871337891
# Step: 100 Loss: 1.8929122234112583e-05 KL_div:0.0038142406847327948 current_lr:0.1 Time taken per iteration: 0.009131431579589844
# Step: 110 Loss: 1.560571945447009e-05 KL_div:0.0034409898798912764 current_lr:0.1 Time taken per iteration: 0.0063021183013916016
# Step: 120 Loss: 1.2865049939136952e-05 KL_div:0.0030913136433809996 current_lr:0.1 Time taken per iteration: 0.010270118713378906
# Step: 130 Loss: 1.0535613000683952e-05 KL_div:0.002730052452534437 current_lr:0.1 Time taken per iteration: 0.0034449100494384766
# Step: 140 Loss: 8.581771908211522e-06 KL_div:0.002428908133879304 current_lr:0.1 Time taken per iteration: 0.002853870391845703
# Step: 150 Loss: 6.954917807888705e-06 KL_div:0.002196395304054022 current_lr:0.1 Time taken per iteration: 0.0034096240997314453
# Step: 160 Loss: 5.629226052406011e-06 KL_div:0.0020121103152632713 current_lr:0.1 Time taken per iteration: 0.00982213020324707
# Step: 170 Loss: 4.570631972455885e-06 KL_div:0.001858122763223946 current_lr:0.1 Time taken per iteration: 0.0052220821380615234
# Step: 180 Loss: 3.741736236406723e-06 KL_div:0.001730967778712511 current_lr:0.1 Time taken per iteration: 0.004492521286010742
# Step: 190 Loss: 3.100043613812886e-06 KL_div:0.0016241089906543493 current_lr:0.1 Time taken per iteration: 0.0036725997924804688
# Step: 200 Loss: 2.6049010557471775e-06 KL_div:0.0015342060942202806 current_lr:0.1 Time taken per iteration: 0.0030922889709472656
# Step: 210 Loss: 2.221277554781409e-06 KL_div:0.001457552658393979 current_lr:0.1 Time taken per iteration: 0.004772663116455078
# Step: 220 Loss: 1.9205501757824095e-06 KL_div:0.001390783116221428 current_lr:0.1 Time taken per iteration: 0.003305196762084961
# Step: 230 Loss: 1.6811512750791735e-06 KL_div:0.001331243198364973 current_lr:0.1 Time taken per iteration: 0.003804922103881836
# Step: 240 Loss: 1.4872252904751804e-06 KL_div:0.0012773241614922881 current_lr:0.1 Time taken per iteration: 0.009999990463256836
# Step: 250 Loss: 1.3269785767988651e-06 KL_div:0.001227118307724595 current_lr:0.1 Time taken per iteration: 0.0063931941986083984
# Step: 260 Loss: 1.1930350183320115e-06 KL_div:0.0011814970057457685 current_lr:0.1 Time taken per iteration: 0.0048542022705078125
# Step: 270 Loss: 1.0787731525851996e-06 KL_div:0.001138149993494153 current_lr:0.1 Time taken per iteration: 0.006762266159057617
# Step: 280 Loss: 9.809203902477748e-07 KL_div:0.0010986365377902985 current_lr:0.1 Time taken per iteration: 0.003407001495361328
# Step: 290 Loss: 8.958530770541984e-07 KL_div:0.0010616424260661006 current_lr:0.1 Time taken per iteration: 0.006603717803955078
# Step: 300 Loss: 8.214339572987228e-07 KL_div:0.0010273021180182695 current_lr:0.1 Time taken per iteration: 0.0032913684844970703
# Step: 310 Loss: 7.556644163742021e-07 KL_div:0.0009948115330189466 current_lr:0.1 Time taken per iteration: 0.007239103317260742
# Step: 320 Loss: 6.971534389776934e-07 KL_div:0.0009640465723350644 current_lr:0.1 Time taken per iteration: 0.0033020973205566406
# Step: 330 Loss: 6.452339675888652e-07 KL_div:0.0009356989176012576 current_lr:0.1 Time taken per iteration: 0.004137992858886719
# Step: 340 Loss: 5.986759674669884e-07 KL_div:0.0009090174571610987 current_lr:0.1 Time taken per iteration: 0.010222673416137695
# Step: 350 Loss: 5.565290166487102e-07 KL_div:0.00088322046212852 current_lr:0.1 Time taken per iteration: 0.003535032272338867
# Step: 360 Loss: 5.188717864257342e-07 KL_div:0.0008597925188951194 current_lr:0.1 Time taken per iteration: 0.0036749839782714844
# Step: 370 Loss: 4.845147714149789e-07 KL_div:0.0008369941497221589 current_lr:0.1 Time taken per iteration: 0.007735729217529297
# Step: 380 Loss: 4.5332498643801955e-07 KL_div:0.0008154133101925254 current_lr:0.1 Time taken per iteration: 0.003465414047241211
# Step: 390 Loss: 4.251076575201296e-07 KL_div:0.0007954725297167897 current_lr:0.1 Time taken per iteration: 0.0038137435913085938
# Step: 400 Loss: 3.9913877003527887e-07 KL_div:0.0007759022410027683 current_lr:0.1 Time taken per iteration: 0.0031609535217285156
# Step: 410 Loss: 3.7573431654891465e-07 KL_div:0.0007581860991194844 current_lr:0.1 Time taken per iteration: 0.006679534912109375
# Step: 420 Loss: 3.5412926990829874e-07 KL_div:0.0007409563986584544 current_lr:0.1 Time taken per iteration: 0.0033774375915527344
# Step: 430 Loss: 3.341143042234762e-07 KL_div:0.0007240183185786009 current_lr:0.1 Time taken per iteration: 0.006023883819580078
# Step: 440 Loss: 3.158949368753383e-07 KL_div:0.0007084303069859743 current_lr:0.1 Time taken per iteration: 0.0045490264892578125
# Step: 450 Loss: 2.9924822797511297e-07 KL_div:0.0006938915466889739 current_lr:0.1 Time taken per iteration: 0.003767728805541992
# Step: 460 Loss: 2.8367162485665176e-07 KL_div:0.0006794128566980362 current_lr:0.1 Time taken per iteration: 0.010082721710205078
# Step: 470 Loss: 2.6907562755695835e-07 KL_div:0.0006650457507930696 current_lr:0.1 Time taken per iteration: 0.004526376724243164
# Step: 480 Loss: 2.559773122357001e-07 KL_div:0.0006524296477437019 current_lr:0.1 Time taken per iteration: 0.006460428237915039
# Step: 490 Loss: 2.434440773413371e-07 KL_div:0.0006392106297425926 current_lr:0.1 Time taken per iteration: 0.0036971569061279297
# Step: 500 Loss: 2.3232249191096344e-07 KL_div:0.0006280559464357793 current_lr:0.1 Time taken per iteration: 0.004971742630004883
# Step: 510 Loss: 2.2175917990807648e-07 KL_div:0.0006167017854750156 current_lr:0.1 Time taken per iteration: 0.0037648677825927734
# Step: 520 Loss: 2.1161433494398807e-07 KL_div:0.0006048593786545098 current_lr:0.1 Time taken per iteration: 0.003223419189453125
# Step: 530 Loss: 2.022746627972083e-07 KL_div:0.0005938676185905933 current_lr:0.1 Time taken per iteration: 0.007017612457275391
# Step: 540 Loss: 1.9365685943739663e-07 KL_div:0.0005835889023728669 current_lr:0.1 Time taken per iteration: 0.007389545440673828
# Step: 550 Loss: 1.856430600355452e-07 KL_div:0.0005737572209909558 current_lr:0.1 Time taken per iteration: 0.005486011505126953
# Step: 560 Loss: 1.781597802619217e-07 KL_div:0.00056444201618433 current_lr:0.1 Time taken per iteration: 0.0036482810974121094
# Step: 570 Loss: 1.7094700410780206e-07 KL_div:0.000554801314137876 current_lr:0.1 Time taken per iteration: 0.004545450210571289
# Step: 580 Loss: 1.6427662785645225e-07 KL_div:0.000545825227163732 current_lr:0.1 Time taken per iteration: 0.005633115768432617
# Step: 590 Loss: 1.5808888065294013e-07 KL_div:0.0005373826716095209 current_lr:0.1 Time taken per iteration: 0.0034058094024658203
# Step: 600 Loss: 1.520819949973884e-07 KL_div:0.0005286857485771179 current_lr:0.1 Time taken per iteration: 0.006175041198730469
# Step: 610 Loss: 1.4666545666841557e-07 KL_div:0.0005210119998082519 current_lr:0.1 Time taken per iteration: 0.006350517272949219
# Step: 620 Loss: 1.4149325977541594e-07 KL_div:0.0005133467493578792 current_lr:0.1 Time taken per iteration: 0.008699655532836914
# Step: 630 Loss: 1.3657496822361281e-07 KL_div:0.0005058236420154572 current_lr:0.1 Time taken per iteration: 0.003915071487426758
# Step: 640 Loss: 1.319626505846827e-07 KL_div:0.0004986781859770417 current_lr:0.1 Time taken per iteration: 0.008006095886230469
# Step: 650 Loss: 1.2742142985189275e-07 KL_div:0.0004911758005619049 current_lr:0.1 Time taken per iteration: 0.006278038024902344
# Step: 660 Loss: 1.2358759704511613e-07 KL_div:0.0004854074213653803 current_lr:0.1 Time taken per iteration: 0.00468134880065918
# Step: 670 Loss: 1.1968714375143463e-07 KL_div:0.00047890515998005867 current_lr:0.1 Time taken per iteration: 0.008188486099243164
# Step: 680 Loss: 1.158892075636686e-07 KL_div:0.000472251238534227 current_lr:0.1 Time taken per iteration: 0.007180690765380859
# Step: 690 Loss: 1.123444874906454e-07 KL_div:0.0004660205449908972 current_lr:0.1 Time taken per iteration: 0.006089687347412109
# Step: 700 Loss: 1.0911594472418074e-07 KL_div:0.00046043688780628145 current_lr:0.1 Time taken per iteration: 0.003448009490966797
# Step: 710 Loss: 1.0597808142165377e-07 KL_div:0.00045477779349312186 current_lr:0.1 Time taken per iteration: 0.007330894470214844
# Step: 720 Loss: 1.0296648156327137e-07 KL_div:0.0004492036532610655 current_lr:0.1 Time taken per iteration: 0.005215167999267578
# Step: 730 Loss: 1.0003283534842922e-07 KL_div:0.0004435720038600266 current_lr:0.1 Time taken per iteration: 0.005280971527099609
# Step: 740 Loss: 9.743465767542148e-08 KL_div:0.00043871987145394087 current_lr:0.1 Time taken per iteration: 0.0034685134887695312
# Step: 750 Loss: 9.489630770076474e-08 KL_div:0.00043378520058467984 current_lr:0.1 Time taken per iteration: 0.006404876708984375
# Step: 760 Loss: 9.219576213581604e-08 KL_div:0.0004280680441297591 current_lr:0.1 Time taken per iteration: 0.0037848949432373047
# Step: 770 Loss: 9.003940704133129e-08 KL_div:0.0004239301197230816 current_lr:0.1 Time taken per iteration: 0.011008739471435547
# Step: 780 Loss: 8.786683736161649e-08 KL_div:0.00041951355524361134 current_lr:0.1 Time taken per iteration: 0.00441431999206543
# Step: 790 Loss: 8.564337861116655e-08 KL_div:0.00041469171992503107 current_lr:0.1 Time taken per iteration: 0.0037140846252441406
# Step: 800 Loss: 8.38018152649056e-08 KL_div:0.0004109928850084543 current_lr:0.1 Time taken per iteration: 0.004155397415161133
# Step: 810 Loss: 8.173514487452849e-08 KL_div:0.00040631936280988157 current_lr:0.1 Time taken per iteration: 0.007043361663818359
# Step: 820 Loss: 8.003897278285876e-08 KL_div:0.0004027587128803134 current_lr:0.1 Time taken per iteration: 0.004792213439941406
# Step: 830 Loss: 7.828666781506399e-08 KL_div:0.00039883391582407057 current_lr:0.1 Time taken per iteration: 0.007600069046020508
# Step: 840 Loss: 7.655258116301411e-08 KL_div:0.00039479328552260995 current_lr:0.1 Time taken per iteration: 0.004609107971191406
# Step: 850 Loss: 7.493853360074354e-08 KL_div:0.0003910582745447755 current_lr:0.1 Time taken per iteration: 0.0063076019287109375
# Step: 860 Loss: 7.338334739870334e-08 KL_div:0.0003873413661494851 current_lr:0.1 Time taken per iteration: 0.00815129280090332
# Step: 870 Loss: 7.188671702351712e-08 KL_div:0.00038374419091269374 current_lr:0.1 Time taken per iteration: 0.0042226314544677734
# Step: 880 Loss: 7.048016925637057e-08 KL_div:0.00038031875737942755 current_lr:0.1 Time taken per iteration: 0.005685567855834961
# Step: 890 Loss: 6.921577266894019e-08 KL_div:0.00037721192347817123 current_lr:0.1 Time taken per iteration: 0.00591588020324707
# Step: 900 Loss: 6.847774614016089e-08 KL_div:0.0003738058148883283 current_lr:0.1 Time taken per iteration: 0.0070993900299072266
# Step: 910 Loss: 1.798597111246636e-07 KL_div:0.00037220204831101 current_lr:0.1 Time taken per iteration: 0.0048007965087890625
# Step: 920 Loss: 4.938865458825603e-05 KL_div:0.0007381383329629898 current_lr:0.1 Time taken per iteration: 0.003904581069946289
# Step: 930 Loss: 6.91016684868373e-05 KL_div:0.0008513452485203743 current_lr:0.1 Time taken per iteration: 0.0052814483642578125
# Step: 940 Loss: 1.271543283110077e-06 KL_div:0.00038623774889856577 current_lr:0.1 Time taken per iteration: 0.016611814498901367
# Step: 950 Loss: 8.559841262467671e-06 KL_div:0.00045295897871255875 current_lr:0.1 Time taken per iteration: 0.012967348098754883
# Step: 960 Loss: 6.720159717588103e-07 KL_div:0.0003846448380500078 current_lr:0.1 Time taken per iteration: 0.004625082015991211
# Step: 970 Loss: 6.152670835035678e-07 KL_div:0.0003820960409939289 current_lr:0.1 Time taken per iteration: 0.011861085891723633
# Step: 980 Loss: 3.542106696841074e-07 KL_div:0.00037947981036268175 current_lr:0.1 Time taken per iteration: 0.014281272888183594
# Step: 990 Loss: 1.0379407910932059e-07 KL_div:0.00037693261401727796 current_lr:0.1 Time taken per iteration: 0.007157564163208008
# Step: 1000 Loss: 1.0000012906630218e-07 KL_div:0.0003734208003152162 current_lr:0.1 Time taken per iteration: 0.007239580154418945
# Step: 1010 Loss: 7.655404488104978e-08 KL_div:0.00036910644848831 current_lr:0.1 Time taken per iteration: 0.011719226837158203
# Step: 1020 Loss: 6.32102015174496e-08 KL_div:0.00036450737388804555 current_lr:0.1 Time taken per iteration: 0.009685277938842773
# Step: 1030 Loss: 6.323196544144594e-08 KL_div:0.0003609018458519131 current_lr:0.1 Time taken per iteration: 0.011324644088745117
# Step: 1040 Loss: 6.127669394118129e-08 KL_div:0.000356867240043357 current_lr:0.1 Time taken per iteration: 0.007730007171630859
# Step: 1050 Loss: 5.975910966071751e-08 KL_div:0.00035409023985266685 current_lr:0.1 Time taken per iteration: 0.006459951400756836
# Step: 1060 Loss: 5.835773819740098e-08 KL_div:0.00035039603244513273 current_lr:0.1 Time taken per iteration: 0.0039017200469970703
# Step: 1070 Loss: 5.74421683552373e-08 KL_div:0.00034786088508553803 current_lr:0.1 Time taken per iteration: 0.012562751770019531
# Step: 1080 Loss: 5.6311328933134064e-08 KL_div:0.0003444504109211266 current_lr:0.1 Time taken per iteration: 0.004782915115356445
# Step: 1090 Loss: 5.529753366317891e-08 KL_div:0.00034133924054913223 current_lr:0.1 Time taken per iteration: 0.004170894622802734
# Step: 1100 Loss: 5.459875040969564e-08 KL_div:0.0003393030201550573 current_lr:0.1 Time taken per iteration: 0.007582664489746094
# Step: 1110 Loss: 5.3887394102503094e-08 KL_div:0.0003370907506905496 current_lr:0.1 Time taken per iteration: 0.00863957405090332
# Step: 1120 Loss: 5.30647028540443e-08 KL_div:0.00033448354224674404 current_lr:0.1 Time taken per iteration: 0.012707233428955078
# Step: 1130 Loss: 5.217123089096276e-08 KL_div:0.00033154693664982915 current_lr:0.1 Time taken per iteration: 0.011530637741088867
# Step: 1140 Loss: 5.1624763131030704e-08 KL_div:0.0003298100782558322 current_lr:0.1 Time taken per iteration: 0.007988929748535156
# Step: 1150 Loss: 5.1105406129181574e-08 KL_div:0.0003280974633526057 current_lr:0.1 Time taken per iteration: 0.011174440383911133
# Step: 1160 Loss: 5.028164551390546e-08 KL_div:0.0003253316390328109 current_lr:0.1 Time taken per iteration: 0.004916667938232422
# Step: 1170 Loss: 4.9838334348351054e-08 KL_div:0.00032383695361204445 current_lr:0.1 Time taken per iteration: 0.006852149963378906
# Step: 1180 Loss: 4.917084339695066e-08 KL_div:0.00032155209919437766 current_lr:0.1 Time taken per iteration: 0.009749412536621094
# Step: 1190 Loss: 4.850134160960806e-08 KL_div:0.0003192174481227994 current_lr:0.1 Time taken per iteration: 0.012707710266113281
# Step: 1200 Loss: 4.814373255612736e-08 KL_div:0.00031796583789400756 current_lr:0.1 Time taken per iteration: 0.004822492599487305
# Step: 1210 Loss: 4.747644410940666e-08 KL_div:0.00031558048794977367 current_lr:0.1 Time taken per iteration: 0.014308691024780273
# Step: 1220 Loss: 4.716769197443682e-08 KL_div:0.00031419616425409913 current_lr:0.1 Time taken per iteration: 0.013667583465576172
# Step: 1230 Loss: 5.3789175780138976e-08 KL_div:0.0003121504560112953 current_lr:0.1 Time taken per iteration: 0.008239030838012695
# Step: 1240 Loss: 1.8645832824404351e-06 KL_div:0.00032392400316894054 current_lr:0.1 Time taken per iteration: 0.006116628646850586
# Step: 1250 Loss: 0.00018792509217746556 KL_div:0.0016905050724744797 current_lr:0.1 Time taken per iteration: 0.007601022720336914
# Step: 1260 Loss: 4.8001700633903965e-05 KL_div:0.00064877700060606 current_lr:0.1 Time taken per iteration: 0.013068199157714844
# Step: 1270 Loss: 7.683841431571636e-06 KL_div:0.00035328930243849754 current_lr:0.1 Time taken per iteration: 0.012334585189819336
# Step: 1280 Loss: 4.173679371888284e-06 KL_div:0.00034953083377331495 current_lr:0.1 Time taken per iteration: 0.010188817977905273
# Step: 1290 Loss: 6.341520588648564e-07 KL_div:0.0003235357580706477 current_lr:0.1 Time taken per iteration: 0.00942087173461914
# Step: 1300 Loss: 5.133202876095311e-07 KL_div:0.00032805121736600995 current_lr:0.1 Time taken per iteration: 0.012233972549438477
# Step: 1310 Loss: 2.0238168474406848e-07 KL_div:0.00032654881943017244 current_lr:0.1 Time taken per iteration: 0.009857416152954102
# Step: 1320 Loss: 8.152781560966105e-08 KL_div:0.0003238064527977258 current_lr:0.1 Time taken per iteration: 0.007765293121337891
# Step: 1330 Loss: 7.358044484817583e-08 KL_div:0.00031937434687279165 current_lr:0.1 Time taken per iteration: 0.008023738861083984
# Step: 1340 Loss: 5.102616285057593e-08 KL_div:0.0003165208036080003 current_lr:0.1 Time taken per iteration: 0.010524749755859375
# Step: 1350 Loss: 4.8101483685059065e-08 KL_div:0.0003128370735794306 current_lr:0.1 Time taken per iteration: 0.009143352508544922
# Step: 1360 Loss: 4.737653824804511e-08 KL_div:0.0003104046336375177 current_lr:0.1 Time taken per iteration: 0.005632877349853516
# Step: 1370 Loss: 4.554090438091407e-08 KL_div:0.00030811098986305296 current_lr:0.1 Time taken per iteration: 0.008285760879516602
# Step: 1380 Loss: 4.49267680835419e-08 KL_div:0.0003066255303565413 current_lr:0.1 Time taken per iteration: 0.00679469108581543
# Step: 1390 Loss: 4.424970612149082e-08 KL_div:0.0003040259180124849 current_lr:0.1 Time taken per iteration: 0.009073734283447266
# Step: 1400 Loss: 4.382847151873648e-08 KL_div:0.00030235532904043794 current_lr:0.1 Time taken per iteration: 0.004033088684082031
# Step: 1410 Loss: 4.3310130592999485e-08 KL_div:0.00030036811949685216 current_lr:0.1 Time taken per iteration: 0.004314422607421875
# Step: 1420 Loss: 4.2957019275036146e-08 KL_div:0.0002988958149217069 current_lr:0.1 Time taken per iteration: 0.0037462711334228516
# Step: 1430 Loss: 4.2578438552709486e-08 KL_div:0.0002973365772049874 current_lr:0.1 Time taken per iteration: 0.0063550472259521484
# Step: 1440 Loss: 4.226258454309573e-08 KL_div:0.0002959558041766286 current_lr:0.1 Time taken per iteration: 0.008584260940551758
# Step: 1450 Loss: 4.17958823106801e-08 KL_div:0.00029400252969935536 current_lr:0.1 Time taken per iteration: 0.006819009780883789
# Step: 1460 Loss: 4.1521747817796495e-08 KL_div:0.00029279422597028315 current_lr:0.1 Time taken per iteration: 0.0050542354583740234
# Step: 1470 Loss: 4.109585560740925e-08 KL_div:0.00029101409018039703 current_lr:0.1 Time taken per iteration: 0.005462169647216797
# Step: 1480 Loss: 4.081510596165572e-08 KL_div:0.00028977548936381936 current_lr:0.1 Time taken per iteration: 0.006339550018310547
# Step: 1490 Loss: 4.066023251425577e-08 KL_div:0.000288986339000985 current_lr:0.1 Time taken per iteration: 0.007759809494018555
# Step: 1500 Loss: 4.03975377594179e-08 KL_div:0.00028776429826393723 current_lr:0.1 Time taken per iteration: 0.006582736968994141
# Step: 1510 Loss: 3.988742136584733e-08 KL_div:0.000285688933217898 current_lr:0.1 Time taken per iteration: 0.00631403923034668
# Step: 1520 Loss: 3.9719619593370226e-08 KL_div:0.0002848351141437888 current_lr:0.1 Time taken per iteration: 0.006617069244384766
# Step: 1530 Loss: 3.9568831766700896e-08 KL_div:0.00028404040494933724 current_lr:0.1 Time taken per iteration: 0.00593256950378418
# Step: 1540 Loss: 3.931383574240499e-08 KL_div:0.00028286012820899487 current_lr:0.1 Time taken per iteration: 0.003659486770629883
# Step: 1550 Loss: 3.9104836702108514e-08 KL_div:0.0002817223721649498 current_lr:0.1 Time taken per iteration: 0.004108428955078125
# Step: 1560 Loss: 3.949104510070356e-08 KL_div:0.0002802307717502117 current_lr:0.1 Time taken per iteration: 0.006092071533203125
# Step: 1570 Loss: 8.399248940804682e-08 KL_div:0.00028047029627487063 current_lr:0.1 Time taken per iteration: 0.005905628204345703
# Step: 1580 Loss: 6.991488589846995e-06 KL_div:0.00032163597643375397 current_lr:0.1 Time taken per iteration: 0.005151271820068359
# Step: 1590 Loss: 3.604085941333324e-05 KL_div:0.0005243162158876657 current_lr:0.1 Time taken per iteration: 0.004679679870605469
# Step: 1600 Loss: 1.5139927199925296e-05 KL_div:0.00047356111463159323 current_lr:0.1 Time taken per iteration: 0.009462118148803711
# Step: 1610 Loss: 1.0024794391938485e-05 KL_div:0.0004434124566614628 current_lr:0.1 Time taken per iteration: 0.006670713424682617
# Step: 1620 Loss: 2.888994686145452e-06 KL_div:0.00041390396654605865 current_lr:0.1 Time taken per iteration: 0.005887508392333984
# Step: 1630 Loss: 2.887013579311315e-07 KL_div:0.0003989569377154112 current_lr:0.1 Time taken per iteration: 0.007985115051269531
# Step: 1640 Loss: 3.3858052006507933e-07 KL_div:0.00039746472612023354 current_lr:0.1 Time taken per iteration: 0.00535273551940918
# Step: 1650 Loss: 8.22429910840583e-08 KL_div:0.0003860464785248041 current_lr:0.1 Time taken per iteration: 0.007565736770629883
# Step: 1660 Loss: 9.721401283968589e-08 KL_div:0.0003726973372977227 current_lr:0.1 Time taken per iteration: 0.008948802947998047
# Step: 1670 Loss: 7.389159861759254e-08 KL_div:0.0003613827284425497 current_lr:0.1 Time taken per iteration: 0.004618644714355469
# Step: 1680 Loss: 6.448663469882376e-08 KL_div:0.00035254270187579095 current_lr:0.1 Time taken per iteration: 0.007964372634887695
# Step: 1690 Loss: 5.973795680347393e-08 KL_div:0.0003452493401709944 current_lr:0.1 Time taken per iteration: 0.0035004615783691406
# Step: 1700 Loss: 5.8642584122026165e-08 KL_div:0.0003398165572434664 current_lr:0.1 Time taken per iteration: 0.007902383804321289
# Step: 1710 Loss: 9.382917909306343e-08 KL_div:0.00033465446904301643 current_lr:0.1 Time taken per iteration: 0.005521297454833984
# Step: 1720 Loss: 1.5587830830554594e-06 KL_div:0.0003403992741368711 current_lr:0.1 Time taken per iteration: 0.007619380950927734
# Step: 1730 Loss: 6.444224709412083e-05 KL_div:0.0007285154424607754 current_lr:0.1 Time taken per iteration: 0.008286476135253906
# Step: 1740 Loss: 1.1394195098546334e-05 KL_div:0.00040642486419528723 current_lr:0.1 Time taken per iteration: 0.005612850189208984
# Step: 1750 Loss: 4.839498160436051e-06 KL_div:0.00036035472294315696 current_lr:0.1 Time taken per iteration: 0.003801584243774414
# Step: 1760 Loss: 1.1132513009215472e-06 KL_div:0.0003281226963736117 current_lr:0.1 Time taken per iteration: 0.006936311721801758
# Step: 1770 Loss: 2.365493543265984e-07 KL_div:0.0003125039511360228 current_lr:0.1 Time taken per iteration: 0.0035169124603271484
# Step: 1780 Loss: 6.230239790738779e-08 KL_div:0.0003031891828868538 current_lr:0.1 Time taken per iteration: 0.005357980728149414
# Step: 1790 Loss: 4.909001205533059e-08 KL_div:0.00029600440757349133 current_lr:0.1 Time taken per iteration: 0.006775856018066406
# Step: 1800 Loss: 4.5017060301688616e-08 KL_div:0.0002898172533605248 current_lr:0.1 Time taken per iteration: 0.0036487579345703125
# Step: 1810 Loss: 4.3690455697742436e-08 KL_div:0.00028517417376860976 current_lr:0.1 Time taken per iteration: 0.006314992904663086
# Step: 1820 Loss: 4.258079044916485e-08 KL_div:0.00028267610468901694 current_lr:0.1 Time taken per iteration: 0.005977153778076172
# Step: 1830 Loss: 4.020069965804396e-08 KL_div:0.00028020190075039864 current_lr:0.1 Time taken per iteration: 0.008281946182250977
# Step: 1840 Loss: 3.8428296988968214e-08 KL_div:0.0002785301476251334 current_lr:0.1 Time taken per iteration: 0.008295297622680664
# Step: 1850 Loss: 3.8022164972062455e-08 KL_div:0.00027673901058733463 current_lr:0.1 Time taken per iteration: 0.004243612289428711
# Step: 1860 Loss: 3.780941071340749e-08 KL_div:0.0002754960733000189 current_lr:0.1 Time taken per iteration: 0.004564523696899414
# Step: 1870 Loss: 3.76351039221845e-08 KL_div:0.00027457450050860643 current_lr:0.1 Time taken per iteration: 0.004865169525146484
# Step: 1880 Loss: 3.7723612678064455e-08 KL_div:0.0002732661087065935 current_lr:0.1 Time taken per iteration: 0.005997419357299805
# Step: 1890 Loss: 6.183641687584895e-08 KL_div:0.00027171248802915215 current_lr:0.1 Time taken per iteration: 0.009793519973754883
# Step: 1900 Loss: 3.995650786237093e-06 KL_div:0.00029534613713622093 current_lr:0.1 Time taken per iteration: 0.006977081298828125
# Step: 1910 Loss: 3.9238300814758986e-05 KL_div:0.0005346974357962608 current_lr:0.1 Time taken per iteration: 0.00694584846496582
# Step: 1920 Loss: 1.0121513696503825e-05 KL_div:0.00041192909702658653 current_lr:0.1 Time taken per iteration: 0.004427909851074219
# Step: 1930 Loss: 5.28473719896283e-06 KL_div:0.0004143943078815937 current_lr:0.1 Time taken per iteration: 0.01468038558959961
# Step: 1940 Loss: 4.18129047830007e-06 KL_div:0.0004095487529411912 current_lr:0.1 Time taken per iteration: 0.011676311492919922
# Step: 1950 Loss: 2.0950270140929206e-07 KL_div:0.00039810777525417507 current_lr:0.1 Time taken per iteration: 0.010921955108642578
# Step: 1960 Loss: 6.588158498743724e-07 KL_div:0.0003902806784026325 current_lr:0.1 Time taken per iteration: 0.005792856216430664
# Step: 1970 Loss: 4.0302631987287896e-07 KL_div:0.000374954950530082 current_lr:0.1 Time taken per iteration: 0.008732080459594727
# Step: 1980 Loss: 4.4816695776717097e-07 KL_div:0.00036203337367624044 current_lr:0.1 Time taken per iteration: 0.006276369094848633
# Step: 1990 Loss: 2.6893771973846015e-06 KL_div:0.0003649548161774874 current_lr:0.1 Time taken per iteration: 0.005766391754150391
# Step: 2000 Loss: 2.1370673493947834e-05 KL_div:0.0004747093189507723 current_lr:0.1 Time taken per iteration: 0.007412910461425781

# %%
# import pickle

# #Save Checkpoint
# checkpoint = {"final_epoch":i,
#               "history":history,
#               "divs":divs,
#               "parameters":parameters}

# # with open(f'anticat_model_distribution_copy.pkl','wb') as file:
# with open(f'4qubit_cat_model_checkpoint.pkl','wb') as file:
#     pickle.dump(checkpoint,file)
    
# print("Model saved successfully")

# %%
fig, axs = plt.subplots(1,2,figsize=(15,8))
axs[0].plot(divs)
axs[0].title.set_text('KL Divergence')

axs[1].plot(history)
axs[1].title.set_text('loss')

# %%
optimal_params = parameters[np.argmin(divs)]
qcbm_probs = circuit(optimal_params)
x_full = jnp.arange(0,2**n_qubits,dtype=jnp.float64)

fig, axs = plt.subplots(1,2,figsize=(15,5))
axs[0].bar(x_full,qcbm_probs[0],color='green',alpha=0.5,label='Obtained Distribution')
axs[0].plot(x_full,target_distribution,color='blue',alpha=0.5,label='Target Distribution')
axs[0].legend()
axs[0].set_title('Obtained vs Target Distribution')
axs[0].set_xlabel('Hilbert Space')
axs[0].set_ylabel('Probability Distribution')

axs[1].plot(x_full,qcbm_probs[1],color='red',alpha=0.5,label='Obtained Distribution')
axs[1].legend()
axs[1].set_title('Obtained Anticat Distribution')
axs[1].set_xlabel('Hilbert Space')
axs[1].set_ylabel('Probability Distribution')
# Out:
# Text(0, 0.5, 'Probability Distribution')

# %%
x = jnp.arange(0,n_qubits+1,dtype=jnp.float64)

fig, axs = plt.subplots(1,2,figsize=(15,5))
particle_distribution1 = pnumber_distribution(qcbm_probs[0],n_qubits)
axs[0].bar(x,particle_distribution1,color='green',alpha=0.5,label='Obtained Distribution')
axs[0].set_title('Particle Number Distribution of Cat')
axs[0].set_xlabel('Particle Number')
axs[0].set_ylabel('Probability')

particle_distribution2 = pnumber_distribution(qcbm_probs[1],n_qubits)
axs[1].bar(x,particle_distribution2,color='green',alpha=0.5,label='Obtained Distribution')
axs[1].set_title('Particle Number Distribution of Anticat')
axs[1].set_xlabel('Particle Number')
axs[1].set_ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %%
print(f"The minimum KL divergence obtained with ancillas, no pretraining and local entanglement : {min(divs)} in {n_epochs} epochs")
# Out:
# The minimum KL divergence obtained with ancillas, no pretraining and local entanglement : 0.00027171248802915215 in 2001 epochs

# %%
with open("/home/akashm/PROJECT/qcbm_hiwi/qcbm_project/cat_anticat/data/4qubit_gaussian_anticat_distribution.pkl", "wb") as f:
    pickle.dump(qcbm_probs[1], f)
    
print("Anticat distribution saved successfully")
# Out:
# Anticat distribution saved successfully
