# %%
from model_and_circuit import *

# %%
with open("/home/akashm/PROJECT/qcbm_hiwi/qcbm_project/cat_anticat/data/4qubit_trial_distribution.pkl", "rb") as f:
    target_distribution = pickle.load(f)
plt.plot(target_distribution)

# %%
qml.draw_mpl(circuit,device='default')(initial_params)
plt.show()

# %%
class MMD:
    def __init__(self,scales,space):
        gammas = 1/(2*(scales**2)).reshape(-1,1,1)
        sq_dists = jnp.abs(space[:,None] - space[None,:])**2
        self.K = jnp.sum(jnp.exp(-gammas * sq_dists), axis=0)/len(scales)
        self.scales = scales
        
    def k_expval(self,px,py):
        return (px @ self.K @ py)
    
    def __call__(self,px,py):
        pxy = px-py
        return self.k_expval(pxy,pxy) 
    
class QCBM:
    def __init__(self,circ,mmd,py):
        self.circ = circ
        self.mmd = mmd
        self.py = py
    
    def mmd_loss(self,params):
        px = self.circ(params)
        loss = (self.mmd(px[0],self.py)) #+ 1*jnp.log10(pnumber_distribution(px[1],n_qubits)[1])**2)
        return loss, px
    

#Model Training
@jit
def update_step(params,opt_state):
    
    (loss_val,qcbm_probs), grads = jax.value_and_grad(qcbm.mmd_loss,has_aux=True)(params)

    updates,opt_state = opt.update(grads,opt_state)
    params = optax.apply_updates(params,updates)
    
    qcbm_probs1 = jnp.asarray(qcbm_probs[0], dtype=jnp.float64)
    qcbm_probs2 = jnp.asarray(qcbm_probs[1], dtype=jnp.float64)
    
    kl_div = (
        -jnp.sum(target_distribution * jnp.nan_to_num(jnp.log(qcbm_probs1) - jnp.log(target_distribution))) 
        #+ 1*jnp.log10(pnumber_distribution(qcbm_probs2,n_qubits)[1])**2
        )
    
    return params, opt_state, loss_val, kl_div

# %%
# #Load the Checkpoint

# with open('/home/akashm/PROJECT/Hiwi_qml/qcbm/model/data_ancilla/model_checkpoint_0.01_13135.pkl', "rb") as file:
#     checkpoint = pickle.load(file)

# start_epoch = checkpoint["final_epoch"] + 1
# weights = checkpoint["parameters"]
# loss_values = checkpoint["history"]
# kl_values = checkpoint["divs"]

# print(f"Resuming training from epoch {start_epoch}...")

# %%
#Calling MMD class
bandwidth = jnp.array([0.25,60],dtype=jnp.float64)
space = jnp.arange(0,2**n_qubits,dtype=jnp.float64)
mmd = MMD(bandwidth,space=space)


#Calling QCBM class to run the previous built circuit with random weights
qcbm = QCBM(circuit,mmd=mmd,py=target_distribution)


#Initial parameters
weights = initial_params
# lr = optax.exponential_decay(init_value=0.1,transition_steps=10,decay_rate=0.99,transition_begin=300,end_value=0.01,staircase=True)
lr = 0.1
opt = optax.adam(learning_rate=lr)
opt_state = opt.init(weights)


history = []
divs = []
parameters = []


kl_div = 1
i = 0 
n_epochs = 2001

# while kl_div > 10^-3:
while i < n_epochs:
    i+=1
    # current_lr = lr(i)
    current_lr = lr
    start_time = time.time()
    weights, opt_state, loss_val, kl_div = update_step(params=weights,opt_state=opt_state)
    end_time = time.time()
    
    if i%10==0:
        print(f"Step: {i} Loss: {loss_val} KL_div:{kl_div} current_lr:{current_lr} Time taken per iteration: {end_time-start_time}")
    
    history.append(loss_val)
    divs.append(kl_div)
    parameters.append(weights)
# Out:
# Step: 990 Loss: 0.0017565764719620347 KL_div:0.05945875495672226 current_lr:0.1 Time taken per iteration: 0.005137920379638672
# Step: 1000 Loss: 0.001756547368131578 KL_div:0.05945783108472824 current_lr:0.1 Time taken per iteration: 0.004714250564575195
# Step: 1010 Loss: 0.0017565339803695679 KL_div:0.05945735424757004 current_lr:0.1 Time taken per iteration: 0.010873556137084961
# Step: 1020 Loss: 0.0017565333982929587 KL_div:0.05945734307169914 current_lr:0.1 Time taken per iteration: 0.005280017852783203
# Step: 1030 Loss: 0.0017565700691193342 KL_div:0.05945803225040436 current_lr:0.1 Time taken per iteration: 0.005478620529174805
# Step: 1040 Loss: 0.0017565692542120814 KL_div:0.05945804715156555 current_lr:0.1 Time taken per iteration: 0.004402637481689453
# Step: 1050 Loss: 0.0017565813614055514 KL_div:0.059458278119564056 current_lr:0.1 Time taken per iteration: 0.005421638488769531
# Step: 1060 Loss: 0.0017565228044986725 KL_div:0.05945725366473198 current_lr:0.1 Time taken per iteration: 0.005963325500488281
# Step: 1070 Loss: 0.0017566080205142498 KL_div:0.059458717703819275 current_lr:0.1 Time taken per iteration: 0.004043102264404297
# Step: 1080 Loss: 0.0017565736779943109 KL_div:0.0594581663608551 current_lr:0.1 Time taken per iteration: 0.005006074905395508
# Step: 1090 Loss: 0.001756552723236382 KL_div:0.05945776775479317 current_lr:0.1 Time taken per iteration: 0.006071805953979492
# Step: 1100 Loss: 0.0017565885791555047 KL_div:0.059458427131175995 current_lr:0.1 Time taken per iteration: 0.006272554397583008
# Step: 1110 Loss: 0.001756496261805296 KL_div:0.059456825256347656 current_lr:0.1 Time taken per iteration: 0.006595611572265625
# Step: 1120 Loss: 0.0017565712332725525 KL_div:0.05945806950330734 current_lr:0.1 Time taken per iteration: 0.00557398796081543
# Step: 1130 Loss: 0.001756551442667842 KL_div:0.059457793831825256 current_lr:0.1 Time taken per iteration: 0.007662773132324219
# Step: 1140 Loss: 0.0017565428279340267 KL_div:0.05945762246847153 current_lr:0.1 Time taken per iteration: 0.006242275238037109
# Step: 1150 Loss: 0.0017565647140145302 KL_div:0.05945798009634018 current_lr:0.1 Time taken per iteration: 0.004172086715698242
# Step: 1160 Loss: 0.001756561454385519 KL_div:0.059457942843437195 current_lr:0.1 Time taken per iteration: 0.005144357681274414
# Step: 1170 Loss: 0.0017565551679581404 KL_div:0.05945777893066406 current_lr:0.1 Time taken per iteration: 0.005120277404785156
# Step: 1180 Loss: 0.001756599172949791 KL_div:0.05945861339569092 current_lr:0.1 Time taken per iteration: 0.004209756851196289
# Step: 1190 Loss: 0.001756554702296853 KL_div:0.05945766717195511 current_lr:0.1 Time taken per iteration: 0.006459951400756836
# Step: 1200 Loss: 0.00175651500467211 KL_div:0.059456609189510345 current_lr:0.1 Time taken per iteration: 0.0051422119140625
# Step: 1210 Loss: 0.001756589044816792 KL_div:0.059453196823596954 current_lr:0.1 Time taken per iteration: 0.005702018737792969
# Step: 1220 Loss: 0.001762922154739499 KL_div:0.05945900082588196 current_lr:0.1 Time taken per iteration: 0.007286548614501953
# Step: 1230 Loss: 0.0017785187810659409 KL_div:0.059761688113212585 current_lr:0.1 Time taken per iteration: 0.007517814636230469
# Step: 1480 Loss: 0.0017565248999744654 KL_div:0.059457696974277496 current_lr:0.1 Time taken per iteration: 0.011667013168334961
# Step: 1490 Loss: 0.0017565328162163496 KL_div:0.059457313269376755 current_lr:0.1 Time taken per iteration: 0.005019426345825195
# Step: 1500 Loss: 0.0017566157039254904 KL_div:0.059458740055561066 current_lr:0.1 Time taken per iteration: 0.00503849983215332
# Step: 1510 Loss: 0.0017565290909260511 KL_div:0.05945724993944168 current_lr:0.1 Time taken per iteration: 0.003825664520263672
# Step: 1520 Loss: 0.0017565693706274033 KL_div:0.059458062052726746 current_lr:0.1 Time taken per iteration: 0.0036897659301757812
# Step: 1530 Loss: 0.0017565670423209667 KL_div:0.05945805087685585 current_lr:0.1 Time taken per iteration: 0.0070095062255859375
# Step: 1540 Loss: 0.0017565429443493485 KL_div:0.059457652270793915 current_lr:0.1 Time taken per iteration: 0.004781484603881836
# Step: 1550 Loss: 0.0017565444577485323 KL_div:0.05945766717195511 current_lr:0.1 Time taken per iteration: 0.007723808288574219
# Step: 1560 Loss: 0.00175655004568398 KL_div:0.059457775205373764 current_lr:0.1 Time taken per iteration: 0.0038902759552001953
# Step: 1570 Loss: 0.0017565378220751882 KL_div:0.05945760756731033 current_lr:0.1 Time taken per iteration: 0.004426717758178711
# Step: 1580 Loss: 0.001756552723236382 KL_div:0.05945788323879242 current_lr:0.1 Time taken per iteration: 0.006731510162353516
# Step: 1590 Loss: 0.001756521174684167 KL_div:0.05945757403969765 current_lr:0.1 Time taken per iteration: 0.01147007942199707
# Step: 1600 Loss: 0.0017565551679581404 KL_div:0.05946061760187149 current_lr:0.1 Time taken per iteration: 0.004171133041381836
# Step: 1610 Loss: 0.0017573297955095768 KL_div:0.05950121209025383 current_lr:0.1 Time taken per iteration: 0.0050737857818603516
# Step: 1620 Loss: 0.0018819948891177773 KL_div:0.06133095920085907 current_lr:0.1 Time taken per iteration: 0.008390188217163086
# Step: 1630 Loss: 0.0017573634395375848 KL_div:0.05950813740491867 current_lr:0.1 Time taken per iteration: 0.004138946533203125
# Step: 1640 Loss: 0.0017684429185464978 KL_div:0.05970245227217674 current_lr:0.1 Time taken per iteration: 0.004785060882568359
# Step: 1650 Loss: 0.001756621291860938 KL_div:0.059470050036907196 current_lr:0.1 Time taken per iteration: 0.005795955657958984
# Step: 1660 Loss: 0.001757918973453343 KL_div:0.059437476098537445 current_lr:0.1 Time taken per iteration: 0.0063571929931640625
# Step: 1670 Loss: 0.0017568429466336966 KL_div:0.05947202444076538 current_lr:0.1 Time taken per iteration: 0.005133152008056641
# Step: 1680 Loss: 0.0017565812449902296 KL_div:0.05946812406182289 current_lr:0.1 Time taken per iteration: 0.003977775573730469
# Step: 1690 Loss: 0.0017566138412803411 KL_div:0.05944747477769852 current_lr:0.1 Time taken per iteration: 0.011995315551757812
# Step: 1700 Loss: 0.00175659719388932 KL_div:0.05945931002497673 current_lr:0.1 Time taken per iteration: 0.003911018371582031
# Step: 1710 Loss: 0.0017565597081556916 KL_div:0.05946067348122597 current_lr:0.1 Time taken per iteration: 0.003866910934448242
# Step: 1720 Loss: 0.001756573561578989 KL_div:0.059458158910274506 current_lr:0.1 Time taken per iteration: 0.005086660385131836
# Step: 1730 Loss: 0.001756552024744451 KL_div:0.0594569556415081 current_lr:0.1 Time taken per iteration: 0.0058650970458984375
# Step: 1740 Loss: 0.0017565401503816247 KL_div:0.059457242488861084 current_lr:0.1 Time taken per iteration: 0.004492521286010742
# Step: 1750 Loss: 0.0017565740272402763 KL_div:0.059458956122398376 current_lr:0.1 Time taken per iteration: 0.00523829460144043
# Step: 1760 Loss: 0.0017565530724823475 KL_div:0.05946442112326622 current_lr:0.1 Time taken per iteration: 0.005188465118408203
# Step: 1770 Loss: 0.0017584851011633873 KL_div:0.05956355109810829 current_lr:0.1 Time taken per iteration: 0.004441976547241211
# Step: 1780 Loss: 0.001768179121427238 KL_div:0.059853702783584595 current_lr:0.1 Time taken per iteration: 0.006712675094604492
# Step: 1790 Loss: 0.0017597199184820056 KL_div:0.05954501032829285 current_lr:0.1 Time taken per iteration: 0.004220247268676758
# Step: 1800 Loss: 0.0017577387625351548 KL_div:0.05951307713985443 current_lr:0.1 Time taken per iteration: 0.006690502166748047
# Step: 1810 Loss: 0.0017570714699104428 KL_div:0.05949131399393082 current_lr:0.1 Time taken per iteration: 0.005053520202636719
# Step: 1820 Loss: 0.0017567324684932828 KL_div:0.05948295071721077 current_lr:0.1 Time taken per iteration: 0.0037660598754882812
# Step: 1830 Loss: 0.0017566039459779859 KL_div:0.059460535645484924 current_lr:0.1 Time taken per iteration: 0.0053555965423583984
# Step: 1840 Loss: 0.0017565864836797118 KL_div:0.05946735292673111 current_lr:0.1 Time taken per iteration: 0.004873037338256836
# Step: 1850 Loss: 0.0017565697198733687 KL_div:0.05945539101958275 current_lr:0.1 Time taken per iteration: 0.004644632339477539
# Step: 1860 Loss: 0.00175657297950238 KL_div:0.059456683695316315 current_lr:0.1 Time taken per iteration: 0.005429744720458984
# Step: 1870 Loss: 0.0017565290909260511 KL_div:0.05945579335093498 current_lr:0.1 Time taken per iteration: 0.005836963653564453
# Step: 1880 Loss: 0.0017565288580954075 KL_div:0.05945858359336853 current_lr:0.1 Time taken per iteration: 0.006451606750488281
# Step: 1890 Loss: 0.0017565676243975759 KL_div:0.05945831537246704 current_lr:0.1 Time taken per iteration: 0.004018545150756836
# Step: 1900 Loss: 0.0017565687885507941 KL_div:0.059457674622535706 current_lr:0.1 Time taken per iteration: 0.004277706146240234
# Step: 1910 Loss: 0.0017565656453371048 KL_div:0.059458158910274506 current_lr:0.1 Time taken per iteration: 0.010411977767944336
# Step: 1920 Loss: 0.001756508368998766 KL_div:0.05945694446563721 current_lr:0.1 Time taken per iteration: 0.008302688598632812
# Step: 1930 Loss: 0.0017565422458574176 KL_div:0.05945762246847153 current_lr:0.1 Time taken per iteration: 0.004900455474853516
# Step: 1940 Loss: 0.001756544690579176 KL_div:0.05945761501789093 current_lr:0.1 Time taken per iteration: 0.007172584533691406
# Step: 1950 Loss: 0.0017565450398251414 KL_div:0.059457577764987946 current_lr:0.1 Time taken per iteration: 0.0052165985107421875
# Step: 1960 Loss: 0.001756503595970571 KL_div:0.059456974267959595 current_lr:0.1 Time taken per iteration: 0.006024837493896484
# Step: 1970 Loss: 0.001756541314534843 KL_div:0.05945760756731033 current_lr:0.1 Time taken per iteration: 0.0050394535064697266
# Step: 1980 Loss: 0.0017565087182447314 KL_div:0.05945703759789467 current_lr:0.1 Time taken per iteration: 0.00444340705871582
# Step: 1990 Loss: 0.0017565515590831637 KL_div:0.05945774167776108 current_lr:0.1 Time taken per iteration: 0.004755735397338867
# Step: 2000 Loss: 0.0017565099988132715 KL_div:0.05945681035518646 current_lr:0.1 Time taken per iteration: 0.013110876083374023

# %%
# import pickle

# #Save Checkpoint
# checkpoint = {"final_epoch":i,
#               "history":history,
#               "divs":divs,
#               "parameters":parameters}

# # with open(f'anticat_model_distribution_copy.pkl','wb') as file:
# with open(f'4qubit_cat_model_checkpoint.pkl','wb') as file:
#     pickle.dump(checkpoint,file)
    
# print("Model saved successfully")

# %%
fig, axs = plt.subplots(1,2,figsize=(15,8))
axs[0].plot(divs)
axs[0].title.set_text('KL Divergence')

axs[1].plot(history)
axs[1].title.set_text('loss')

# %%
optimal_params = parameters[np.argmin(divs)]
qcbm_probs = circuit(optimal_params)
x_full = jnp.arange(0,2**n_qubits,dtype=jnp.float64)

fig, axs = plt.subplots(1,2,figsize=(15,5))
axs[0].bar(x_full,qcbm_probs[0],color='green',alpha=0.5,label='Obtained Distribution')
axs[0].plot(x_full,target_distribution,color='blue',alpha=0.5,label='Target Distribution')
axs[0].legend()
axs[0].set_title('Obtained vs Target Distribution')
axs[0].set_xlabel('Hilbert Space')
axs[0].set_ylabel('Probability Distribution')

axs[1].plot(x_full,qcbm_probs[1],color='red',alpha=0.5,label='Obtained Distribution')
axs[1].legend()
axs[1].set_title('Obtained Anticat Distribution')
axs[1].set_xlabel('Hilbert Space')
axs[1].set_ylabel('Probability Distribution')
# Out:
# Text(0, 0.5, 'Probability Distribution')

# %%
x = jnp.arange(0,n_qubits+1,dtype=jnp.float64)

fig, axs = plt.subplots(1,2,figsize=(15,5))
particle_distribution1 = pnumber_distribution(qcbm_probs[0],n_qubits)
axs[0].bar(x,particle_distribution1,color='green',alpha=0.5,label='Obtained Distribution')
axs[0].set_title('Particle Number Distribution of Cat')
axs[0].set_xlabel('Particle Number')
axs[0].set_ylabel('Probability')

particle_distribution2 = pnumber_distribution(qcbm_probs[1],n_qubits)
axs[1].bar(x,particle_distribution2,color='green',alpha=0.5,label='Obtained Distribution')
axs[1].set_title('Particle Number Distribution of Anticat')
axs[1].set_xlabel('Particle Number')
axs[1].set_ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %%
print(f"The minimum KL divergence obtained with ancillas, no pretraining and local entanglement : {min(divs)} in {n_epochs} epochs")
# Out:
# The minimum KL divergence obtained with ancillas, no pretraining and local entanglement : 0.059388548135757446 in 2001 epochs

# %%
with open("/home/akashm/PROJECT/qcbm_hiwi/qcbm_project/cat_anticat/data/4qubit_trial_anticat_distribution.pkl", "wb") as f:
    pickle.dump(qcbm_probs[1], f)
    
print("Anticat distribution saved successfully")
# Out:
# Anticat distribution saved successfully
