# %%
from vqc_model_gaussian import *

from jax.lib import xla_bridge
jax.experimental.enable_x64()
print("JAX Backend:", xla_bridge.get_backend().platform)
# Out:
# JAX Backend: gpu

# %%
# Visualizing Original Cat Distribution
plt.plot(cat_data, label='Target Distribution')
plt.xlabel("Hilbert Space",fontsize=12)
plt.ylabel("Probability Distribution",fontsize=12)
plt.title("Gaussian Distribution",fontsize=14)
plt.legend()

# %%
# Visualizing Original AntiCat Distribution
plt.plot(anticat_data, label='Anticat Distribution')
plt.xlabel("Hilbert Space")
plt.ylabel("Probability Distribution")
plt.title("Anticat of Gaussian Distribution")
plt.legend()

# %%
qml.draw_mpl(circuit,device='default')(input_params=initial_params)
plt.show()

# %% [markdown]
# ### Cells to be run if the target_distribution corresponds to superposition of all half filled states

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations


# Number of qubits
num_qubits = 8

# Generate all binary states with exactly 4 ones
valid_states = ["".join("1" if i in comb else "0" for i in range(num_qubits)) 
                for comb in combinations(range(num_qubits), 4)]

# Convert binary states to decimal indices
valid_indices = [int(state, 2) for state in valid_states]

# Create target distribution
target_distribution = np.zeros(2**num_qubits)
for index in valid_indices:
    target_distribution[index] = 1  # Assign probability 1 to valid states

# Normalize the distribution
target_distribution /= np.sum(target_distribution)

# Plot the target distribution
plt.figure(figsize=(10, 5))
plt.plot(target_distribution, linestyle="-", label="Superposition of 4 Ones & 4 Zeros")
plt.xlabel("State Index")
plt.ylabel("Probability")
plt.title("Target Distribution for 4-Ones-4-Zeros Superposition")
plt.legend()
plt.show()

# %%
class MMD:
    def __init__(self,scales,space):
        gammas = 1/(2*(scales**2)).reshape(-1,1,1)
        sq_dists = jnp.abs(space[:,None] - space[None,:])**2
        self.K = jnp.sum(jnp.exp(-gammas * sq_dists), axis=0)/len(scales)
        self.scales = scales
        
    def k_expval(self,px,py):
        return px @ self.K @ py
    
    def __call__(self,px,py):
        pxy = px-py
        return self.k_expval(pxy,pxy)
    
class QCBM:
    def __init__(self,circ,mmd,py):
        self.circ = circ
        self.mmd = mmd
        self.py = py
    
    def mmd_loss(self,params):
        px = self.circ(params)
        loss = self.mmd(px,self.py)

        return loss, px
    

#Model Training
@jit
def update_step(params,opt_state):
    
    (total_loss_val,qcbm_probs), grads = jax.value_and_grad(qcbm.mmd_loss,has_aux=True)(params)

    updates,opt_state = opt.update(grads,opt_state)
    params = optax.apply_updates(params,updates)
    
    qcbm_probs = jnp.asarray(qcbm_probs, dtype=jnp.float64)
    
    kl_div = -jnp.sum(target_distribution * jnp.nan_to_num(jnp.log(qcbm_probs) - jnp.log(target_distribution)))
    
    total_kl_div = kl_div
    
    return params, opt_state, total_loss_val, total_kl_div

# %%
#Calling MMD class
bandwidth = jnp.array([0.25,60],dtype=jnp.float64)
space = jnp.arange(0,2**total_qubits,dtype=jnp.float64)
mmd = MMD(bandwidth,space=space)


#Calling QCBM class to run the previous built circuit with random weights
qcbm = QCBM(circuit,mmd=mmd,py=target_distribution)


#Initial parameters
weights = initial_params
lr = optax.exponential_decay(init_value=0.1,transition_steps=10,decay_rate=0.99,transition_begin=300,end_value=0.025,staircase=True)
# lr = 0.01
opt = optax.adam(learning_rate=lr)
opt_state = opt.init(weights)


history = []
divs = []
parameters = []


kl_div = 1
i = 0
# i = start_epoch

# while kl_div > 10^-3:
while i < 5001:
    i+=1
    current_lr = lr(i)
    # current_lr = lr
    start_time = time.time()
    weights, opt_state, loss_val, kl_div = update_step(params=weights,opt_state=opt_state)
    end_time = time.time()
    
    if i%10==0:
        print(f"Step: {i} Loss: {loss_val} KL_div:{kl_div} current_lr:{current_lr} Time taken per iteration: {end_time-start_time}")
    
    history.append(loss_val)
    divs.append(kl_div)
    parameters.append(weights)
# Out:
# ---------------------------------------------------------------------------
# TracerArrayConversionError                Traceback (most recent call last)
# Cell In[8], line 34
#      32 # current_lr = lr
#      33 start_time = time.time()
# ---> 34 weights, opt_state, loss_val, kl_div = update_step(params=weights,opt_state=opt_state)
#      35 end_time = time.time()
#      37 if i%10==0:
#
#     [... skipping hidden 13 frame]
#
# Cell In[7], line 32, in update_step(params, opt_state)
#      29 @jit
#      30 def update_step(params,opt_state):
# ---> 32     (total_loss_val,qcbm_probs), grads = jax.value_and_grad(qcbm.mmd_loss,has_aux=True)(params)
#      34     updates,opt_state = opt.update(grads,opt_state)
#      35     params = optax.apply_updates(params,updates)
#
#     [... skipping hidden 16 frame]
#
# Cell In[7], line 23, in QCBM.mmd_loss(self, params)
#      21 def mmd_loss(self,params):
#      22     px = self.circ(params)
# ---> 23     loss = self.mmd(px,self.py)
#      25     return loss, px
#
# Cell In[7], line 12, in MMD.__call__(self, px, py)
#      11 def __call__(self,px,py):
# ---> 12     pxy = px-py
#      13     return self.k_expval(pxy,pxy)
#
# File ~/mambaforge/envs/pennylane/lib/python3.12/site-packages/jax/_src/core.py:756, in Tracer.__array__(self, *args, **kw)
#     755 def __array__(self, *args, **kw):
# --> 756   raise TracerArrayConversionError(self)
#
# TracerArrayConversionError: The numpy.ndarray conversion method __array__() was called on traced array with shape float32[16]
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.TracerArrayConversionError

# %%
print(f"Minimum KL Divergence obtained is {np.min(divs)}")
# Out:
# Minimum KL Divergence obtained is 0.49561136960983276

# %%
fig, axs = plt.subplots(1,2,figsize=(15,8))
axs[0].plot(divs)
axs[0].title.set_text('KL Divergence')

axs[1].plot(history)
axs[1].title.set_text('loss')

# %%
optimal_params = parameters[np.argmin(divs)]

qcbm_probs = circuit(optimal_params)
x_array = jnp.arange(0,2**(total_qubits),dtype=jnp.float64)


plt.bar(x_array,qcbm_probs,color='green',alpha=0.5,label='Obtained Cat')
plt.plot(x_array,target_distribution,color='blue',alpha=0.5,label='Original Cat')
plt.xlabel("Hilbert Space")
plt.ylabel("Probability Distribution")
plt.title("Cat Distribution")
plt.legend()
plt.show()

# %% [markdown]
# ### Cells to be run if target_distribution is only 10101010

# %%
# import numpy as np

# Target binary pattern
target_binary = "10110100"

#Odd Numbered Qubits
target_binary1 = '0110'

#Even Numbered Qubits
target_binary2 = '1100'

# Convert binary to decimal index
target_index1 = int(target_binary1, 2)
target_index2 = int(target_binary2, 2)

# Create a one-hot encoded target distribution
num_qubits = 4
target_distribution1 = np.zeros(2**num_qubits)
target_distribution1[target_index1] = 1

target_distribution2 = np.zeros(2**num_qubits)
target_distribution2[target_index2] = 1

# plt.subplot(1, 2, 1)
plt.plot(target_distribution1)
# plt.plot(target_distribution2)

# %%
class MMD:
    def __init__(self,scales,space):
        gammas = 1/(2*(scales**2)).reshape(-1,1,1)
        sq_dists = jnp.abs(space[:,None] - space[None,:])**2
        self.K = jnp.sum(jnp.exp(-gammas * sq_dists), axis=0)/len(scales)
        self.scales = scales
        
    def k_expval(self,px,py):
        return px @ self.K @ py
    
    def __call__(self,px,py):
        pxy = px-py
        return self.k_expval(pxy,pxy)
    
class QCBM:
    def __init__(self,circ,mmd1,mmd2,py1,py2):
        self.circ = circ
        self.mmd1 = mmd1
        self.mmd2 = mmd2
        self.py1 = py1
        self.py2 = py2
    
    def mmd_loss(self,params):
        px = self.circ(params)
        loss1 = self.mmd1(px[0],self.py1)
        loss2 = self.mmd2(px[1],self.py2)
        
        return loss1+loss2, px
    

#Model Training
@jit
def update_step(params,opt_state):
    
    (total_loss_val,qcbm_probs), grads = jax.value_and_grad(qcbm.mmd_loss,has_aux=True)(params)

    updates,opt_state = opt.update(grads,opt_state)
    params = optax.apply_updates(params,updates)
    
    qcbm_probs1 = jnp.asarray(qcbm_probs[0], dtype=jnp.float64)
    qcbm_probs2 = jnp.asarray(qcbm_probs[1], dtype=jnp.float64)
    
    kl_div1 = -jnp.sum(target_distribution1 * jnp.nan_to_num(jnp.log(qcbm_probs1) - jnp.log(target_distribution1)))
    kl_div2 = -jnp.sum(target_distribution2 * jnp.nan_to_num(jnp.log(qcbm_probs2) - jnp.log(target_distribution2)))
    
    total_kl_div = kl_div1 + kl_div2
    
    return params, opt_state, total_loss_val, total_kl_div

# %%
#Calling MMD class
bandwidth = jnp.array([0.25,60],dtype=jnp.float64)
space = jnp.arange(0,2**n_qubits,dtype=jnp.float64)
mmd1 = MMD(bandwidth,space=space)
mmd2 = MMD(bandwidth,space=space)


#Calling QCBM class to run the previous built circuit with random weights
qcbm = QCBM(circuit,mmd1=mmd1,mmd2=mmd2,py1=target_distribution1,py2=target_distribution2)


#Initial parameters
weights = initial_params
# lr = optax.exponential_decay(init_value=0.1,transition_steps=10,decay_rate=0.99,transition_begin=300,end_value=0.005,staircase=True)
lr = 0.01
opt = optax.adam(learning_rate=lr)
opt_state = opt.init(weights)


history = []
divs = []
parameters = []


kl_div = 1
i = 0
# i = start_epoch

# while kl_div > 10^-3:
while i < 5001:
    i+=1
    # current_lr = lr(i)
    current_lr = lr
    start_time = time.time()
    weights, opt_state, loss_val, kl_div = update_step(params=weights,opt_state=opt_state)
    end_time = time.time()
    
    if i%10==0:
        print(f"Step: {i} Loss: {loss_val} KL_div:{kl_div} current_lr:{current_lr} Time taken per iteration: {end_time-start_time}")
    
    history.append(loss_val)
    divs.append(kl_div)
    parameters.append(weights)
# Out:
# Step: 10 Loss: 0.779204249382019 KL_div:4.202237129211426 current_lr:0.01 Time taken per iteration: 0.028098583221435547
# Step: 20 Loss: 0.6427479386329651 KL_div:3.102839469909668 current_lr:0.01 Time taken per iteration: 0.0040891170501708984
# Step: 30 Loss: 0.5095099210739136 KL_div:2.304790735244751 current_lr:0.01 Time taken per iteration: 0.004076242446899414
# Step: 40 Loss: 0.41291487216949463 KL_div:1.8726933002471924 current_lr:0.01 Time taken per iteration: 0.004374504089355469
# Step: 50 Loss: 0.3328792154788971 KL_div:1.5512014627456665 current_lr:0.01 Time taken per iteration: 0.005232334136962891
# Step: 60 Loss: 0.2740705609321594 KL_div:1.3220839500427246 current_lr:0.01 Time taken per iteration: 0.0043523311614990234
# Step: 70 Loss: 0.23930302262306213 KL_div:1.181136131286621 current_lr:0.01 Time taken per iteration: 0.007773876190185547
# Step: 80 Loss: 0.21187162399291992 KL_div:1.0686962604522705 current_lr:0.01 Time taken per iteration: 0.0052394866943359375
# Step: 90 Loss: 0.19091427326202393 KL_div:0.9856767058372498 current_lr:0.01 Time taken per iteration: 0.005658149719238281
# Step: 100 Loss: 0.17235903441905975 KL_div:0.9153136014938354 current_lr:0.01 Time taken per iteration: 0.010166168212890625
# Step: 110 Loss: 0.156714528799057 KL_div:0.8546657562255859 current_lr:0.01 Time taken per iteration: 0.007632017135620117
# Step: 120 Loss: 0.14624370634555817 KL_div:0.8127723932266235 current_lr:0.01 Time taken per iteration: 0.016367435455322266
# Step: 130 Loss: 0.13867391645908356 KL_div:0.7857533693313599 current_lr:0.01 Time taken per iteration: 0.0069713592529296875
# Step: 140 Loss: 0.13192689418792725 KL_div:0.7665911912918091 current_lr:0.01 Time taken per iteration: 0.010262012481689453
# Step: 150 Loss: 0.1260451376438141 KL_div:0.7520643472671509 current_lr:0.01 Time taken per iteration: 0.01127934455871582
# Step: 160 Loss: 0.12115254998207092 KL_div:0.7391388416290283 current_lr:0.01 Time taken per iteration: 0.004389286041259766
# Step: 170 Loss: 0.11697041243314743 KL_div:0.7260072231292725 current_lr:0.01 Time taken per iteration: 0.013114213943481445
# Step: 180 Loss: 0.11305113136768341 KL_div:0.7119256258010864 current_lr:0.01 Time taken per iteration: 0.010111570358276367
# Step: 190 Loss: 0.1089877039194107 KL_div:0.6962363123893738 current_lr:0.01 Time taken per iteration: 0.006507396697998047
# Step: 200 Loss: 0.10444647818803787 KL_div:0.6781139373779297 current_lr:0.01 Time taken per iteration: 0.009745121002197266
# Step: 210 Loss: 0.09918075799942017 KL_div:0.6567668318748474 current_lr:0.01 Time taken per iteration: 0.006560087203979492
# Step: 220 Loss: 0.09310445189476013 KL_div:0.6317814588546753 current_lr:0.01 Time taken per iteration: 0.007154703140258789
# Step: 230 Loss: 0.08640839159488678 KL_div:0.6036576628684998 current_lr:0.01 Time taken per iteration: 0.0045757293701171875
# Step: 240 Loss: 0.07960417121648788 KL_div:0.5741688013076782 current_lr:0.01 Time taken per iteration: 0.005400657653808594
# Step: 250 Loss: 0.07339738309383392 KL_div:0.5461491346359253 current_lr:0.01 Time taken per iteration: 0.009357929229736328
# Step: 260 Loss: 0.06839063763618469 KL_div:0.5224398970603943 current_lr:0.01 Time taken per iteration: 0.009320974349975586
# Step: 270 Loss: 0.06482351571321487 KL_div:0.5046327710151672 current_lr:0.01 Time taken per iteration: 0.0051424503326416016
# Step: 280 Loss: 0.0625411719083786 KL_div:0.49258220195770264 current_lr:0.01 Time taken per iteration: 0.012041091918945312
# Step: 290 Loss: 0.06117244064807892 KL_div:0.48493993282318115 current_lr:0.01 Time taken per iteration: 0.006254911422729492
# Step: 300 Loss: 0.06034614518284798 KL_div:0.4801051616668701 current_lr:0.01 Time taken per iteration: 0.009591341018676758
# Step: 310 Loss: 0.05980316177010536 KL_div:0.4768425226211548 current_lr:0.01 Time taken per iteration: 0.011913776397705078
# Step: 320 Loss: 0.059400759637355804 KL_div:0.4744088053703308 current_lr:0.01 Time taken per iteration: 0.0063114166259765625
# Step: 330 Loss: 0.059070587158203125 KL_div:0.4724085330963135 current_lr:0.01 Time taken per iteration: 0.006594419479370117
# Step: 340 Loss: 0.05878382921218872 KL_div:0.4706566333770752 current_lr:0.01 Time taken per iteration: 0.00796055793762207
# Step: 350 Loss: 0.058525875210762024 KL_div:0.4690524935722351 current_lr:0.01 Time taken per iteration: 0.0040247440338134766
# Step: 360 Loss: 0.05829137936234474 KL_div:0.46756109595298767 current_lr:0.01 Time taken per iteration: 0.005510568618774414
# Step: 370 Loss: 0.05807557702064514 KL_div:0.46615615487098694 current_lr:0.01 Time taken per iteration: 0.004256010055541992
# Step: 380 Loss: 0.05787576735019684 KL_div:0.4648275077342987 current_lr:0.01 Time taken per iteration: 0.007824897766113281
# Step: 390 Loss: 0.057688627392053604 KL_div:0.4635612964630127 current_lr:0.01 Time taken per iteration: 0.009754180908203125
# Step: 400 Loss: 0.05751243978738785 KL_div:0.4623534679412842 current_lr:0.01 Time taken per iteration: 0.009372472763061523
# Step: 410 Loss: 0.057344645261764526 KL_div:0.46119239926338196 current_lr:0.01 Time taken per iteration: 0.009954690933227539
# Step: 420 Loss: 0.05718357861042023 KL_div:0.4600713551044464 current_lr:0.01 Time taken per iteration: 0.008931636810302734
# Step: 430 Loss: 0.05702739208936691 KL_div:0.45898115634918213 current_lr:0.01 Time taken per iteration: 0.012060403823852539
# Step: 440 Loss: 0.05687475949525833 KL_div:0.4579150974750519 current_lr:0.01 Time taken per iteration: 0.010320663452148438
# Step: 450 Loss: 0.05672512203454971 KL_div:0.4568713307380676 current_lr:0.01 Time taken per iteration: 0.02339029312133789
# Step: 460 Loss: 0.056577231734991074 KL_div:0.4558429419994354 current_lr:0.01 Time taken per iteration: 0.008308172225952148
# Step: 470 Loss: 0.05643080174922943 KL_div:0.4548284709453583 current_lr:0.01 Time taken per iteration: 0.010359525680541992
# Step: 480 Loss: 0.056285466998815536 KL_div:0.45382651686668396 current_lr:0.01 Time taken per iteration: 0.007488250732421875
# Step: 490 Loss: 0.05614057928323746 KL_div:0.45283302664756775 current_lr:0.01 Time taken per iteration: 0.00838327407836914
# Step: 500 Loss: 0.05599682405591011 KL_div:0.4518529772758484 current_lr:0.01 Time taken per iteration: 0.009115457534790039
# Step: 510 Loss: 0.055853720754384995 KL_div:0.45088285207748413 current_lr:0.01 Time taken per iteration: 0.009175777435302734
# Step: 520 Loss: 0.0557117685675621 KL_div:0.4499264359474182 current_lr:0.01 Time taken per iteration: 0.010643720626831055
# Step: 530 Loss: 0.05557076632976532 KL_div:0.4489818215370178 current_lr:0.01 Time taken per iteration: 0.015944480895996094
# Step: 540 Loss: 0.05543188005685806 KL_div:0.4480569362640381 current_lr:0.01 Time taken per iteration: 0.011548519134521484
# Step: 550 Loss: 0.055295057594776154 KL_div:0.44715094566345215 current_lr:0.01 Time taken per iteration: 0.010010957717895508
# Step: 560 Loss: 0.05516105890274048 KL_div:0.4462687075138092 current_lr:0.01 Time taken per iteration: 0.011719226837158203
# Step: 570 Loss: 0.05502989888191223 KL_div:0.44540995359420776 current_lr:0.01 Time taken per iteration: 0.010444402694702148
# Step: 580 Loss: 0.05490255728363991 KL_div:0.4445808231830597 current_lr:0.01 Time taken per iteration: 0.01062631607055664
# Step: 590 Loss: 0.05477939546108246 KL_div:0.44378331303596497 current_lr:0.01 Time taken per iteration: 0.01771712303161621
# Step: 600 Loss: 0.05466112494468689 KL_div:0.4430221617221832 current_lr:0.01 Time taken per iteration: 0.014220237731933594
# Step: 610 Loss: 0.0545479878783226 KL_div:0.4422982931137085 current_lr:0.01 Time taken per iteration: 0.008956432342529297
# Step: 620 Loss: 0.05444048345088959 KL_div:0.44161468744277954 current_lr:0.01 Time taken per iteration: 0.011368036270141602
# Step: 630 Loss: 0.05433845520019531 KL_div:0.4409700930118561 current_lr:0.01 Time taken per iteration: 0.0053250789642333984
# Step: 640 Loss: 0.05424289032816887 KL_div:0.44037073850631714 current_lr:0.01 Time taken per iteration: 0.012573003768920898
# Step: 650 Loss: 0.05415327101945877 KL_div:0.43981289863586426 current_lr:0.01 Time taken per iteration: 0.005297660827636719
# Step: 660 Loss: 0.05406981706619263 KL_div:0.4392976760864258 current_lr:0.01 Time taken per iteration: 0.008422136306762695
# Step: 670 Loss: 0.05399252474308014 KL_div:0.4388248026371002 current_lr:0.01 Time taken per iteration: 0.006748199462890625
# Step: 680 Loss: 0.053920961916446686 KL_div:0.43839091062545776 current_lr:0.01 Time taken per iteration: 0.011968374252319336
# Step: 690 Loss: 0.053855277597904205 KL_div:0.43799689412117004 current_lr:0.01 Time taken per iteration: 0.00654911994934082
# Step: 700 Loss: 0.05379509925842285 KL_div:0.43763983249664307 current_lr:0.01 Time taken per iteration: 0.006381034851074219
# Step: 710 Loss: 0.053740184754133224 KL_div:0.43731778860092163 current_lr:0.01 Time taken per iteration: 0.010386943817138672
# Step: 720 Loss: 0.05369006097316742 KL_div:0.43702733516693115 current_lr:0.01 Time taken per iteration: 0.004509925842285156
# Step: 730 Loss: 0.05364459380507469 KL_div:0.4367671012878418 current_lr:0.01 Time taken per iteration: 0.013562202453613281
# Step: 740 Loss: 0.0536031499505043 KL_div:0.43653273582458496 current_lr:0.01 Time taken per iteration: 0.010766267776489258
# Step: 750 Loss: 0.053565990179777145 KL_div:0.4363258481025696 current_lr:0.01 Time taken per iteration: 0.010359525680541992
# Step: 760 Loss: 0.05353214219212532 KL_div:0.43613940477371216 current_lr:0.01 Time taken per iteration: 0.010293722152709961
# Step: 770 Loss: 0.05350155383348465 KL_div:0.435973197221756 current_lr:0.01 Time taken per iteration: 0.008336544036865234
# Step: 780 Loss: 0.05347424000501633 KL_div:0.43582725524902344 current_lr:0.01 Time taken per iteration: 0.010157585144042969
# Step: 790 Loss: 0.053449489176273346 KL_div:0.43569618463516235 current_lr:0.01 Time taken per iteration: 0.004702091217041016
# Step: 800 Loss: 0.05342714488506317 KL_div:0.4355792999267578 current_lr:0.01 Time taken per iteration: 0.012307167053222656
# Step: 810 Loss: 0.05340704694390297 KL_div:0.4354757070541382 current_lr:0.01 Time taken per iteration: 0.009868621826171875
# Step: 820 Loss: 0.053388793021440506 KL_div:0.43538227677345276 current_lr:0.01 Time taken per iteration: 0.003818988800048828
# Step: 830 Loss: 0.05337235704064369 KL_div:0.435299277305603 current_lr:0.01 Time taken per iteration: 0.008517026901245117
# Step: 840 Loss: 0.05335736274719238 KL_div:0.43522390723228455 current_lr:0.01 Time taken per iteration: 0.005580425262451172
# Step: 850 Loss: 0.05334409326314926 KL_div:0.43515831232070923 current_lr:0.01 Time taken per iteration: 0.007422685623168945
# Step: 860 Loss: 0.05333174392580986 KL_div:0.435097336769104 current_lr:0.01 Time taken per iteration: 0.008933544158935547
# Step: 870 Loss: 0.053320422768592834 KL_div:0.435041606426239 current_lr:0.01 Time taken per iteration: 0.010014772415161133
# Step: 880 Loss: 0.05331038683652878 KL_div:0.43499279022216797 current_lr:0.01 Time taken per iteration: 0.009063720703125
# Step: 890 Loss: 0.05330100655555725 KL_div:0.43494707345962524 current_lr:0.01 Time taken per iteration: 0.009203195571899414
# Step: 900 Loss: 0.05329196900129318 KL_div:0.4349020719528198 current_lr:0.01 Time taken per iteration: 0.010030031204223633
# Step: 910 Loss: 0.05328381806612015 KL_div:0.43486201763153076 current_lr:0.01 Time taken per iteration: 0.0075147151947021484
# Step: 920 Loss: 0.05327615886926651 KL_div:0.4348238408565521 current_lr:0.01 Time taken per iteration: 0.011605501174926758
# Step: 930 Loss: 0.05326904356479645 KL_div:0.43478816747665405 current_lr:0.01 Time taken per iteration: 0.009544849395751953
# Step: 940 Loss: 0.05326220393180847 KL_div:0.4347532093524933 current_lr:0.01 Time taken per iteration: 0.008870363235473633
# Step: 950 Loss: 0.053256042301654816 KL_div:0.43472176790237427 current_lr:0.01 Time taken per iteration: 0.010833978652954102
# Step: 960 Loss: 0.05324971675872803 KL_div:0.4346882104873657 current_lr:0.01 Time taken per iteration: 0.012757539749145508
# Step: 970 Loss: 0.05324403941631317 KL_div:0.43465808033943176 current_lr:0.01 Time taken per iteration: 0.010116338729858398
# Step: 980 Loss: 0.053238220512866974 KL_div:0.4346260726451874 current_lr:0.01 Time taken per iteration: 0.008717060089111328
# Step: 990 Loss: 0.05323248729109764 KL_div:0.43459373712539673 current_lr:0.01 Time taken per iteration: 0.008231163024902344
# Step: 1000 Loss: 0.05322742462158203 KL_div:0.43456506729125977 current_lr:0.01 Time taken per iteration: 0.008247613906860352
# Step: 1010 Loss: 0.053222253918647766 KL_div:0.43453478813171387 current_lr:0.01 Time taken per iteration: 0.010120153427124023
# Step: 1020 Loss: 0.05321744084358215 KL_div:0.4345061779022217 current_lr:0.01 Time taken per iteration: 0.011364221572875977
# Step: 1030 Loss: 0.053212471306324005 KL_div:0.4344756603240967 current_lr:0.01 Time taken per iteration: 0.009318828582763672
# Step: 1040 Loss: 0.053207673132419586 KL_div:0.4344455599784851 current_lr:0.01 Time taken per iteration: 0.009840726852416992
# Step: 1050 Loss: 0.0532030388712883 KL_div:0.4344157576560974 current_lr:0.01 Time taken per iteration: 0.00866246223449707
# Step: 1060 Loss: 0.05319811403751373 KL_div:0.43438321352005005 current_lr:0.01 Time taken per iteration: 0.008661270141601562
# Step: 1070 Loss: 0.05319364368915558 KL_div:0.434353232383728 current_lr:0.01 Time taken per iteration: 0.02188396453857422
# Step: 1080 Loss: 0.053189292550086975 KL_div:0.4343233108520508 current_lr:0.01 Time taken per iteration: 0.009192705154418945
# Step: 1090 Loss: 0.05318465083837509 KL_div:0.4342906177043915 current_lr:0.01 Time taken per iteration: 0.007962226867675781
# Step: 1100 Loss: 0.053180381655693054 KL_div:0.434259831905365 current_lr:0.01 Time taken per iteration: 0.0074329376220703125
# Step: 1110 Loss: 0.05317576974630356 KL_div:0.4342261254787445 current_lr:0.01 Time taken per iteration: 0.010993003845214844
# Step: 1120 Loss: 0.05317160487174988 KL_div:0.4341946244239807 current_lr:0.01 Time taken per iteration: 0.01121377944946289
# Step: 1130 Loss: 0.05316704511642456 KL_div:0.4341598153114319 current_lr:0.01 Time taken per iteration: 0.009044408798217773
# Step: 1140 Loss: 0.05316311866044998 KL_div:0.4341288208961487 current_lr:0.01 Time taken per iteration: 0.003518342971801758
# Step: 1150 Loss: 0.05315861850976944 KL_div:0.43409329652786255 current_lr:0.01 Time taken per iteration: 0.003945112228393555
# Step: 1160 Loss: 0.053154636174440384 KL_div:0.43406063318252563 current_lr:0.01 Time taken per iteration: 0.005635738372802734
# Step: 1170 Loss: 0.05315035954117775 KL_div:0.4340253472328186 current_lr:0.01 Time taken per iteration: 0.004889965057373047
# Step: 1180 Loss: 0.05314633250236511 KL_div:0.4339912533760071 current_lr:0.01 Time taken per iteration: 0.007528781890869141
# Step: 1190 Loss: 0.053141944110393524 KL_div:0.43395426869392395 current_lr:0.01 Time taken per iteration: 0.005011558532714844
# Step: 1200 Loss: 0.0531378909945488 KL_div:0.433918833732605 current_lr:0.01 Time taken per iteration: 0.006353616714477539
# Step: 1210 Loss: 0.053133752197027206 KL_div:0.43388229608535767 current_lr:0.01 Time taken per iteration: 0.004280805587768555
# Step: 1220 Loss: 0.05312977731227875 KL_div:0.4338466227054596 current_lr:0.01 Time taken per iteration: 0.005617618560791016
# Step: 1230 Loss: 0.05312573164701462 KL_div:0.43380966782569885 current_lr:0.01 Time taken per iteration: 0.004401683807373047
# Step: 1240 Loss: 0.05312170833349228 KL_div:0.43377256393432617 current_lr:0.01 Time taken per iteration: 0.0050470829010009766
# Step: 1250 Loss: 0.05311768501996994 KL_div:0.43373486399650574 current_lr:0.01 Time taken per iteration: 0.012528419494628906
# Step: 1260 Loss: 0.05311354994773865 KL_div:0.433695912361145 current_lr:0.01 Time taken per iteration: 0.005101919174194336
# Step: 1270 Loss: 0.053109508007764816 KL_div:0.4336572289466858 current_lr:0.01 Time taken per iteration: 0.0076444149017333984
# Step: 1280 Loss: 0.053105682134628296 KL_div:0.4336196184158325 current_lr:0.01 Time taken per iteration: 0.005713939666748047
# Step: 1290 Loss: 0.05310148745775223 KL_div:0.4335789084434509 current_lr:0.01 Time taken per iteration: 0.005330562591552734
# Step: 1300 Loss: 0.05309754237532616 KL_div:0.4335395395755768 current_lr:0.01 Time taken per iteration: 0.007515907287597656
# Step: 1310 Loss: 0.053093697875738144 KL_div:0.4335007071495056 current_lr:0.01 Time taken per iteration: 0.007264137268066406
# Step: 1320 Loss: 0.053089529275894165 KL_div:0.4334588944911957 current_lr:0.01 Time taken per iteration: 0.008219480514526367
# Step: 1330 Loss: 0.05308576673269272 KL_div:0.43341976404190063 current_lr:0.01 Time taken per iteration: 0.0034623146057128906
# Step: 1340 Loss: 0.05308148264884949 KL_div:0.43337661027908325 current_lr:0.01 Time taken per iteration: 0.0037140846252441406
# Step: 1350 Loss: 0.0530775785446167 KL_div:0.4333357810974121 current_lr:0.01 Time taken per iteration: 0.003912687301635742
# Step: 1360 Loss: 0.05307356268167496 KL_div:0.43329378962516785 current_lr:0.01 Time taken per iteration: 0.006714820861816406
# Step: 1370 Loss: 0.05306980758905411 KL_div:0.4332531690597534 current_lr:0.01 Time taken per iteration: 0.005507469177246094
# Step: 1380 Loss: 0.05306578055024147 KL_div:0.4332105815410614 current_lr:0.01 Time taken per iteration: 0.024378061294555664
# Step: 1390 Loss: 0.05306196212768555 KL_div:0.4331689476966858 current_lr:0.01 Time taken per iteration: 0.008373498916625977
# Step: 1400 Loss: 0.0530577227473259 KL_div:0.4331243634223938 current_lr:0.01 Time taken per iteration: 0.010223627090454102
# Step: 1410 Loss: 0.053053878247737885 KL_div:0.4330819845199585 current_lr:0.01 Time taken per iteration: 0.008356094360351562
# Step: 1420 Loss: 0.05305007845163345 KL_div:0.43303990364074707 current_lr:0.01 Time taken per iteration: 0.009104013442993164
# Step: 1430 Loss: 0.05304621160030365 KL_div:0.4329967796802521 current_lr:0.01 Time taken per iteration: 0.008703470230102539
# Step: 1440 Loss: 0.05304219573736191 KL_div:0.4329525828361511 current_lr:0.01 Time taken per iteration: 0.016508817672729492
# Step: 1450 Loss: 0.05303838104009628 KL_div:0.4329095184803009 current_lr:0.01 Time taken per iteration: 0.011774063110351562
# Step: 1460 Loss: 0.05303439497947693 KL_div:0.4328649938106537 current_lr:0.01 Time taken per iteration: 0.010148048400878906
# Step: 1470 Loss: 0.05303047224879265 KL_div:0.43282070755958557 current_lr:0.01 Time taken per iteration: 0.010622739791870117
# Step: 1480 Loss: 0.05302620306611061 KL_div:0.4327738285064697 current_lr:0.01 Time taken per iteration: 0.01299285888671875
# Step: 1490 Loss: 0.05302256718277931 KL_div:0.43273115158081055 current_lr:0.01 Time taken per iteration: 0.010133981704711914
# Step: 1500 Loss: 0.05301884561777115 KL_div:0.4326877295970917 current_lr:0.01 Time taken per iteration: 0.010576248168945312
# Step: 1510 Loss: 0.05301523581147194 KL_div:0.432644784450531 current_lr:0.01 Time taken per iteration: 0.010246515274047852
# Step: 1520 Loss: 0.0530109778046608 KL_div:0.432597279548645 current_lr:0.01 Time taken per iteration: 0.010189533233642578
# Step: 1530 Loss: 0.0530070960521698 KL_div:0.4325522482395172 current_lr:0.01 Time taken per iteration: 0.009653329849243164
# Step: 1540 Loss: 0.05300343409180641 KL_div:0.4325082302093506 current_lr:0.01 Time taken per iteration: 0.009629487991333008
# Step: 1550 Loss: 0.05299960821866989 KL_div:0.4324634075164795 current_lr:0.01 Time taken per iteration: 0.011106729507446289
# Step: 1560 Loss: 0.05299591273069382 KL_div:0.4324190318584442 current_lr:0.01 Time taken per iteration: 0.009665489196777344
# Step: 1570 Loss: 0.052991800010204315 KL_div:0.43237176537513733 current_lr:0.01 Time taken per iteration: 0.0095672607421875
# Step: 1580 Loss: 0.052988264709711075 KL_div:0.4323281943798065 current_lr:0.01 Time taken per iteration: 0.009083271026611328
# Step: 1590 Loss: 0.052984632551670074 KL_div:0.43228402733802795 current_lr:0.01 Time taken per iteration: 0.009184598922729492
# Step: 1600 Loss: 0.052980829030275345 KL_div:0.43223845958709717 current_lr:0.01 Time taken per iteration: 0.015311956405639648
# Step: 1610 Loss: 0.05297701060771942 KL_div:0.4321926236152649 current_lr:0.01 Time taken per iteration: 0.008685827255249023
# Step: 1620 Loss: 0.05297360569238663 KL_div:0.43214964866638184 current_lr:0.01 Time taken per iteration: 0.009129047393798828
# Step: 1630 Loss: 0.05296987295150757 KL_div:0.43210428953170776 current_lr:0.01 Time taken per iteration: 0.008819818496704102
# Step: 1640 Loss: 0.05296614393591881 KL_div:0.4320589303970337 current_lr:0.01 Time taken per iteration: 0.00802469253540039
# Step: 1650 Loss: 0.052962735295295715 KL_div:0.43201568722724915 current_lr:0.01 Time taken per iteration: 0.00973963737487793
# Step: 1660 Loss: 0.05295927822589874 KL_div:0.43197202682495117 current_lr:0.01 Time taken per iteration: 0.009943723678588867
# Step: 1670 Loss: 0.052955709397792816 KL_div:0.4319273829460144 current_lr:0.01 Time taken per iteration: 0.009287595748901367
# Step: 1680 Loss: 0.05295208841562271 KL_div:0.43188250064849854 current_lr:0.01 Time taken per iteration: 0.006962299346923828
# Step: 1690 Loss: 0.0529487207531929 KL_div:0.43183934688568115 current_lr:0.01 Time taken per iteration: 0.023138046264648438
# Step: 1700 Loss: 0.05294555425643921 KL_div:0.43179765343666077 current_lr:0.01 Time taken per iteration: 0.009486913681030273
# Step: 1710 Loss: 0.05294202268123627 KL_div:0.431753009557724 current_lr:0.01 Time taken per iteration: 0.010409832000732422
# Step: 1720 Loss: 0.05293846130371094 KL_div:0.43170857429504395 current_lr:0.01 Time taken per iteration: 0.008872509002685547
# Step: 1730 Loss: 0.0529354065656662 KL_div:0.4316675364971161 current_lr:0.01 Time taken per iteration: 0.008755207061767578
# Step: 1740 Loss: 0.052932143211364746 KL_div:0.431625097990036 current_lr:0.01 Time taken per iteration: 0.009327173233032227
# Step: 1750 Loss: 0.05292879790067673 KL_div:0.43158191442489624 current_lr:0.01 Time taken per iteration: 0.010464191436767578
# Step: 1760 Loss: 0.052925437688827515 KL_div:0.4315389394760132 current_lr:0.01 Time taken per iteration: 0.009813308715820312
# Step: 1770 Loss: 0.05292245000600815 KL_div:0.4314984083175659 current_lr:0.01 Time taken per iteration: 0.02248525619506836
# Step: 1780 Loss: 0.052919283509254456 KL_div:0.4314567446708679 current_lr:0.01 Time taken per iteration: 0.008093118667602539
# Step: 1790 Loss: 0.052916139364242554 KL_div:0.431415319442749 current_lr:0.01 Time taken per iteration: 0.011258125305175781
# Step: 1800 Loss: 0.052913010120391846 KL_div:0.4313739836215973 current_lr:0.01 Time taken per iteration: 0.009552001953125
# Step: 1810 Loss: 0.05291023850440979 KL_div:0.43133535981178284 current_lr:0.01 Time taken per iteration: 0.007825851440429688
# Step: 1820 Loss: 0.052907295525074005 KL_div:0.43129563331604004 current_lr:0.01 Time taken per iteration: 0.011829137802124023
# Step: 1830 Loss: 0.05290424823760986 KL_div:0.4312552213668823 current_lr:0.01 Time taken per iteration: 0.009786367416381836
# Step: 1840 Loss: 0.05290115624666214 KL_div:0.43121469020843506 current_lr:0.01 Time taken per iteration: 0.00900578498840332
# Step: 1850 Loss: 0.05289846658706665 KL_div:0.431177020072937 current_lr:0.01 Time taken per iteration: 0.01494908332824707
# Step: 1860 Loss: 0.05289565771818161 KL_div:0.4311387538909912 current_lr:0.01 Time taken per iteration: 0.010433197021484375
# Step: 1870 Loss: 0.05289255827665329 KL_div:0.431098610162735 current_lr:0.01 Time taken per iteration: 0.008095026016235352
# Step: 1880 Loss: 0.0528898611664772 KL_div:0.43106144666671753 current_lr:0.01 Time taken per iteration: 0.009279251098632812
# Step: 1890 Loss: 0.05288707837462425 KL_div:0.43102362751960754 current_lr:0.01 Time taken per iteration: 0.008671998977661133
# Step: 1900 Loss: 0.05288446694612503 KL_div:0.43098747730255127 current_lr:0.01 Time taken per iteration: 0.008593082427978516
# Step: 1910 Loss: 0.05288155376911163 KL_div:0.43094921112060547 current_lr:0.01 Time taken per iteration: 0.006278038024902344
# Step: 1920 Loss: 0.05287868529558182 KL_div:0.430911660194397 current_lr:0.01 Time taken per iteration: 0.009674072265625
# Step: 1930 Loss: 0.05287635326385498 KL_div:0.4308779239654541 current_lr:0.01 Time taken per iteration: 0.006522655487060547
# Step: 1940 Loss: 0.052873656153678894 KL_div:0.430841863155365 current_lr:0.01 Time taken per iteration: 0.005688667297363281
# Step: 1950 Loss: 0.05287095159292221 KL_div:0.43080586194992065 current_lr:0.01 Time taken per iteration: 0.004540443420410156
# Step: 1960 Loss: 0.052868302911520004 KL_div:0.43077072501182556 current_lr:0.01 Time taken per iteration: 0.0063915252685546875
# Step: 1970 Loss: 0.052865881472826004 KL_div:0.43073731660842896 current_lr:0.01 Time taken per iteration: 0.012525320053100586
# Step: 1980 Loss: 0.052863411605358124 KL_div:0.43070369958877563 current_lr:0.01 Time taken per iteration: 0.0038764476776123047
# Step: 1990 Loss: 0.05286083370447159 KL_div:0.4306696653366089 current_lr:0.01 Time taken per iteration: 0.0066912174224853516
# Step: 2000 Loss: 0.052858300507068634 KL_div:0.43063631653785706 current_lr:0.01 Time taken per iteration: 0.014091968536376953
# Step: 2010 Loss: 0.052855636924505234 KL_div:0.43060213327407837 current_lr:0.01 Time taken per iteration: 0.003818035125732422
# Step: 2020 Loss: 0.052853185683488846 KL_div:0.43056976795196533 current_lr:0.01 Time taken per iteration: 0.010276556015014648
# Step: 2030 Loss: 0.05285079777240753 KL_div:0.43053823709487915 current_lr:0.01 Time taken per iteration: 0.005182027816772461
# Step: 2040 Loss: 0.05284830555319786 KL_div:0.4305061101913452 current_lr:0.01 Time taken per iteration: 0.0054645538330078125
# Step: 2050 Loss: 0.05284576863050461 KL_div:0.4304739832878113 current_lr:0.01 Time taken per iteration: 0.0062563419342041016
# Step: 2060 Loss: 0.05284339189529419 KL_div:0.4304433763027191 current_lr:0.01 Time taken per iteration: 0.00810384750366211
# Step: 2070 Loss: 0.05284114181995392 KL_div:0.43041372299194336 current_lr:0.01 Time taken per iteration: 0.010515689849853516
# Step: 2080 Loss: 0.05283880978822708 KL_div:0.4303840100765228 current_lr:0.01 Time taken per iteration: 0.005416154861450195
# Step: 2090 Loss: 0.052836209535598755 KL_div:0.43035274744033813 current_lr:0.01 Time taken per iteration: 0.003337860107421875
# Step: 2100 Loss: 0.05283398926258087 KL_div:0.4303244352340698 current_lr:0.01 Time taken per iteration: 0.007150411605834961
# Step: 2110 Loss: 0.05283176153898239 KL_div:0.430296391248703 current_lr:0.01 Time taken per iteration: 0.003608226776123047
# Step: 2120 Loss: 0.05282936245203018 KL_div:0.4302676022052765 current_lr:0.01 Time taken per iteration: 0.008483648300170898
# Step: 2130 Loss: 0.05282701551914215 KL_div:0.43023931980133057 current_lr:0.01 Time taken per iteration: 0.0035622119903564453
# Step: 2140 Loss: 0.05282461643218994 KL_div:0.43021124601364136 current_lr:0.01 Time taken per iteration: 0.0037293434143066406
# Step: 2150 Loss: 0.05282221734523773 KL_div:0.43018338084220886 current_lr:0.01 Time taken per iteration: 0.010343313217163086
# Step: 2160 Loss: 0.05282014608383179 KL_div:0.43015819787979126 current_lr:0.01 Time taken per iteration: 0.009176254272460938
# Step: 2170 Loss: 0.05281761288642883 KL_div:0.4301301836967468 current_lr:0.01 Time taken per iteration: 0.023175477981567383
# Step: 2180 Loss: 0.05281533673405647 KL_div:0.4301043152809143 current_lr:0.01 Time taken per iteration: 0.007795572280883789
# Step: 2190 Loss: 0.05281291902065277 KL_div:0.4300778806209564 current_lr:0.01 Time taken per iteration: 0.009327173233032227
# Step: 2200 Loss: 0.05281075835227966 KL_div:0.4300536513328552 current_lr:0.01 Time taken per iteration: 0.008794069290161133
# Step: 2210 Loss: 0.052808456122875214 KL_div:0.4300287961959839 current_lr:0.01 Time taken per iteration: 0.009017467498779297
# Step: 2220 Loss: 0.05280625820159912 KL_div:0.43000519275665283 current_lr:0.01 Time taken per iteration: 0.011065006256103516
# Step: 2230 Loss: 0.052804019302129745 KL_div:0.4299815893173218 current_lr:0.01 Time taken per iteration: 0.008471250534057617
# Step: 2240 Loss: 0.052801672369241714 KL_div:0.4299578368663788 current_lr:0.01 Time taken per iteration: 0.007761478424072266
# Step: 2250 Loss: 0.05279962718486786 KL_div:0.42993658781051636 current_lr:0.01 Time taken per iteration: 0.00809478759765625
# Step: 2260 Loss: 0.05279748886823654 KL_div:0.42991504073143005 current_lr:0.01 Time taken per iteration: 0.014414548873901367
# Step: 2270 Loss: 0.05279501527547836 KL_div:0.4298914670944214 current_lr:0.01 Time taken per iteration: 0.009341001510620117
# Step: 2280 Loss: 0.05279281735420227 KL_div:0.4298704266548157 current_lr:0.01 Time taken per iteration: 0.008147716522216797
# Step: 2290 Loss: 0.05279078334569931 KL_div:0.4298509359359741 current_lr:0.01 Time taken per iteration: 0.020243167877197266
# Step: 2300 Loss: 0.052788518369197845 KL_div:0.429830402135849 current_lr:0.01 Time taken per iteration: 0.012645483016967773
# Step: 2310 Loss: 0.05278643220663071 KL_div:0.42981141805648804 current_lr:0.01 Time taken per iteration: 0.008466720581054688
# Step: 2320 Loss: 0.05278436839580536 KL_div:0.4297931492328644 current_lr:0.01 Time taken per iteration: 0.013924837112426758
# Step: 2330 Loss: 0.0527820810675621 KL_div:0.42977362871170044 current_lr:0.01 Time taken per iteration: 0.006702899932861328
# Step: 2340 Loss: 0.052779994904994965 KL_div:0.4297560453414917 current_lr:0.01 Time taken per iteration: 0.011728286743164062
# Step: 2350 Loss: 0.052778154611587524 KL_div:0.4297404885292053 current_lr:0.01 Time taken per iteration: 0.011444807052612305
# Step: 2360 Loss: 0.05277577042579651 KL_div:0.4297217130661011 current_lr:0.01 Time taken per iteration: 0.009283065795898438
# Step: 2370 Loss: 0.052773892879486084 KL_div:0.4297066926956177 current_lr:0.01 Time taken per iteration: 0.011840343475341797
# Step: 2380 Loss: 0.05277178809046745 KL_div:0.42969053983688354 current_lr:0.01 Time taken per iteration: 0.010545492172241211
# Step: 2390 Loss: 0.05276999622583389 KL_div:0.42967700958251953 current_lr:0.01 Time taken per iteration: 0.007040977478027344
# Step: 2400 Loss: 0.0527680441737175 KL_div:0.42966264486312866 current_lr:0.01 Time taken per iteration: 0.008426427841186523
# Step: 2410 Loss: 0.052766352891922 KL_div:0.4296503961086273 current_lr:0.01 Time taken per iteration: 0.011084794998168945
# Step: 2420 Loss: 0.0527644157409668 KL_div:0.4296368360519409 current_lr:0.01 Time taken per iteration: 0.012045621871948242
# Step: 2430 Loss: 0.05276259407401085 KL_div:0.42962437868118286 current_lr:0.01 Time taken per iteration: 0.012265205383300781
# Step: 2440 Loss: 0.05276091769337654 KL_div:0.4296131134033203 current_lr:0.01 Time taken per iteration: 0.011140823364257812
# Step: 2450 Loss: 0.05275953561067581 KL_div:0.4296042323112488 current_lr:0.01 Time taken per iteration: 0.008427619934082031
# Step: 2460 Loss: 0.05275765806436539 KL_div:0.4295920133590698 current_lr:0.01 Time taken per iteration: 0.010662078857421875
# Step: 2470 Loss: 0.052756041288375854 KL_div:0.42958182096481323 current_lr:0.01 Time taken per iteration: 0.010080575942993164
# Step: 2480 Loss: 0.052754659205675125 KL_div:0.429573655128479 current_lr:0.01 Time taken per iteration: 0.009182214736938477
# Step: 2490 Loss: 0.05275331437587738 KL_div:0.4295656681060791 current_lr:0.01 Time taken per iteration: 0.011661529541015625
# Step: 2500 Loss: 0.05275160074234009 KL_div:0.42955535650253296 current_lr:0.01 Time taken per iteration: 0.009654998779296875
# Step: 2510 Loss: 0.0527501218020916 KL_div:0.429546594619751 current_lr:0.01 Time taken per iteration: 0.007802486419677734
# Step: 2520 Loss: 0.0527491495013237 KL_div:0.4295414686203003 current_lr:0.01 Time taken per iteration: 0.011506319046020508
# Step: 2530 Loss: 0.05274742841720581 KL_div:0.4295312166213989 current_lr:0.01 Time taken per iteration: 0.007866144180297852
# Step: 2540 Loss: 0.05274644494056702 KL_div:0.4295262396335602 current_lr:0.01 Time taken per iteration: 0.010406732559204102
# Step: 2550 Loss: 0.05274534970521927 KL_div:0.4295203685760498 current_lr:0.01 Time taken per iteration: 0.009393692016601562
# Step: 2560 Loss: 0.05274425446987152 KL_div:0.4295145273208618 current_lr:0.01 Time taken per iteration: 0.011008024215698242
# Step: 2570 Loss: 0.052743226289749146 KL_div:0.42950916290283203 current_lr:0.01 Time taken per iteration: 0.009056329727172852
# Step: 2580 Loss: 0.05274195969104767 KL_div:0.42950212955474854 current_lr:0.01 Time taken per iteration: 0.009657144546508789
# Step: 2590 Loss: 0.05274078994989395 KL_div:0.42949551343917847 current_lr:0.01 Time taken per iteration: 0.010449886322021484
# Step: 2600 Loss: 0.052739888429641724 KL_div:0.42949098348617554 current_lr:0.01 Time taken per iteration: 0.00884699821472168
# Step: 2610 Loss: 0.0527389794588089 KL_div:0.4294862449169159 current_lr:0.01 Time taken per iteration: 0.009577512741088867
# Step: 2620 Loss: 0.05273805558681488 KL_div:0.4294814169406891 current_lr:0.01 Time taken per iteration: 0.0073888301849365234
# Step: 2630 Loss: 0.05273725092411041 KL_div:0.42947718501091003 current_lr:0.01 Time taken per iteration: 0.009083271026611328
# Step: 2640 Loss: 0.05273634195327759 KL_div:0.4294722080230713 current_lr:0.01 Time taken per iteration: 0.009809494018554688
# Step: 2650 Loss: 0.052735574543476105 KL_div:0.42946821451187134 current_lr:0.01 Time taken per iteration: 0.008203268051147461
# Step: 2660 Loss: 0.052734822034835815 KL_div:0.4294642210006714 current_lr:0.01 Time taken per iteration: 0.008253812789916992
# Step: 2670 Loss: 0.052734002470970154 KL_div:0.42945969104766846 current_lr:0.01 Time taken per iteration: 0.009009838104248047
# Step: 2680 Loss: 0.05273312330245972 KL_div:0.42945462465286255 current_lr:0.01 Time taken per iteration: 0.008437871932983398
# Step: 2690 Loss: 0.0527324303984642 KL_div:0.4294508695602417 current_lr:0.01 Time taken per iteration: 0.010108470916748047
# Step: 2700 Loss: 0.05273161828517914 KL_div:0.42944616079330444 current_lr:0.01 Time taken per iteration: 0.007921695709228516
# Step: 2710 Loss: 0.052730903029441833 KL_div:0.4294421076774597 current_lr:0.01 Time taken per iteration: 0.011102676391601562
# Step: 2720 Loss: 0.052730098366737366 KL_div:0.4294373393058777 current_lr:0.01 Time taken per iteration: 0.011966466903686523
# Step: 2730 Loss: 0.0527292862534523 KL_div:0.4294325113296509 current_lr:0.01 Time taken per iteration: 0.01402735710144043
# Step: 2740 Loss: 0.05272877216339111 KL_div:0.4294296205043793 current_lr:0.01 Time taken per iteration: 0.008467674255371094
# Step: 2750 Loss: 0.05272822827100754 KL_div:0.4294265806674957 current_lr:0.01 Time taken per iteration: 0.022134065628051758
# Step: 2760 Loss: 0.05272720009088516 KL_div:0.4294200539588928 current_lr:0.01 Time taken per iteration: 0.010270118713378906
# Step: 2770 Loss: 0.052726853638887405 KL_div:0.42941826581954956 current_lr:0.01 Time taken per iteration: 0.009953498840332031
# Step: 2780 Loss: 0.052726320922374725 KL_div:0.42941492795944214 current_lr:0.01 Time taken per iteration: 0.008327484130859375
# Step: 2790 Loss: 0.052725523710250854 KL_div:0.42941009998321533 current_lr:0.01 Time taken per iteration: 0.008329153060913086
# Step: 2800 Loss: 0.05272480845451355 KL_div:0.42940545082092285 current_lr:0.01 Time taken per iteration: 0.011587381362915039
# Step: 2810 Loss: 0.052724190056324005 KL_div:0.429401695728302 current_lr:0.01 Time taken per iteration: 0.007706403732299805
# Step: 2820 Loss: 0.05272328481078148 KL_div:0.42939573526382446 current_lr:0.01 Time taken per iteration: 0.009964942932128906
# Step: 2830 Loss: 0.0527229905128479 KL_div:0.429394006729126 current_lr:0.01 Time taken per iteration: 0.013817071914672852
# Step: 2840 Loss: 0.0527220144867897 KL_div:0.4293876886367798 current_lr:0.01 Time taken per iteration: 0.009396553039550781
# Step: 2850 Loss: 0.052721455693244934 KL_div:0.4293842315673828 current_lr:0.01 Time taken per iteration: 0.01125025749206543
# Step: 2860 Loss: 0.05272082984447479 KL_div:0.4293801188468933 current_lr:0.01 Time taken per iteration: 0.008826971054077148
# Step: 2870 Loss: 0.05272052437067032 KL_div:0.4293782413005829 current_lr:0.01 Time taken per iteration: 0.009070873260498047
# Step: 2880 Loss: 0.052719660103321075 KL_div:0.4293724596500397 current_lr:0.01 Time taken per iteration: 0.008179664611816406
# Step: 2890 Loss: 0.05271921306848526 KL_div:0.4293696880340576 current_lr:0.01 Time taken per iteration: 0.00972437858581543
# Step: 2900 Loss: 0.052718572318553925 KL_div:0.4293656051158905 current_lr:0.01 Time taken per iteration: 0.009926080703735352
# Step: 2910 Loss: 0.052717868238687515 KL_div:0.4293609857559204 current_lr:0.01 Time taken per iteration: 0.022478580474853516
# Step: 2920 Loss: 0.052717190235853195 KL_div:0.4293564558029175 current_lr:0.01 Time taken per iteration: 0.010564327239990234
# Step: 2930 Loss: 0.05271659046411514 KL_div:0.4293524920940399 current_lr:0.01 Time taken per iteration: 0.009293794631958008
# Step: 2940 Loss: 0.05271601676940918 KL_div:0.42934876680374146 current_lr:0.01 Time taken per iteration: 0.008568286895751953
# Step: 2950 Loss: 0.0527154766023159 KL_div:0.4293452501296997 current_lr:0.01 Time taken per iteration: 0.007420063018798828
# Step: 2960 Loss: 0.052714861929416656 KL_div:0.42934122681617737 current_lr:0.01 Time taken per iteration: 0.012621164321899414
# Step: 2970 Loss: 0.05271442234516144 KL_div:0.42933839559555054 current_lr:0.01 Time taken per iteration: 0.010781049728393555
# Step: 2980 Loss: 0.05271371454000473 KL_div:0.4293336272239685 current_lr:0.01 Time taken per iteration: 0.009903430938720703
# Step: 2990 Loss: 0.05271310731768608 KL_div:0.4293297529220581 current_lr:0.01 Time taken per iteration: 0.009231805801391602
# Step: 3000 Loss: 0.05271264910697937 KL_div:0.4293266832828522 current_lr:0.01 Time taken per iteration: 0.01113438606262207
# Step: 3010 Loss: 0.05271196365356445 KL_div:0.4293223023414612 current_lr:0.01 Time taken per iteration: 0.008995532989501953
# Step: 3020 Loss: 0.05271138623356819 KL_div:0.4293183982372284 current_lr:0.01 Time taken per iteration: 0.01898789405822754
# Step: 3030 Loss: 0.0527106374502182 KL_div:0.42931342124938965 current_lr:0.01 Time taken per iteration: 0.008862018585205078
# Step: 3040 Loss: 0.0527103915810585 KL_div:0.4293119013309479 current_lr:0.01 Time taken per iteration: 0.008355140686035156
# Step: 3050 Loss: 0.052709758281707764 KL_div:0.4293077290058136 current_lr:0.01 Time taken per iteration: 0.013377189636230469
# Step: 3060 Loss: 0.05270899087190628 KL_div:0.4293026030063629 current_lr:0.01 Time taken per iteration: 0.013824224472045898
# Step: 3070 Loss: 0.05270868539810181 KL_div:0.4293006360530853 current_lr:0.01 Time taken per iteration: 0.011209249496459961
# Step: 3080 Loss: 0.052708134055137634 KL_div:0.4292971193790436 current_lr:0.01 Time taken per iteration: 0.010352134704589844
# Step: 3090 Loss: 0.0527077317237854 KL_div:0.4292944073677063 current_lr:0.01 Time taken per iteration: 0.010582208633422852
# Step: 3100 Loss: 0.05270684137940407 KL_div:0.4292885363101959 current_lr:0.01 Time taken per iteration: 0.0093994140625
# Step: 3110 Loss: 0.05270666629076004 KL_div:0.42928755283355713 current_lr:0.01 Time taken per iteration: 0.009182929992675781
# Step: 3120 Loss: 0.05270572751760483 KL_div:0.4292812943458557 current_lr:0.01 Time taken per iteration: 0.006539821624755859
# Step: 3130 Loss: 0.05270520597696304 KL_div:0.42927783727645874 current_lr:0.01 Time taken per iteration: 0.011239767074584961
# Step: 3140 Loss: 0.05270469933748245 KL_div:0.42927461862564087 current_lr:0.01 Time taken per iteration: 0.012360095977783203
# Step: 3150 Loss: 0.05270426720380783 KL_div:0.42927175760269165 current_lr:0.01 Time taken per iteration: 0.005850553512573242
# Step: 3160 Loss: 0.05270353704690933 KL_div:0.4292669892311096 current_lr:0.01 Time taken per iteration: 0.014005899429321289
# Step: 3170 Loss: 0.05270318686962128 KL_div:0.42926472425460815 current_lr:0.01 Time taken per iteration: 0.005471706390380859
# Step: 3180 Loss: 0.05270279198884964 KL_div:0.42926228046417236 current_lr:0.01 Time taken per iteration: 0.006348848342895508
# Step: 3190 Loss: 0.052702292799949646 KL_div:0.42925912141799927 current_lr:0.01 Time taken per iteration: 0.006539106369018555
# Step: 3200 Loss: 0.05270149186253548 KL_div:0.4292537569999695 current_lr:0.01 Time taken per iteration: 0.00628662109375
# Step: 3210 Loss: 0.05270117521286011 KL_div:0.4292517900466919 current_lr:0.01 Time taken per iteration: 0.006383180618286133
# Step: 3220 Loss: 0.05270066857337952 KL_div:0.429248571395874 current_lr:0.01 Time taken per iteration: 0.004705667495727539
# Step: 3230 Loss: 0.05270039662718773 KL_div:0.4292469024658203 current_lr:0.01 Time taken per iteration: 0.010549783706665039
# Step: 3240 Loss: 0.05269966647028923 KL_div:0.4292420446872711 current_lr:0.01 Time taken per iteration: 0.009978055953979492
# Step: 3250 Loss: 0.05269888788461685 KL_div:0.4292370080947876 current_lr:0.01 Time taken per iteration: 0.005423545837402344
# Step: 3260 Loss: 0.05269857496023178 KL_div:0.4292351007461548 current_lr:0.01 Time taken per iteration: 0.014646291732788086
# Step: 3270 Loss: 0.05269801989197731 KL_div:0.42923152446746826 current_lr:0.01 Time taken per iteration: 0.003963470458984375
# Step: 3280 Loss: 0.052697546780109406 KL_div:0.4292284846305847 current_lr:0.01 Time taken per iteration: 0.0064220428466796875
# Step: 3290 Loss: 0.05269724130630493 KL_div:0.4292266070842743 current_lr:0.01 Time taken per iteration: 0.005422830581665039
# Step: 3300 Loss: 0.05269687622785568 KL_div:0.4292243421077728 current_lr:0.01 Time taken per iteration: 0.006639719009399414
# Step: 3310 Loss: 0.052696242928504944 KL_div:0.4292203187942505 current_lr:0.01 Time taken per iteration: 0.006764411926269531
# Step: 3320 Loss: 0.05269547551870346 KL_div:0.4292150139808655 current_lr:0.01 Time taken per iteration: 0.007718563079833984
# Step: 3330 Loss: 0.05269493907690048 KL_div:0.42921173572540283 current_lr:0.01 Time taken per iteration: 0.010883092880249023
# Step: 3340 Loss: 0.05269481986761093 KL_div:0.42921122908592224 current_lr:0.01 Time taken per iteration: 0.017202377319335938
# Step: 3350 Loss: 0.05269414931535721 KL_div:0.42920684814453125 current_lr:0.01 Time taken per iteration: 0.010219812393188477
# Step: 3360 Loss: 0.05269354581832886 KL_div:0.4292028546333313 current_lr:0.01 Time taken per iteration: 0.008904695510864258
# Step: 3370 Loss: 0.052693188190460205 KL_div:0.429200679063797 current_lr:0.01 Time taken per iteration: 0.009991884231567383
# Step: 3380 Loss: 0.05269274488091469 KL_div:0.42919790744781494 current_lr:0.01 Time taken per iteration: 0.012586593627929688
# Step: 3390 Loss: 0.052692316472530365 KL_div:0.42919519543647766 current_lr:0.01 Time taken per iteration: 0.011359214782714844
# Step: 3400 Loss: 0.05269180238246918 KL_div:0.42919182777404785 current_lr:0.01 Time taken per iteration: 0.011164426803588867
# Step: 3410 Loss: 0.05269130319356918 KL_div:0.4291887581348419 current_lr:0.01 Time taken per iteration: 0.012765169143676758
# Step: 3420 Loss: 0.05269073694944382 KL_div:0.429185152053833 current_lr:0.01 Time taken per iteration: 0.009456872940063477
# Step: 3430 Loss: 0.052690401673316956 KL_div:0.4291830360889435 current_lr:0.01 Time taken per iteration: 0.010380744934082031
# Step: 3440 Loss: 0.05268998071551323 KL_div:0.429180383682251 current_lr:0.01 Time taken per iteration: 0.008641242980957031
# Step: 3450 Loss: 0.05268960818648338 KL_div:0.4291781187057495 current_lr:0.01 Time taken per iteration: 0.009830951690673828
# Step: 3460 Loss: 0.052689068019390106 KL_div:0.4291746914386749 current_lr:0.01 Time taken per iteration: 0.010208606719970703
# Step: 3470 Loss: 0.05268862098455429 KL_div:0.4291718602180481 current_lr:0.01 Time taken per iteration: 0.00924372673034668
# Step: 3480 Loss: 0.052688274532556534 KL_div:0.4291697144508362 current_lr:0.01 Time taken per iteration: 0.010057687759399414
# Step: 3490 Loss: 0.05268777906894684 KL_div:0.42916664481163025 current_lr:0.01 Time taken per iteration: 0.007544279098510742
# Step: 3500 Loss: 0.05268722027540207 KL_div:0.42916303873062134 current_lr:0.01 Time taken per iteration: 0.009557723999023438
# Step: 3510 Loss: 0.05268695950508118 KL_div:0.4291614592075348 current_lr:0.01 Time taken per iteration: 0.00934147834777832
# Step: 3520 Loss: 0.052686192095279694 KL_div:0.42915648221969604 current_lr:0.01 Time taken per iteration: 0.00940084457397461
# Step: 3530 Loss: 0.05268578976392746 KL_div:0.4291539788246155 current_lr:0.01 Time taken per iteration: 0.010853290557861328
# Step: 3540 Loss: 0.05268552899360657 KL_div:0.42915236949920654 current_lr:0.01 Time taken per iteration: 0.008689165115356445
# Step: 3550 Loss: 0.052685193717479706 KL_div:0.42915046215057373 current_lr:0.01 Time taken per iteration: 0.008877277374267578
# Step: 3560 Loss: 0.05268474668264389 KL_div:0.42914748191833496 current_lr:0.01 Time taken per iteration: 0.009348869323730469
# Step: 3570 Loss: 0.05268411710858345 KL_div:0.42914342880249023 current_lr:0.01 Time taken per iteration: 0.010205745697021484
# Step: 3580 Loss: 0.05268377438187599 KL_div:0.4291413128376007 current_lr:0.01 Time taken per iteration: 0.010435819625854492
# Step: 3590 Loss: 0.052683308720588684 KL_div:0.4291384518146515 current_lr:0.01 Time taken per iteration: 0.01058340072631836
# Step: 3600 Loss: 0.05268297716975212 KL_div:0.4291364848613739 current_lr:0.01 Time taken per iteration: 0.00904703140258789
# Step: 3610 Loss: 0.0526825487613678 KL_div:0.42913371324539185 current_lr:0.01 Time taken per iteration: 0.012132644653320312
# Step: 3620 Loss: 0.05268191546201706 KL_div:0.42912960052490234 current_lr:0.01 Time taken per iteration: 0.02125096321105957
# Step: 3630 Loss: 0.05268189311027527 KL_div:0.42912977933883667 current_lr:0.01 Time taken per iteration: 0.008969783782958984
# Step: 3640 Loss: 0.052681416273117065 KL_div:0.42912667989730835 current_lr:0.01 Time taken per iteration: 0.006348133087158203
# Step: 3650 Loss: 0.052680619060993195 KL_div:0.42912155389785767 current_lr:0.01 Time taken per iteration: 0.010474681854248047
# Step: 3660 Loss: 0.05268045887351036 KL_div:0.4291206896305084 current_lr:0.01 Time taken per iteration: 0.016429424285888672
# Step: 3670 Loss: 0.05267999321222305 KL_div:0.42911767959594727 current_lr:0.01 Time taken per iteration: 0.00920414924621582
# Step: 3680 Loss: 0.05267958343029022 KL_div:0.42911505699157715 current_lr:0.01 Time taken per iteration: 0.010724067687988281
# Step: 3690 Loss: 0.05267933011054993 KL_div:0.4291136860847473 current_lr:0.01 Time taken per iteration: 0.009046792984008789
# Step: 3700 Loss: 0.052678853273391724 KL_div:0.429110586643219 current_lr:0.01 Time taken per iteration: 0.009745597839355469
# Step: 3710 Loss: 0.05267862603068352 KL_div:0.4291093647480011 current_lr:0.01 Time taken per iteration: 0.010356903076171875
# Step: 3720 Loss: 0.05267808586359024 KL_div:0.42910584807395935 current_lr:0.01 Time taken per iteration: 0.011010408401489258
# Step: 3730 Loss: 0.05267760157585144 KL_div:0.4291027784347534 current_lr:0.01 Time taken per iteration: 0.00918436050415039
# Step: 3740 Loss: 0.052677370607852936 KL_div:0.42910146713256836 current_lr:0.01 Time taken per iteration: 0.0068776607513427734
# Step: 3750 Loss: 0.052677031606435776 KL_div:0.429099440574646 current_lr:0.01 Time taken per iteration: 0.013711690902709961
# Step: 3760 Loss: 0.05267685651779175 KL_div:0.42909833788871765 current_lr:0.01 Time taken per iteration: 0.010710716247558594
# Step: 3770 Loss: 0.052676182240247726 KL_div:0.4290940761566162 current_lr:0.01 Time taken per iteration: 0.01018977165222168
# Step: 3780 Loss: 0.0526757687330246 KL_div:0.4290913939476013 current_lr:0.01 Time taken per iteration: 0.008845329284667969
# Step: 3790 Loss: 0.05267540365457535 KL_div:0.42908918857574463 current_lr:0.01 Time taken per iteration: 0.011084556579589844
# Step: 3800 Loss: 0.05267530307173729 KL_div:0.4290887117385864 current_lr:0.01 Time taken per iteration: 0.00926828384399414
# Step: 3810 Loss: 0.05267481505870819 KL_div:0.42908555269241333 current_lr:0.01 Time taken per iteration: 0.008990049362182617
# Step: 3820 Loss: 0.052674323320388794 KL_div:0.42908239364624023 current_lr:0.01 Time taken per iteration: 0.007885932922363281
# Step: 3830 Loss: 0.052674077451229095 KL_div:0.4290810227394104 current_lr:0.01 Time taken per iteration: 0.010689258575439453
# Step: 3840 Loss: 0.05267360061407089 KL_div:0.42907795310020447 current_lr:0.01 Time taken per iteration: 0.011880159378051758
# Step: 3850 Loss: 0.0526733323931694 KL_div:0.42907628417015076 current_lr:0.01 Time taken per iteration: 0.008828401565551758
# Step: 3860 Loss: 0.05267303064465523 KL_div:0.42907437682151794 current_lr:0.01 Time taken per iteration: 0.012108564376831055
# Step: 3870 Loss: 0.05267282947897911 KL_div:0.42907315492630005 current_lr:0.01 Time taken per iteration: 0.00841379165649414
# Step: 3880 Loss: 0.052672192454338074 KL_div:0.4290691912174225 current_lr:0.01 Time taken per iteration: 0.013438701629638672
# Step: 3890 Loss: 0.05267205089330673 KL_div:0.42906832695007324 current_lr:0.01 Time taken per iteration: 0.009287595748901367
# Step: 3900 Loss: 0.052671514451503754 KL_div:0.42906486988067627 current_lr:0.01 Time taken per iteration: 0.02103734016418457
# Step: 3910 Loss: 0.052671320736408234 KL_div:0.4290636479854584 current_lr:0.01 Time taken per iteration: 0.0077724456787109375
# Step: 3920 Loss: 0.05267102271318436 KL_div:0.4290618896484375 current_lr:0.01 Time taken per iteration: 0.007224559783935547
# Step: 3930 Loss: 0.05267076566815376 KL_div:0.4290603697299957 current_lr:0.01 Time taken per iteration: 0.009765863418579102
# Step: 3940 Loss: 0.052670158445835114 KL_div:0.42905640602111816 current_lr:0.01 Time taken per iteration: 0.008519887924194336
# Step: 3950 Loss: 0.052670106291770935 KL_div:0.4290562868118286 current_lr:0.01 Time taken per iteration: 0.009361505508422852
# Step: 3960 Loss: 0.0526697039604187 KL_div:0.4290536642074585 current_lr:0.01 Time taken per iteration: 0.00953531265258789
# Step: 3970 Loss: 0.05266928672790527 KL_div:0.429051011800766 current_lr:0.01 Time taken per iteration: 0.008710622787475586
# Step: 3980 Loss: 0.05266909673810005 KL_div:0.42904990911483765 current_lr:0.01 Time taken per iteration: 0.008322715759277344
# Step: 3990 Loss: 0.05266880244016647 KL_div:0.4290478825569153 current_lr:0.01 Time taken per iteration: 0.009798049926757812
# Step: 4000 Loss: 0.05266911908984184 KL_div:0.4290475845336914 current_lr:0.01 Time taken per iteration: 0.00953984260559082
# Step: 4010 Loss: 0.052670277655124664 KL_div:0.4290521740913391 current_lr:0.01 Time taken per iteration: 0.009546995162963867
# Step: 4020 Loss: 0.05266802757978439 KL_div:0.4290435314178467 current_lr:0.01 Time taken per iteration: 0.008698225021362305
# Step: 4030 Loss: 0.05266813188791275 KL_div:0.42904454469680786 current_lr:0.01 Time taken per iteration: 0.00809335708618164
# Step: 4040 Loss: 0.052667371928691864 KL_div:0.42903831601142883 current_lr:0.01 Time taken per iteration: 0.007866859436035156
# Step: 4050 Loss: 0.0526670441031456 KL_div:0.42903733253479004 current_lr:0.01 Time taken per iteration: 0.009221553802490234
# Step: 4060 Loss: 0.052666690200567245 KL_div:0.42903509736061096 current_lr:0.01 Time taken per iteration: 0.010530233383178711
# Step: 4070 Loss: 0.05266629531979561 KL_div:0.42903241515159607 current_lr:0.01 Time taken per iteration: 0.009008169174194336
# Step: 4080 Loss: 0.0526663139462471 KL_div:0.42903292179107666 current_lr:0.01 Time taken per iteration: 0.008940696716308594
# Step: 4090 Loss: 0.05266577750444412 KL_div:0.42902928590774536 current_lr:0.01 Time taken per iteration: 0.011954069137573242
# Step: 4100 Loss: 0.05266550928354263 KL_div:0.42902758717536926 current_lr:0.01 Time taken per iteration: 0.00941610336303711
# Step: 4110 Loss: 0.05266544222831726 KL_div:0.4290274381637573 current_lr:0.01 Time taken per iteration: 0.008489370346069336
# Step: 4120 Loss: 0.05266524851322174 KL_div:0.4290260672569275 current_lr:0.01 Time taken per iteration: 0.00825953483581543
# Step: 4130 Loss: 0.05266469717025757 KL_div:0.42902255058288574 current_lr:0.01 Time taken per iteration: 0.00911092758178711
# Step: 4140 Loss: 0.052664659917354584 KL_div:0.42902252078056335 current_lr:0.01 Time taken per iteration: 0.009897232055664062
# Step: 4150 Loss: 0.05266427993774414 KL_div:0.4290200471878052 current_lr:0.01 Time taken per iteration: 0.008647918701171875
# Step: 4160 Loss: 0.05266386643052101 KL_div:0.42901724576950073 current_lr:0.01 Time taken per iteration: 0.01263570785522461
# Step: 4170 Loss: 0.052663687616586685 KL_div:0.4290163516998291 current_lr:0.01 Time taken per iteration: 0.009274721145629883
# Step: 4180 Loss: 0.052663303911685944 KL_div:0.42901378870010376 current_lr:0.01 Time taken per iteration: 0.009496212005615234
# Step: 4190 Loss: 0.0526631623506546 KL_div:0.429013192653656 current_lr:0.01 Time taken per iteration: 0.028931856155395508
# Step: 4200 Loss: 0.052665747702121735 KL_div:0.4290273189544678 current_lr:0.01 Time taken per iteration: 0.008676528930664062
# Step: 4210 Loss: 0.052663207054138184 KL_div:0.42901188135147095 current_lr:0.01 Time taken per iteration: 0.010662317276000977
# Step: 4220 Loss: 0.052662983536720276 KL_div:0.42901188135147095 current_lr:0.01 Time taken per iteration: 0.009983301162719727
# Step: 4230 Loss: 0.05266271159052849 KL_div:0.4290092885494232 current_lr:0.01 Time taken per iteration: 0.011295795440673828
# Step: 4240 Loss: 0.05266214907169342 KL_div:0.42900699377059937 current_lr:0.01 Time taken per iteration: 0.0074825286865234375
# Step: 4250 Loss: 0.05266162008047104 KL_div:0.42900341749191284 current_lr:0.01 Time taken per iteration: 0.008335590362548828
# Step: 4260 Loss: 0.05266165733337402 KL_div:0.42900362610816956 current_lr:0.01 Time taken per iteration: 0.009854555130004883
# Step: 4270 Loss: 0.05266141518950462 KL_div:0.4290022850036621 current_lr:0.01 Time taken per iteration: 0.008571386337280273
# Step: 4280 Loss: 0.05266093462705612 KL_div:0.4289989471435547 current_lr:0.01 Time taken per iteration: 0.011178255081176758
# Step: 4290 Loss: 0.05266062915325165 KL_div:0.42899709939956665 current_lr:0.01 Time taken per iteration: 0.010095357894897461
# Step: 4300 Loss: 0.05266052857041359 KL_div:0.42899659276008606 current_lr:0.01 Time taken per iteration: 0.009016036987304688
# Step: 4310 Loss: 0.05266011878848076 KL_div:0.42899394035339355 current_lr:0.01 Time taken per iteration: 0.00949716567993164
# Step: 4320 Loss: 0.05266016349196434 KL_div:0.4289942979812622 current_lr:0.01 Time taken per iteration: 0.008016109466552734
# Step: 4330 Loss: 0.05265997722744942 KL_div:0.4289931654930115 current_lr:0.01 Time taken per iteration: 0.009994268417358398
# Step: 4340 Loss: 0.05265936627984047 KL_div:0.4289891719818115 current_lr:0.01 Time taken per iteration: 0.00808405876159668
# Step: 4350 Loss: 0.05265948921442032 KL_div:0.42899009585380554 current_lr:0.01 Time taken per iteration: 0.00806570053100586
# Step: 4360 Loss: 0.05265925079584122 KL_div:0.42898857593536377 current_lr:0.01 Time taken per iteration: 0.00845789909362793
# Step: 4370 Loss: 0.052659012377262115 KL_div:0.4289870262145996 current_lr:0.01 Time taken per iteration: 0.012492179870605469
# Step: 4380 Loss: 0.05265901982784271 KL_div:0.4289867579936981 current_lr:0.01 Time taken per iteration: 0.010032176971435547
# Step: 4390 Loss: 0.05266087129712105 KL_div:0.42899319529533386 current_lr:0.01 Time taken per iteration: 0.008495092391967773
# Step: 4400 Loss: 0.0526600107550621 KL_div:0.42899349331855774 current_lr:0.01 Time taken per iteration: 0.008735418319702148
# Step: 4410 Loss: 0.05265973508358002 KL_div:0.4289885461330414 current_lr:0.01 Time taken per iteration: 0.022707223892211914
# Step: 4420 Loss: 0.052661195397377014 KL_div:0.42900151014328003 current_lr:0.01 Time taken per iteration: 0.008583307266235352
# Step: 4430 Loss: 0.052658312022686005 KL_div:0.4289828836917877 current_lr:0.01 Time taken per iteration: 0.010490179061889648
# Step: 4440 Loss: 0.052657872438430786 KL_div:0.4289795756340027 current_lr:0.01 Time taken per iteration: 0.011899948120117188
# Step: 4450 Loss: 0.0526575967669487 KL_div:0.42897844314575195 current_lr:0.01 Time taken per iteration: 0.010325431823730469
# Step: 4460 Loss: 0.05265744775533676 KL_div:0.42897748947143555 current_lr:0.01 Time taken per iteration: 0.008365869522094727
# Step: 4470 Loss: 0.05265720933675766 KL_div:0.4289759397506714 current_lr:0.01 Time taken per iteration: 0.009761571884155273
# Step: 4480 Loss: 0.05265688896179199 KL_div:0.42897385358810425 current_lr:0.01 Time taken per iteration: 0.007376670837402344
# Step: 4490 Loss: 0.052656807005405426 KL_div:0.42897337675094604 current_lr:0.01 Time taken per iteration: 0.009393692016601562
# Step: 4500 Loss: 0.05265643075108528 KL_div:0.4289707541465759 current_lr:0.01 Time taken per iteration: 0.010744333267211914
# Step: 4510 Loss: 0.052656203508377075 KL_div:0.4289693236351013 current_lr:0.01 Time taken per iteration: 0.01123356819152832
# Step: 4520 Loss: 0.0526561513543129 KL_div:0.42896920442581177 current_lr:0.01 Time taken per iteration: 0.008243322372436523
# Step: 4530 Loss: 0.052656009793281555 KL_div:0.42896825075149536 current_lr:0.01 Time taken per iteration: 0.00910186767578125
# Step: 4540 Loss: 0.052655793726444244 KL_div:0.4289669394493103 current_lr:0.01 Time taken per iteration: 0.009273052215576172
# Step: 4550 Loss: 0.05265548825263977 KL_div:0.4289648234844208 current_lr:0.01 Time taken per iteration: 0.008452415466308594
# Step: 4560 Loss: 0.052655547857284546 KL_div:0.42896538972854614 current_lr:0.01 Time taken per iteration: 0.0108184814453125
# Step: 4570 Loss: 0.05265539884567261 KL_div:0.42896443605422974 current_lr:0.01 Time taken per iteration: 0.012290239334106445
# Step: 4580 Loss: 0.05265510827302933 KL_div:0.4289625287055969 current_lr:0.01 Time taken per iteration: 0.009393930435180664
# Step: 4590 Loss: 0.05265489220619202 KL_div:0.42896130681037903 current_lr:0.01 Time taken per iteration: 0.009355783462524414
# Step: 4600 Loss: 0.05265507102012634 KL_div:0.4289625287055969 current_lr:0.01 Time taken per iteration: 0.009994745254516602
# Step: 4610 Loss: 0.052665602415800095 KL_div:0.42901578545570374 current_lr:0.01 Time taken per iteration: 0.007950782775878906
# Step: 4620 Loss: 0.05265668034553528 KL_div:0.4289671778678894 current_lr:0.01 Time taken per iteration: 0.009571552276611328
# Step: 4630 Loss: 0.05265555903315544 KL_div:0.4289637506008148 current_lr:0.01 Time taken per iteration: 0.02082085609436035
# Step: 4640 Loss: 0.05266447365283966 KL_div:0.4290236234664917 current_lr:0.01 Time taken per iteration: 0.008929729461669922
# Step: 4650 Loss: 0.05265431851148605 KL_div:0.42895784974098206 current_lr:0.01 Time taken per iteration: 0.008843183517456055
# Step: 4660 Loss: 0.052654772996902466 KL_div:0.4289603531360626 current_lr:0.01 Time taken per iteration: 0.009018421173095703
# Step: 4670 Loss: 0.05265413597226143 KL_div:0.42895635962486267 current_lr:0.01 Time taken per iteration: 0.008350372314453125
# Step: 4680 Loss: 0.05265364050865173 KL_div:0.4289533495903015 current_lr:0.01 Time taken per iteration: 0.011490345001220703
# Step: 4690 Loss: 0.05265359580516815 KL_div:0.42895305156707764 current_lr:0.01 Time taken per iteration: 0.008973836898803711
# Step: 4700 Loss: 0.05265333503484726 KL_div:0.4289513826370239 current_lr:0.01 Time taken per iteration: 0.01007843017578125
# Step: 4710 Loss: 0.05265318229794502 KL_div:0.42895054817199707 current_lr:0.01 Time taken per iteration: 0.010885477066040039
# Step: 4720 Loss: 0.05265303701162338 KL_div:0.4289495348930359 current_lr:0.01 Time taken per iteration: 0.011075019836425781
# Step: 4730 Loss: 0.0526529923081398 KL_div:0.42894938588142395 current_lr:0.01 Time taken per iteration: 0.007554531097412109
# Step: 4740 Loss: 0.052652813494205475 KL_div:0.4289480745792389 current_lr:0.01 Time taken per iteration: 0.010297536849975586
# Step: 4750 Loss: 0.05265270173549652 KL_div:0.42894744873046875 current_lr:0.01 Time taken per iteration: 0.008540153503417969
# Step: 4760 Loss: 0.05265270173549652 KL_div:0.4289475679397583 current_lr:0.01 Time taken per iteration: 0.008955240249633789
# Step: 4770 Loss: 0.05265248194336891 KL_div:0.42894604802131653 current_lr:0.01 Time taken per iteration: 0.00893402099609375
# Step: 4780 Loss: 0.05265241116285324 KL_div:0.4289456605911255 current_lr:0.01 Time taken per iteration: 0.009083032608032227
# Step: 4790 Loss: 0.05265219509601593 KL_div:0.42894428968429565 current_lr:0.01 Time taken per iteration: 0.005377531051635742
# Step: 4800 Loss: 0.05265219882130623 KL_div:0.42894431948661804 current_lr:0.01 Time taken per iteration: 0.008889436721801758
# Step: 4810 Loss: 0.05265197902917862 KL_div:0.42894285917282104 current_lr:0.01 Time taken per iteration: 0.006468772888183594
# Step: 4820 Loss: 0.05265192687511444 KL_div:0.42894256114959717 current_lr:0.01 Time taken per iteration: 0.006132364273071289
# Step: 4830 Loss: 0.052651796489953995 KL_div:0.4289408028125763 current_lr:0.01 Time taken per iteration: 0.007966756820678711
# Step: 4840 Loss: 0.052660852670669556 KL_div:0.42898041009902954 current_lr:0.01 Time taken per iteration: 0.003541231155395508
# Step: 4850 Loss: 0.05265669897198677 KL_div:0.42896777391433716 current_lr:0.01 Time taken per iteration: 0.0058612823486328125
# Step: 4860 Loss: 0.052669212222099304 KL_div:0.42905426025390625 current_lr:0.01 Time taken per iteration: 0.004916191101074219
# Step: 4870 Loss: 0.05265258997678757 KL_div:0.4289451539516449 current_lr:0.01 Time taken per iteration: 0.01032876968383789
# Step: 4880 Loss: 0.05265123397111893 KL_div:0.42893821001052856 current_lr:0.01 Time taken per iteration: 0.00462794303894043
# Step: 4890 Loss: 0.052651457488536835 KL_div:0.4289397895336151 current_lr:0.01 Time taken per iteration: 0.006571292877197266
# Step: 4900 Loss: 0.05265136808156967 KL_div:0.4289388656616211 current_lr:0.01 Time taken per iteration: 0.008644819259643555
# Step: 4910 Loss: 0.052651070058345795 KL_div:0.4289371371269226 current_lr:0.01 Time taken per iteration: 0.011619329452514648
# Step: 4920 Loss: 0.052650827914476395 KL_div:0.4289356768131256 current_lr:0.01 Time taken per iteration: 0.004567384719848633
# Step: 4930 Loss: 0.05265058949589729 KL_div:0.4289339780807495 current_lr:0.01 Time taken per iteration: 0.01026463508605957
# Step: 4940 Loss: 0.05265069007873535 KL_div:0.4289347529411316 current_lr:0.01 Time taken per iteration: 0.007157087326049805
# Step: 4950 Loss: 0.05265069380402565 KL_div:0.4289347529411316 current_lr:0.01 Time taken per iteration: 0.005739688873291016
# Step: 4960 Loss: 0.05265037715435028 KL_div:0.4289326071739197 current_lr:0.01 Time taken per iteration: 0.006543636322021484
# Step: 4970 Loss: 0.05265025421977043 KL_div:0.4289318919181824 current_lr:0.01 Time taken per iteration: 0.0077419281005859375
# Step: 4980 Loss: 0.052650146186351776 KL_div:0.4289313554763794 current_lr:0.01 Time taken per iteration: 0.0073888301849365234
# Step: 4990 Loss: 0.052650224417448044 KL_div:0.4289318323135376 current_lr:0.01 Time taken per iteration: 0.007590055465698242
# Step: 5000 Loss: 0.05265011638402939 KL_div:0.4289310574531555 current_lr:0.01 Time taken per iteration: 0.004036664962768555

# %%
fig, axs = plt.subplots(1,2,figsize=(15,8))
axs[0].plot(divs)
axs[0].title.set_text('KL Divergence')

axs[1].plot(history)
axs[1].title.set_text('loss')

# %%
optimal_params = parameters[np.argmin(divs)]
qcbm_probs = circuit(optimal_params)
x_full = jnp.arange(0,2**n_qubits,dtype=jnp.float64)

fig, axs = plt.subplots(1,2,figsize=(15,5))
axs[0].bar(x_full,qcbm_probs[0],color='green',alpha=0.5,label='Obtained Distribution')
axs[0].plot(x_full,target_distribution1,color='blue',alpha=0.5,label='Target Distribution')
axs[0].legend()
axs[0].set_title('1111 Distribution')
axs[0].set_xlabel('Hilbert Space')
axs[0].set_ylabel('Probability Distribution')

axs[1].bar(x_full,qcbm_probs[1],color='red',alpha=0.5,label='Obtained Distribution')
axs[1].plot(x_full,target_distribution2,color='blue',alpha=0.5,label='Target Distribution')
axs[1].legend()
axs[1].set_title('0000 Distribution')
axs[1].set_xlabel('Hilbert Space')
axs[1].set_ylabel('Probability Distribution')
# Out:
# Text(0, 0.5, 'Probability Distribution')

# %%
print(f"Minimum KL Divergence obtained is {np.min(divs)}")
# Out:
# Minimum KL Divergence obtained is 0.4289291501045227

# %%
dev = qml.device("default.qubit",wires=n_qubits)

@qml.qnode(dev,interface='jax')
def output_vqc_circuit(input_params,n_qubits=4):
    # uniform_init(num_qubits,cat_pre_training,seed=0)
    params = input_params[0]
    for i in range(vqc_folds):
        vqc_circuit(params[i])
    return qml.probs(wires=range(n_qubits))

qml.draw_mpl(output_vqc_circuit)(optimal_params)
plt.show()

# %%
hybrid_output = output_vqc_circuit(optimal_params,n_qubits)

# %%
fig, axs = plt.subplots(1,2,figsize=(15,5))
axs[0].plot(x_full,hybrid_output,label='Generated Cat')
axs[0].legend()
axs[0].set_title('Generated Cat Distribution')
axs[0].set_xlabel('Hilbert Space')
axs[0].set_ylabel('Probability Distribution')

axs[1].plot(x_full,cat_data,label='Original Cat')
axs[1].legend()
axs[1].set_title('Original Cat Distribution')
axs[1].set_xlabel('Hilbert Space')
axs[1].set_ylabel('Probability Distribution')
# Out:
# Text(0, 0.5, 'Probability Distribution')

# %%
x = jnp.arange(0,n_qubits+1,dtype=jnp.float64)
fig, axs = plt.subplots(1,2,figsize=(15,5))
axs[0].bar(x,pnumber_distribution(hybrid_output,n_qubits),color='green',alpha=0.5,label='Generated Cat')
axs[0].legend()
axs[0].set_title('Generated Cat Distribution')
axs[0].set_xlabel('Particle Number')
axs[0].set_ylabel('Particle Number Distribution')

axs[1].bar(x,pnumber_distribution(cat_data,n_qubits),color='red',alpha=0.5,label='Original Cat')
axs[1].legend()
axs[1].set_title('Original Cat Distribution')
axs[1].set_xlabel('Particle Number')
axs[1].set_ylabel('Particle Number Distribution')
# Out:
# Text(0, 0.5, 'Particle Number Distribution')

# %%
# #Save Checkpoint
# checkpoint = {"final_epoch":i,
#               "history":history,
#               "divs":divs,
#               "parameters":parameters}

# with open(f'model_cat_anticat_distribution.pkl','wb') as file:
#     pickle.dump(checkpoint,file)
    
# print("Model saved successfully")
