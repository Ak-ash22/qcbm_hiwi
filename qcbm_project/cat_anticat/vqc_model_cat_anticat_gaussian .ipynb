# %%
from vqc_model_gaussian import *

from jax.lib import xla_bridge
jax.experimental.enable_x64()
print("JAX Backend:", xla_bridge.get_backend().platform)
# Out:
# JAX Backend: gpu

# %%
# Visualizing Original Cat Distribution
plt.plot(cat_data, label='Target Distribution')
plt.xlabel("Hilbert Space",fontsize=12)
plt.ylabel("Probability Distribution",fontsize=12)
plt.title("Gaussian Distribution",fontsize=14)
plt.legend()

# %%
# Visualizing Original AntiCat Distribution
plt.plot(anticat_data, label='Anticat Distribution')
plt.xlabel("Hilbert Space")
plt.ylabel("Probability Distribution")
plt.title("Anticat of Gaussian Distribution")
plt.legend()

# %%
qml.draw_mpl(circuit,device='default')(input_params=initial_params)
plt.show()

# %% [markdown]
# ### Cells to be run if the target_distribution corresponds to superposition of all half filled states

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations


# Number of qubits
num_qubits = 8

# Generate all binary states with exactly 4 ones
valid_states = ["".join("1" if i in comb else "0" for i in range(num_qubits)) 
                for comb in combinations(range(num_qubits), 4)]

# Convert binary states to decimal indices
valid_indices = [int(state, 2) for state in valid_states]

# Create target distribution
target_distribution = np.zeros(2**num_qubits)
for index in valid_indices:
    target_distribution[index] = 1  # Assign probability 1 to valid states

# Normalize the distribution
target_distribution /= np.sum(target_distribution)

# Plot the target distribution
plt.figure(figsize=(10, 5))
plt.plot(target_distribution, linestyle="-", label="Superposition of 4 Ones & 4 Zeros")
plt.xlabel("State Index")
plt.ylabel("Probability")
plt.title("Target Distribution for 4-Ones-4-Zeros Superposition")
plt.legend()
plt.show()

# %%
class MMD:
    def __init__(self,scales,space):
        gammas = 1/(2*(scales**2)).reshape(-1,1,1)
        sq_dists = jnp.abs(space[:,None] - space[None,:])**2
        self.K = jnp.sum(jnp.exp(-gammas * sq_dists), axis=0)/len(scales)
        self.scales = scales
        
    def k_expval(self,px,py):
        return px @ self.K @ py
    
    def __call__(self,px,py):
        pxy = px-py
        return self.k_expval(pxy,pxy)
    
class QCBM:
    def __init__(self,circ,mmd,py):
        self.circ = circ
        self.mmd = mmd
        self.py = py
    
    def mmd_loss(self,params):
        px = self.circ(params)
        loss = self.mmd(px,self.py)

        return loss, px
    

#Model Training
@jit
def update_step(params,opt_state):
    
    (total_loss_val,qcbm_probs), grads = jax.value_and_grad(qcbm.mmd_loss,has_aux=True)(params)

    updates,opt_state = opt.update(grads,opt_state)
    params = optax.apply_updates(params,updates)
    
    qcbm_probs = jnp.asarray(qcbm_probs, dtype=jnp.float64)
    
    kl_div = -jnp.sum(target_distribution * jnp.nan_to_num(jnp.log(qcbm_probs) - jnp.log(target_distribution)))
    
    total_kl_div = kl_div
    
    return params, opt_state, total_loss_val, total_kl_div

# %%
#Calling MMD class
bandwidth = jnp.array([0.25,60],dtype=jnp.float64)
space = jnp.arange(0,2**total_qubits,dtype=jnp.float64)
mmd = MMD(bandwidth,space=space)


#Calling QCBM class to run the previous built circuit with random weights
qcbm = QCBM(circuit,mmd=mmd,py=target_distribution)


#Initial parameters
weights = initial_params
lr = optax.exponential_decay(init_value=0.1,transition_steps=10,decay_rate=0.99,transition_begin=300,end_value=0.025,staircase=True)
# lr = 0.01
opt = optax.adam(learning_rate=lr)
opt_state = opt.init(weights)


history = []
divs = []
parameters = []


kl_div = 1
i = 0
# i = start_epoch

# while kl_div > 10^-3:
while i < 5001:
    i+=1
    current_lr = lr(i)
    # current_lr = lr
    start_time = time.time()
    weights, opt_state, loss_val, kl_div = update_step(params=weights,opt_state=opt_state)
    end_time = time.time()
    
    if i%10==0:
        print(f"Step: {i} Loss: {loss_val} KL_div:{kl_div} current_lr:{current_lr} Time taken per iteration: {end_time-start_time}")
    
    history.append(loss_val)
    divs.append(kl_div)
    parameters.append(weights)
# Out:
# ---------------------------------------------------------------------------
# TracerArrayConversionError                Traceback (most recent call last)
# Cell In[8], line 34
#      32 # current_lr = lr
#      33 start_time = time.time()
# ---> 34 weights, opt_state, loss_val, kl_div = update_step(params=weights,opt_state=opt_state)
#      35 end_time = time.time()
#      37 if i%10==0:
#
#     [... skipping hidden 13 frame]
#
# Cell In[7], line 32, in update_step(params, opt_state)
#      29 @jit
#      30 def update_step(params,opt_state):
# ---> 32     (total_loss_val,qcbm_probs), grads = jax.value_and_grad(qcbm.mmd_loss,has_aux=True)(params)
#      34     updates,opt_state = opt.update(grads,opt_state)
#      35     params = optax.apply_updates(params,updates)
#
#     [... skipping hidden 16 frame]
#
# Cell In[7], line 23, in QCBM.mmd_loss(self, params)
#      21 def mmd_loss(self,params):
#      22     px = self.circ(params)
# ---> 23     loss = self.mmd(px,self.py)
#      25     return loss, px
#
# Cell In[7], line 12, in MMD.__call__(self, px, py)
#      11 def __call__(self,px,py):
# ---> 12     pxy = px-py
#      13     return self.k_expval(pxy,pxy)
#
# File ~/mambaforge/envs/pennylane/lib/python3.12/site-packages/jax/_src/core.py:756, in Tracer.__array__(self, *args, **kw)
#     755 def __array__(self, *args, **kw):
# --> 756   raise TracerArrayConversionError(self)
#
# TracerArrayConversionError: The numpy.ndarray conversion method __array__() was called on traced array with shape float32[16]
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.TracerArrayConversionError

# %%
print(f"Minimum KL Divergence obtained is {np.min(divs)}")
# Out:
# Minimum KL Divergence obtained is 0.49561136960983276

# %%
fig, axs = plt.subplots(1,2,figsize=(15,8))
axs[0].plot(divs)
axs[0].title.set_text('KL Divergence')

axs[1].plot(history)
axs[1].title.set_text('loss')

# %%
optimal_params = parameters[np.argmin(divs)]

qcbm_probs = circuit(optimal_params)
x_array = jnp.arange(0,2**(total_qubits),dtype=jnp.float64)


plt.bar(x_array,qcbm_probs,color='green',alpha=0.5,label='Obtained Cat')
plt.plot(x_array,target_distribution,color='blue',alpha=0.5,label='Original Cat')
plt.xlabel("Hilbert Space")
plt.ylabel("Probability Distribution")
plt.title("Cat Distribution")
plt.legend()
plt.show()

# %% [markdown]
# ### Cells to be run if target_distribution is only 10101010

# %%
# import numpy as np

# Target binary pattern
target_binary = "10101010"

#Odd Numbered Qubits
target_binary1 = '1111'

#Even Numbered Qubits
target_binary2 = '0000'

# Convert binary to decimal index
target_index1 = int(target_binary1, 2)
target_index2 = int(target_binary2, 2)

# Create a one-hot encoded target distribution
num_qubits = 4
target_distribution1 = np.zeros(2**num_qubits)
target_distribution1[target_index1] = 1

target_distribution2 = np.zeros(2**num_qubits)
target_distribution2[target_index2] = 1

# plt.subplot(1, 2, 1)
plt.plot(target_distribution1)
# plt.plot(target_distribution2)

# %%
class MMD:
    def __init__(self,scales,space):
        gammas = 1/(2*(scales**2)).reshape(-1,1,1)
        sq_dists = jnp.abs(space[:,None] - space[None,:])**2
        self.K = jnp.sum(jnp.exp(-gammas * sq_dists), axis=0)/len(scales)
        self.scales = scales
        
    def k_expval(self,px,py):
        return px @ self.K @ py
    
    def __call__(self,px,py):
        pxy = px-py
        return self.k_expval(pxy,pxy)
    
class QCBM:
    def __init__(self,circ,mmd1,mmd2,py1,py2):
        self.circ = circ
        self.mmd1 = mmd1
        self.mmd2 = mmd2
        self.py1 = py1
        self.py2 = py2
    
    def mmd_loss(self,params):
        px = self.circ(params)
        loss1 = self.mmd1(px[0],self.py1)
        loss2 = self.mmd2(px[1],self.py2)
        
        return loss1+loss2, px
    

#Model Training
@jit
def update_step(params,opt_state):
    
    (total_loss_val,qcbm_probs), grads = jax.value_and_grad(qcbm.mmd_loss,has_aux=True)(params)

    updates,opt_state = opt.update(grads,opt_state)
    params = optax.apply_updates(params,updates)
    
    qcbm_probs1 = jnp.asarray(qcbm_probs[0], dtype=jnp.float64)
    qcbm_probs2 = jnp.asarray(qcbm_probs[1], dtype=jnp.float64)
    
    kl_div1 = -jnp.sum(target_distribution1 * jnp.nan_to_num(jnp.log(qcbm_probs1) - jnp.log(target_distribution1)))
    kl_div2 = -jnp.sum(target_distribution2 * jnp.nan_to_num(jnp.log(qcbm_probs2) - jnp.log(target_distribution2)))
    
    total_kl_div = kl_div1 + kl_div2
    
    return params, opt_state, total_loss_val, total_kl_div

# %%
#Calling MMD class
bandwidth = jnp.array([0.25,60],dtype=jnp.float64)
space = jnp.arange(0,2**n_qubits,dtype=jnp.float64)
mmd1 = MMD(bandwidth,space=space)
mmd2 = MMD(bandwidth,space=space)


#Calling QCBM class to run the previous built circuit with random weights
qcbm = QCBM(circuit,mmd1=mmd1,mmd2=mmd2,py1=target_distribution1,py2=target_distribution2)


#Initial parameters
weights = initial_params
# lr = optax.exponential_decay(init_value=0.1,transition_steps=10,decay_rate=0.99,transition_begin=300,end_value=0.005,staircase=True)
lr = 0.01
opt = optax.adam(learning_rate=lr)
opt_state = opt.init(weights)


history = []
divs = []
parameters = []


kl_div = 1
i = 0
# i = start_epoch

# while kl_div > 10^-3:
while i < 5001:
    i+=1
    # current_lr = lr(i)
    current_lr = lr
    start_time = time.time()
    weights, opt_state, loss_val, kl_div = update_step(params=weights,opt_state=opt_state)
    end_time = time.time()
    
    if i%10==0:
        print(f"Step: {i} Loss: {loss_val} KL_div:{kl_div} current_lr:{current_lr} Time taken per iteration: {end_time-start_time}")
    
    history.append(loss_val)
    divs.append(kl_div)
    parameters.append(weights)
# Out:
# Step: 10 Loss: 0.8493881225585938 KL_div:4.314406871795654 current_lr:0.01 Time taken per iteration: 0.02825331687927246
# Step: 20 Loss: 0.7792155742645264 KL_div:3.746431827545166 current_lr:0.01 Time taken per iteration: 0.006741046905517578
# Step: 30 Loss: 0.7261190414428711 KL_div:3.3845367431640625 current_lr:0.01 Time taken per iteration: 0.0076220035552978516
# Step: 40 Loss: 0.6750195026397705 KL_div:3.0827393531799316 current_lr:0.01 Time taken per iteration: 0.01009225845336914
# Step: 50 Loss: 0.6136367321014404 KL_div:2.7594809532165527 current_lr:0.01 Time taken per iteration: 0.011411905288696289
# Step: 60 Loss: 0.5421525239944458 KL_div:2.4273581504821777 current_lr:0.01 Time taken per iteration: 0.009979963302612305
# Step: 70 Loss: 0.47509050369262695 KL_div:2.145548105239868 current_lr:0.01 Time taken per iteration: 0.012900352478027344
# Step: 80 Loss: 0.40519553422927856 KL_div:1.861100435256958 current_lr:0.01 Time taken per iteration: 0.01396799087524414
# Step: 90 Loss: 0.30824434757232666 KL_div:1.4894285202026367 current_lr:0.01 Time taken per iteration: 0.009939193725585938
# Step: 100 Loss: 0.19992157816886902 KL_div:1.0912823677062988 current_lr:0.01 Time taken per iteration: 0.007291555404663086
# Step: 110 Loss: 0.13732606172561646 KL_div:0.858035683631897 current_lr:0.01 Time taken per iteration: 0.006344318389892578
# Step: 120 Loss: 0.10783736407756805 KL_div:0.7411023378372192 current_lr:0.01 Time taken per iteration: 0.006916046142578125
# Step: 130 Loss: 0.08768577128648758 KL_div:0.6561665534973145 current_lr:0.01 Time taken per iteration: 0.006907224655151367
# Step: 140 Loss: 0.07267406582832336 KL_div:0.5892065763473511 current_lr:0.01 Time taken per iteration: 0.007206916809082031
# Step: 150 Loss: 0.06022260710597038 KL_div:0.5294129848480225 current_lr:0.01 Time taken per iteration: 0.006478786468505859
# Step: 160 Loss: 0.04962533339858055 KL_div:0.4742201566696167 current_lr:0.01 Time taken per iteration: 0.007208347320556641
# Step: 170 Loss: 0.040704093873500824 KL_div:0.42361748218536377 current_lr:0.01 Time taken per iteration: 0.006940364837646484
# Step: 180 Loss: 0.03371346741914749 KL_div:0.3802942633628845 current_lr:0.01 Time taken per iteration: 0.00704646110534668
# Step: 190 Loss: 0.028721123933792114 KL_div:0.34671318531036377 current_lr:0.01 Time taken per iteration: 0.0076754093170166016
# Step: 200 Loss: 0.025353409349918365 KL_div:0.3225640654563904 current_lr:0.01 Time taken per iteration: 0.009570837020874023
# Step: 210 Loss: 0.023028500378131866 KL_div:0.3051055669784546 current_lr:0.01 Time taken per iteration: 0.007771968841552734
# Step: 220 Loss: 0.02127121016383171 KL_div:0.29141104221343994 current_lr:0.01 Time taken per iteration: 0.008097410202026367
# Step: 230 Loss: 0.019812053069472313 KL_div:0.27961796522140503 current_lr:0.01 Time taken per iteration: 0.008983373641967773
# Step: 240 Loss: 0.018535379320383072 KL_div:0.2688865661621094 current_lr:0.01 Time taken per iteration: 0.007288217544555664
# Step: 250 Loss: 0.017399320378899574 KL_div:0.2589312791824341 current_lr:0.01 Time taken per iteration: 0.010826587677001953
# Step: 260 Loss: 0.016387667506933212 KL_div:0.24968239665031433 current_lr:0.01 Time taken per iteration: 0.00927281379699707
# Step: 270 Loss: 0.01548861339688301 KL_div:0.24111145734786987 current_lr:0.01 Time taken per iteration: 0.006803035736083984
# Step: 280 Loss: 0.014690703712403774 KL_div:0.23318922519683838 current_lr:0.01 Time taken per iteration: 0.011147260665893555
# Step: 290 Loss: 0.01398206502199173 KL_div:0.22587166726589203 current_lr:0.01 Time taken per iteration: 0.00722050666809082
# Step: 300 Loss: 0.013351589441299438 KL_div:0.21910828351974487 current_lr:0.01 Time taken per iteration: 0.009818553924560547
# Step: 310 Loss: 0.012788965366780758 KL_div:0.21284328401088715 current_lr:0.01 Time taken per iteration: 0.0069293975830078125
# Step: 320 Loss: 0.012285906821489334 KL_div:0.2070315182209015 current_lr:0.01 Time taken per iteration: 0.010153532028198242
# Step: 330 Loss: 0.011834903620183468 KL_div:0.20162749290466309 current_lr:0.01 Time taken per iteration: 0.00846099853515625
# Step: 340 Loss: 0.011430841870605946 KL_div:0.19660663604736328 current_lr:0.01 Time taken per iteration: 0.007587432861328125
# Step: 350 Loss: 0.01106893178075552 KL_div:0.19194360077381134 current_lr:0.01 Time taken per iteration: 0.008099555969238281
# Step: 360 Loss: 0.010745537467300892 KL_div:0.18762362003326416 current_lr:0.01 Time taken per iteration: 0.007025480270385742
# Step: 370 Loss: 0.010457688011229038 KL_div:0.18363764882087708 current_lr:0.01 Time taken per iteration: 0.008445024490356445
# Step: 380 Loss: 0.010202786885201931 KL_div:0.1799795925617218 current_lr:0.01 Time taken per iteration: 0.008262872695922852
# Step: 390 Loss: 0.00997831765562296 KL_div:0.17664307355880737 current_lr:0.01 Time taken per iteration: 0.0071659088134765625
# Step: 400 Loss: 0.009781538508832455 KL_div:0.17361710965633392 current_lr:0.01 Time taken per iteration: 0.0075223445892333984
# Step: 410 Loss: 0.009610071778297424 KL_div:0.17089375853538513 current_lr:0.01 Time taken per iteration: 0.007051944732666016
# Step: 420 Loss: 0.009460845962166786 KL_div:0.16845297813415527 current_lr:0.01 Time taken per iteration: 0.006626129150390625
# Step: 430 Loss: 0.009331142529845238 KL_div:0.1662767082452774 current_lr:0.01 Time taken per iteration: 0.007497072219848633
# Step: 440 Loss: 0.009218288585543633 KL_div:0.16434404253959656 current_lr:0.01 Time taken per iteration: 0.006891489028930664
# Step: 450 Loss: 0.009119423106312752 KL_div:0.1626281440258026 current_lr:0.01 Time taken per iteration: 0.007077217102050781
# Step: 460 Loss: 0.00903239194303751 KL_div:0.16110870242118835 current_lr:0.01 Time taken per iteration: 0.007311582565307617
# Step: 470 Loss: 0.00895503256469965 KL_div:0.15976224839687347 current_lr:0.01 Time taken per iteration: 0.007189035415649414
# Step: 480 Loss: 0.00888572633266449 KL_div:0.15857024490833282 current_lr:0.01 Time taken per iteration: 0.006799936294555664
# Step: 490 Loss: 0.008822989650070667 KL_div:0.15751433372497559 current_lr:0.01 Time taken per iteration: 0.007515907287597656
# Step: 500 Loss: 0.008765678852796555 KL_div:0.15657879412174225 current_lr:0.01 Time taken per iteration: 0.0064275264739990234
# Step: 510 Loss: 0.00871285144239664 KL_div:0.15574975311756134 current_lr:0.01 Time taken per iteration: 0.0065534114837646484
# Step: 520 Loss: 0.008663812652230263 KL_div:0.15501606464385986 current_lr:0.01 Time taken per iteration: 0.006958723068237305
# Step: 530 Loss: 0.008618139661848545 KL_div:0.15436951816082 current_lr:0.01 Time taken per iteration: 0.007541656494140625
# Step: 540 Loss: 0.008575409650802612 KL_div:0.15380173921585083 current_lr:0.01 Time taken per iteration: 0.009302854537963867
# Step: 550 Loss: 0.008535104803740978 KL_div:0.15330222249031067 current_lr:0.01 Time taken per iteration: 0.007673501968383789
# Step: 560 Loss: 0.008497091010212898 KL_div:0.1528662145137787 current_lr:0.01 Time taken per iteration: 0.006910562515258789
# Step: 570 Loss: 0.008461211808025837 KL_div:0.1524883508682251 current_lr:0.01 Time taken per iteration: 0.00653839111328125
# Step: 580 Loss: 0.008427239023149014 KL_div:0.15216225385665894 current_lr:0.01 Time taken per iteration: 0.006721019744873047
# Step: 590 Loss: 0.008395250886678696 KL_div:0.15188589692115784 current_lr:0.01 Time taken per iteration: 0.006617546081542969
# Step: 600 Loss: 0.008364778943359852 KL_div:0.15164923667907715 current_lr:0.01 Time taken per iteration: 0.006718873977661133
# Step: 610 Loss: 0.008335964754223824 KL_div:0.1514514535665512 current_lr:0.01 Time taken per iteration: 0.006847381591796875
# Step: 620 Loss: 0.00830882042646408 KL_div:0.15128988027572632 current_lr:0.01 Time taken per iteration: 0.007226705551147461
# Step: 630 Loss: 0.008282904513180256 KL_div:0.1511550098657608 current_lr:0.01 Time taken per iteration: 0.017839908599853516
# Step: 640 Loss: 0.008258622139692307 KL_div:0.1510503590106964 current_lr:0.01 Time taken per iteration: 0.011611700057983398
# Step: 650 Loss: 0.008235503919422626 KL_div:0.15096646547317505 current_lr:0.01 Time taken per iteration: 0.009358644485473633
# Step: 660 Loss: 0.008213820867240429 KL_div:0.15090525150299072 current_lr:0.01 Time taken per iteration: 0.011077642440795898
# Step: 670 Loss: 0.008193355053663254 KL_div:0.15086135268211365 current_lr:0.01 Time taken per iteration: 0.006709575653076172
# Step: 680 Loss: 0.008174196816980839 KL_div:0.15083442628383636 current_lr:0.01 Time taken per iteration: 0.0078105926513671875
# Step: 690 Loss: 0.008156117051839828 KL_div:0.150819331407547 current_lr:0.01 Time taken per iteration: 0.010627985000610352
# Step: 700 Loss: 0.008139220997691154 KL_div:0.15081645548343658 current_lr:0.01 Time taken per iteration: 0.008172035217285156
# Step: 710 Loss: 0.008123324252665043 KL_div:0.15082190930843353 current_lr:0.01 Time taken per iteration: 0.008395910263061523
# Step: 720 Loss: 0.008108221925795078 KL_div:0.15083155035972595 current_lr:0.01 Time taken per iteration: 0.006938457489013672
# Step: 730 Loss: 0.008094345219433308 KL_div:0.15085141360759735 current_lr:0.01 Time taken per iteration: 0.006788730621337891
# Step: 740 Loss: 0.008081093430519104 KL_div:0.15087172389030457 current_lr:0.01 Time taken per iteration: 0.009655237197875977
# Step: 750 Loss: 0.008068792521953583 KL_div:0.1508970707654953 current_lr:0.01 Time taken per iteration: 0.007179737091064453
# Step: 760 Loss: 0.008057225495576859 KL_div:0.15092426538467407 current_lr:0.01 Time taken per iteration: 0.006872653961181641
# Step: 770 Loss: 0.00804628524929285 KL_div:0.15095138549804688 current_lr:0.01 Time taken per iteration: 0.007014751434326172
# Step: 780 Loss: 0.008036050945520401 KL_div:0.15097971260547638 current_lr:0.01 Time taken per iteration: 0.008399248123168945
# Step: 790 Loss: 0.008026400581002235 KL_div:0.15100759267807007 current_lr:0.01 Time taken per iteration: 0.007506608963012695
# Step: 800 Loss: 0.008017178624868393 KL_div:0.15103289484977722 current_lr:0.01 Time taken per iteration: 0.006576061248779297
# Step: 810 Loss: 0.008008433505892754 KL_div:0.15105658769607544 current_lr:0.01 Time taken per iteration: 0.006846904754638672
# Step: 820 Loss: 0.008000312373042107 KL_div:0.15108147263526917 current_lr:0.01 Time taken per iteration: 0.0069980621337890625
# Step: 830 Loss: 0.007992330007255077 KL_div:0.151100292801857 current_lr:0.01 Time taken per iteration: 0.009966850280761719
# Step: 840 Loss: 0.007984835654497147 KL_div:0.1511189490556717 current_lr:0.01 Time taken per iteration: 0.00697779655456543
# Step: 850 Loss: 0.00797767098993063 KL_div:0.15113551914691925 current_lr:0.01 Time taken per iteration: 0.006781101226806641
# Step: 860 Loss: 0.007970753125846386 KL_div:0.15114900469779968 current_lr:0.01 Time taken per iteration: 0.007380962371826172
# Step: 870 Loss: 0.007963919080793858 KL_div:0.15115758776664734 current_lr:0.01 Time taken per iteration: 0.006525993347167969
# Step: 880 Loss: 0.00795740820467472 KL_div:0.15116532146930695 current_lr:0.01 Time taken per iteration: 0.006719827651977539
# Step: 890 Loss: 0.007951054722070694 KL_div:0.15117013454437256 current_lr:0.01 Time taken per iteration: 0.006557941436767578
# Step: 900 Loss: 0.007944691926240921 KL_div:0.15117007493972778 current_lr:0.01 Time taken per iteration: 0.007432699203491211
# Step: 910 Loss: 0.00793853122740984 KL_div:0.1511687934398651 current_lr:0.01 Time taken per iteration: 0.006954193115234375
# Step: 920 Loss: 0.007932215929031372 KL_div:0.15116120874881744 current_lr:0.01 Time taken per iteration: 0.008135080337524414
# Step: 930 Loss: 0.00792605895549059 KL_div:0.15115287899971008 current_lr:0.01 Time taken per iteration: 0.0073621273040771484
# Step: 940 Loss: 0.007919845171272755 KL_div:0.1511407196521759 current_lr:0.01 Time taken per iteration: 0.011310338973999023
# Step: 950 Loss: 0.007913625799119473 KL_div:0.15112625062465668 current_lr:0.01 Time taken per iteration: 0.00706934928894043
# Step: 960 Loss: 0.007907247170805931 KL_div:0.1511075645685196 current_lr:0.01 Time taken per iteration: 0.006918430328369141
# Step: 970 Loss: 0.007900728844106197 KL_div:0.15108570456504822 current_lr:0.01 Time taken per iteration: 0.010644197463989258
# Step: 980 Loss: 0.0078939413651824 KL_div:0.151059091091156 current_lr:0.01 Time taken per iteration: 0.0199129581451416
# Step: 990 Loss: 0.007886976934969425 KL_div:0.15103012323379517 current_lr:0.01 Time taken per iteration: 0.00672602653503418
# Step: 1000 Loss: 0.007879660464823246 KL_div:0.15099680423736572 current_lr:0.01 Time taken per iteration: 0.009999990463256836
# Step: 1010 Loss: 0.007871939800679684 KL_div:0.15095920860767365 current_lr:0.01 Time taken per iteration: 0.009083986282348633
# Step: 1020 Loss: 0.007863902486860752 KL_div:0.1509198248386383 current_lr:0.01 Time taken per iteration: 0.007702827453613281
# Step: 1030 Loss: 0.007855155505239964 KL_div:0.15087389945983887 current_lr:0.01 Time taken per iteration: 0.007207393646240234
# Step: 1040 Loss: 0.007845786400139332 KL_div:0.1508243978023529 current_lr:0.01 Time taken per iteration: 0.01677250862121582
# Step: 1050 Loss: 0.007835641503334045 KL_div:0.15077091753482819 current_lr:0.01 Time taken per iteration: 0.009619712829589844
# Step: 1060 Loss: 0.007824379950761795 KL_div:0.15071070194244385 current_lr:0.01 Time taken per iteration: 0.009638309478759766
# Step: 1070 Loss: 0.0078117200173437595 KL_div:0.15064269304275513 current_lr:0.01 Time taken per iteration: 0.007315874099731445
# Step: 1080 Loss: 0.007797651924192905 KL_div:0.15057078003883362 current_lr:0.01 Time taken per iteration: 0.0068817138671875
# Step: 1090 Loss: 0.00778156379237771 KL_div:0.15049095451831818 current_lr:0.01 Time taken per iteration: 0.008114099502563477
# Step: 1100 Loss: 0.007762858644127846 KL_div:0.15040111541748047 current_lr:0.01 Time taken per iteration: 0.007345676422119141
# Step: 1110 Loss: 0.007740846369415522 KL_div:0.15030033886432648 current_lr:0.01 Time taken per iteration: 0.008461475372314453
# Step: 1120 Loss: 0.007714688777923584 KL_div:0.15018847584724426 current_lr:0.01 Time taken per iteration: 0.0106658935546875
# Step: 1130 Loss: 0.007682946976274252 KL_div:0.1500612199306488 current_lr:0.01 Time taken per iteration: 0.006611347198486328
# Step: 1140 Loss: 0.007643692195415497 KL_div:0.14991283416748047 current_lr:0.01 Time taken per iteration: 0.007158041000366211
# Step: 1150 Loss: 0.007594441995024681 KL_div:0.14973798394203186 current_lr:0.01 Time taken per iteration: 0.006742238998413086
# Step: 1160 Loss: 0.007531594485044479 KL_div:0.14952559769153595 current_lr:0.01 Time taken per iteration: 0.007725238800048828
# Step: 1170 Loss: 0.007450342644006014 KL_div:0.1492597460746765 current_lr:0.01 Time taken per iteration: 0.007261753082275391
# Step: 1180 Loss: 0.007344102952629328 KL_div:0.14891105890274048 current_lr:0.01 Time taken per iteration: 0.007147312164306641
# Step: 1190 Loss: 0.007205000147223473 KL_div:0.14843760430812836 current_lr:0.01 Time taken per iteration: 0.007834196090698242
# Step: 1200 Loss: 0.007024385500699282 KL_div:0.14777156710624695 current_lr:0.01 Time taken per iteration: 0.010896921157836914
# Step: 1210 Loss: 0.006796667352318764 KL_div:0.14683659374713898 current_lr:0.01 Time taken per iteration: 0.006924867630004883
# Step: 1220 Loss: 0.0065238079987466335 KL_div:0.1455591320991516 current_lr:0.01 Time taken per iteration: 0.006423473358154297
# Step: 1230 Loss: 0.006221471354365349 KL_div:0.14393162727355957 current_lr:0.01 Time taken per iteration: 0.00707244873046875
# Step: 1240 Loss: 0.005919125862419605 KL_div:0.1420709639787674 current_lr:0.01 Time taken per iteration: 0.0071790218353271484
# Step: 1250 Loss: 0.005648558959364891 KL_div:0.14018680155277252 current_lr:0.01 Time taken per iteration: 0.0066242218017578125
# Step: 1260 Loss: 0.005430812947452068 KL_div:0.13849826157093048 current_lr:0.01 Time taken per iteration: 0.006670713424682617
# Step: 1270 Loss: 0.005269276909530163 KL_div:0.13712148368358612 current_lr:0.01 Time taken per iteration: 0.00897359848022461
# Step: 1280 Loss: 0.0051546297036111355 KL_div:0.13605795800685883 current_lr:0.01 Time taken per iteration: 0.00718379020690918
# Step: 1290 Loss: 0.005073157139122486 KL_div:0.13524101674556732 current_lr:0.01 Time taken per iteration: 0.006592988967895508
# Step: 1300 Loss: 0.00501230638474226 KL_div:0.13458329439163208 current_lr:0.01 Time taken per iteration: 0.007604122161865234
# Step: 1310 Loss: 0.004964083433151245 KL_div:0.13402850925922394 current_lr:0.01 Time taken per iteration: 0.005842924118041992
# Step: 1320 Loss: 0.004922868683934212 KL_div:0.13352736830711365 current_lr:0.01 Time taken per iteration: 0.0065174102783203125
# Step: 1330 Loss: 0.004886130802333355 KL_div:0.13306185603141785 current_lr:0.01 Time taken per iteration: 0.006436347961425781
# Step: 1340 Loss: 0.004852327052503824 KL_div:0.13261938095092773 current_lr:0.01 Time taken per iteration: 0.015102624893188477
# Step: 1350 Loss: 0.004820607136934996 KL_div:0.13219335675239563 current_lr:0.01 Time taken per iteration: 0.006563425064086914
# Step: 1360 Loss: 0.004790219012647867 KL_div:0.1317758858203888 current_lr:0.01 Time taken per iteration: 0.00887441635131836
# Step: 1370 Loss: 0.004760613664984703 KL_div:0.1313609778881073 current_lr:0.01 Time taken per iteration: 0.008466720581054688
# Step: 1380 Loss: 0.004731589462608099 KL_div:0.13094763457775116 current_lr:0.01 Time taken per iteration: 0.00568389892578125
# Step: 1390 Loss: 0.004702389240264893 KL_div:0.130525141954422 current_lr:0.01 Time taken per iteration: 0.006507158279418945
# Step: 1400 Loss: 0.004672683775424957 KL_div:0.130089670419693 current_lr:0.01 Time taken per iteration: 0.007688283920288086
# Step: 1410 Loss: 0.004642115440219641 KL_div:0.12963663041591644 current_lr:0.01 Time taken per iteration: 0.006956815719604492
# Step: 1420 Loss: 0.004610344767570496 KL_div:0.1291615217924118 current_lr:0.01 Time taken per iteration: 0.0065920352935791016
# Step: 1430 Loss: 0.0045768460258841515 KL_div:0.12865640223026276 current_lr:0.01 Time taken per iteration: 0.007246255874633789
# Step: 1440 Loss: 0.004541155882179737 KL_div:0.12811408936977386 current_lr:0.01 Time taken per iteration: 0.007356882095336914
# Step: 1450 Loss: 0.004502783063799143 KL_div:0.12752655148506165 current_lr:0.01 Time taken per iteration: 0.006489992141723633
# Step: 1460 Loss: 0.004461581353098154 KL_div:0.12689141929149628 current_lr:0.01 Time taken per iteration: 0.006954193115234375
# Step: 1470 Loss: 0.004416964948177338 KL_div:0.12619830667972565 current_lr:0.01 Time taken per iteration: 0.007256746292114258
# Step: 1480 Loss: 0.0043685478158295155 KL_div:0.12543979287147522 current_lr:0.01 Time taken per iteration: 0.006481170654296875
# Step: 1490 Loss: 0.0043160393834114075 KL_div:0.1246095597743988 current_lr:0.01 Time taken per iteration: 0.006221771240234375
# Step: 1500 Loss: 0.004259149543941021 KL_div:0.12370090186595917 current_lr:0.01 Time taken per iteration: 0.0059888362884521484
# Step: 1510 Loss: 0.004197650123387575 KL_div:0.12270747125148773 current_lr:0.01 Time taken per iteration: 0.006397247314453125
# Step: 1520 Loss: 0.0041314950212836266 KL_div:0.1216258853673935 current_lr:0.01 Time taken per iteration: 0.006604194641113281
# Step: 1530 Loss: 0.004060401581227779 KL_div:0.12044790387153625 current_lr:0.01 Time taken per iteration: 0.009406328201293945
# Step: 1540 Loss: 0.003984527196735144 KL_div:0.11917288601398468 current_lr:0.01 Time taken per iteration: 0.006503582000732422
# Step: 1550 Loss: 0.0039038551039993763 KL_div:0.11779679358005524 current_lr:0.01 Time taken per iteration: 0.006792783737182617
# Step: 1560 Loss: 0.0038185366429388523 KL_div:0.11631836742162704 current_lr:0.01 Time taken per iteration: 0.009014368057250977
# Step: 1570 Loss: 0.0037286528386175632 KL_div:0.11473498493432999 current_lr:0.01 Time taken per iteration: 0.006473541259765625
# Step: 1580 Loss: 0.0036346130073070526 KL_div:0.1130499392747879 current_lr:0.01 Time taken per iteration: 0.0066280364990234375
# Step: 1590 Loss: 0.0035367831587791443 KL_div:0.11126573383808136 current_lr:0.01 Time taken per iteration: 0.0060977935791015625
# Step: 1600 Loss: 0.003435663413256407 KL_div:0.10938722640275955 current_lr:0.01 Time taken per iteration: 0.00865626335144043
# Step: 1610 Loss: 0.0033318258356302977 KL_div:0.10742056369781494 current_lr:0.01 Time taken per iteration: 0.005935192108154297
# Step: 1620 Loss: 0.0032263346947729588 KL_div:0.10538172721862793 current_lr:0.01 Time taken per iteration: 0.006592750549316406
# Step: 1630 Loss: 0.0031199066434055567 KL_div:0.1032797321677208 current_lr:0.01 Time taken per iteration: 0.008962869644165039
# Step: 1640 Loss: 0.003013982903212309 KL_div:0.10113917291164398 current_lr:0.01 Time taken per iteration: 0.00645756721496582
# Step: 1650 Loss: 0.002909766510128975 KL_div:0.09898079931735992 current_lr:0.01 Time taken per iteration: 0.006242036819458008
# Step: 1660 Loss: 0.002808900084346533 KL_div:0.09683679044246674 current_lr:0.01 Time taken per iteration: 0.006013631820678711
# Step: 1670 Loss: 0.002712693065404892 KL_div:0.094734787940979 current_lr:0.01 Time taken per iteration: 0.006712436676025391
# Step: 1680 Loss: 0.002622389467433095 KL_div:0.09270399063825607 current_lr:0.01 Time taken per iteration: 0.011066675186157227
# Step: 1690 Loss: 0.002538919448852539 KL_div:0.09076958149671555 current_lr:0.01 Time taken per iteration: 0.006558895111083984
# Step: 1700 Loss: 0.002462809206917882 KL_div:0.08895006775856018 current_lr:0.01 Time taken per iteration: 0.006497621536254883
# Step: 1710 Loss: 0.0023942068219184875 KL_div:0.08725675195455551 current_lr:0.01 Time taken per iteration: 0.008809089660644531
# Step: 1720 Loss: 0.0023327930830419064 KL_div:0.08569058030843735 current_lr:0.01 Time taken per iteration: 0.009083271026611328
# Step: 1730 Loss: 0.0022780923172831535 KL_div:0.08424842357635498 current_lr:0.01 Time taken per iteration: 0.006509542465209961
# Step: 1740 Loss: 0.0022296009119600058 KL_div:0.082925945520401 current_lr:0.01 Time taken per iteration: 0.006797075271606445
# Step: 1750 Loss: 0.002186443191021681 KL_div:0.08170831203460693 current_lr:0.01 Time taken per iteration: 0.007386207580566406
# Step: 1760 Loss: 0.0021479788701981306 KL_div:0.08058567345142365 current_lr:0.01 Time taken per iteration: 0.00694584846496582
# Step: 1770 Loss: 0.0021136607974767685 KL_div:0.07954942435026169 current_lr:0.01 Time taken per iteration: 0.007637739181518555
# Step: 1780 Loss: 0.002082716440781951 KL_div:0.07858425378799438 current_lr:0.01 Time taken per iteration: 0.009874582290649414
# Step: 1790 Loss: 0.0020551360212266445 KL_div:0.07769451290369034 current_lr:0.01 Time taken per iteration: 0.005791664123535156
# Step: 1800 Loss: 0.0020301667973399162 KL_div:0.07686396688222885 current_lr:0.01 Time taken per iteration: 0.006036996841430664
# Step: 1810 Loss: 0.0020076162181794643 KL_div:0.07609096169471741 current_lr:0.01 Time taken per iteration: 0.0066149234771728516
# Step: 1820 Loss: 0.001987162511795759 KL_div:0.07536984235048294 current_lr:0.01 Time taken per iteration: 0.00632023811340332
# Step: 1830 Loss: 0.0019686443265527487 KL_div:0.07469910383224487 current_lr:0.01 Time taken per iteration: 0.00675511360168457
# Step: 1840 Loss: 0.001951811253093183 KL_div:0.07407423853874207 current_lr:0.01 Time taken per iteration: 0.00841522216796875
# Step: 1850 Loss: 0.0019364797044545412 KL_div:0.07349225878715515 current_lr:0.01 Time taken per iteration: 0.009530305862426758
# Step: 1860 Loss: 0.001922564348205924 KL_div:0.07295269519090652 current_lr:0.01 Time taken per iteration: 0.008338451385498047
# Step: 1870 Loss: 0.0019098387565463781 KL_div:0.07245055586099625 current_lr:0.01 Time taken per iteration: 0.006932973861694336
# Step: 1880 Loss: 0.001898171380162239 KL_div:0.07198333740234375 current_lr:0.01 Time taken per iteration: 0.0061435699462890625
# Step: 1890 Loss: 0.0018874813104048371 KL_div:0.07154976576566696 current_lr:0.01 Time taken per iteration: 0.0073394775390625
# Step: 1900 Loss: 0.0018777395598590374 KL_div:0.07114970684051514 current_lr:0.01 Time taken per iteration: 0.007071256637573242
# Step: 1910 Loss: 0.001868698513135314 KL_div:0.07077652961015701 current_lr:0.01 Time taken per iteration: 0.006478309631347656
# Step: 1920 Loss: 0.0018604360520839691 KL_div:0.07043293118476868 current_lr:0.01 Time taken per iteration: 0.006406545639038086
# Step: 1930 Loss: 0.0018527648644521832 KL_div:0.07011353969573975 current_lr:0.01 Time taken per iteration: 0.007980585098266602
# Step: 1940 Loss: 0.0018457149853929877 KL_div:0.06981945037841797 current_lr:0.01 Time taken per iteration: 0.006750345230102539
# Step: 1950 Loss: 0.001839153002947569 KL_div:0.06954658031463623 current_lr:0.01 Time taken per iteration: 0.006777048110961914
# Step: 1960 Loss: 0.0018331095343455672 KL_div:0.06929580867290497 current_lr:0.01 Time taken per iteration: 0.008419990539550781
# Step: 1970 Loss: 0.0018273545429110527 KL_div:0.06906002759933472 current_lr:0.01 Time taken per iteration: 0.0069158077239990234
# Step: 1980 Loss: 0.001822123071178794 KL_div:0.06884609162807465 current_lr:0.01 Time taken per iteration: 0.006799936294555664
# Step: 1990 Loss: 0.0018172041745856404 KL_div:0.06864745169878006 current_lr:0.01 Time taken per iteration: 0.007840156555175781
# Step: 2000 Loss: 0.0018126633949577808 KL_div:0.06846579164266586 current_lr:0.01 Time taken per iteration: 0.009337425231933594
# Step: 2010 Loss: 0.00180833472404629 KL_div:0.06829574704170227 current_lr:0.01 Time taken per iteration: 0.009716272354125977
# Step: 2020 Loss: 0.0018043494783341885 KL_div:0.06814100593328476 current_lr:0.01 Time taken per iteration: 0.00658869743347168
# Step: 2030 Loss: 0.0018006388563662767 KL_div:0.06799924373626709 current_lr:0.01 Time taken per iteration: 0.006430864334106445
# Step: 2040 Loss: 0.0017970616463571787 KL_div:0.06786565482616425 current_lr:0.01 Time taken per iteration: 0.0062313079833984375
# Step: 2050 Loss: 0.0017937227385118604 KL_div:0.06774333119392395 current_lr:0.01 Time taken per iteration: 0.009157419204711914
# Step: 2060 Loss: 0.0017906336579471827 KL_div:0.06763225793838501 current_lr:0.01 Time taken per iteration: 0.009718656539916992
# Step: 2070 Loss: 0.0017876296769827604 KL_div:0.06752697378396988 current_lr:0.01 Time taken per iteration: 0.013956546783447266
# Step: 2080 Loss: 0.0017849000869318843 KL_div:0.067433200776577 current_lr:0.01 Time taken per iteration: 0.006516695022583008
# Step: 2090 Loss: 0.0017822124063968658 KL_div:0.06734343618154526 current_lr:0.01 Time taken per iteration: 0.006317853927612305
# Step: 2100 Loss: 0.0017797626787796617 KL_div:0.06726352870464325 current_lr:0.01 Time taken per iteration: 0.00627589225769043
# Step: 2110 Loss: 0.001777398050762713 KL_div:0.06718844175338745 current_lr:0.01 Time taken per iteration: 0.007130861282348633
# Step: 2120 Loss: 0.0017751825507730246 KL_div:0.0671200156211853 current_lr:0.01 Time taken per iteration: 0.006578922271728516
# Step: 2130 Loss: 0.0017730578547343612 KL_div:0.06705628335475922 current_lr:0.01 Time taken per iteration: 0.0067691802978515625
# Step: 2140 Loss: 0.0017710566753521562 KL_div:0.06699793040752411 current_lr:0.01 Time taken per iteration: 0.00876927375793457
# Step: 2150 Loss: 0.0017691781977191567 KL_div:0.0669448971748352 current_lr:0.01 Time taken per iteration: 0.00831747055053711
# Step: 2160 Loss: 0.0017673929687589407 KL_div:0.06689601391553879 current_lr:0.01 Time taken per iteration: 0.006306886672973633
# Step: 2170 Loss: 0.0017656759591773152 KL_div:0.06685036420822144 current_lr:0.01 Time taken per iteration: 0.006600379943847656
# Step: 2180 Loss: 0.0017640431178733706 KL_div:0.0668083131313324 current_lr:0.01 Time taken per iteration: 0.006873369216918945
# Step: 2190 Loss: 0.0017624575411900878 KL_div:0.06676869839429855 current_lr:0.01 Time taken per iteration: 0.008786201477050781
# Step: 2200 Loss: 0.0017609774367883801 KL_div:0.06673306226730347 current_lr:0.01 Time taken per iteration: 0.006590366363525391
# Step: 2210 Loss: 0.0017595905810594559 KL_div:0.06670091301202774 current_lr:0.01 Time taken per iteration: 0.006096601486206055
# Step: 2220 Loss: 0.0017582719447091222 KL_div:0.06667157262563705 current_lr:0.01 Time taken per iteration: 0.007906913757324219
# Step: 2230 Loss: 0.0017569444607943296 KL_div:0.06664233654737473 current_lr:0.01 Time taken per iteration: 0.008970499038696289
# Step: 2240 Loss: 0.0017557945102453232 KL_div:0.06661911308765411 current_lr:0.01 Time taken per iteration: 0.007123231887817383
# Step: 2250 Loss: 0.0017545927548781037 KL_div:0.06659452617168427 current_lr:0.01 Time taken per iteration: 0.0064508914947509766
# Step: 2260 Loss: 0.0017535326769575477 KL_div:0.06657466292381287 current_lr:0.01 Time taken per iteration: 0.00626683235168457
# Step: 2270 Loss: 0.0017524557188153267 KL_div:0.0665544718503952 current_lr:0.01 Time taken per iteration: 0.008177995681762695
# Step: 2280 Loss: 0.0017514118226245046 KL_div:0.06653537601232529 current_lr:0.01 Time taken per iteration: 0.007523059844970703
# Step: 2290 Loss: 0.0017504661809653044 KL_div:0.06651954352855682 current_lr:0.01 Time taken per iteration: 0.006798982620239258
# Step: 2300 Loss: 0.0017495076172053814 KL_div:0.06650325655937195 current_lr:0.01 Time taken per iteration: 0.008270025253295898
# Step: 2310 Loss: 0.001748636830598116 KL_div:0.0664898008108139 current_lr:0.01 Time taken per iteration: 0.005917549133300781
# Step: 2320 Loss: 0.001747785252518952 KL_div:0.06647695600986481 current_lr:0.01 Time taken per iteration: 0.009416580200195312
# Step: 2330 Loss: 0.0017469879239797592 KL_div:0.06646575778722763 current_lr:0.01 Time taken per iteration: 0.007383584976196289
# Step: 2340 Loss: 0.001746193040162325 KL_div:0.06645455211400986 current_lr:0.01 Time taken per iteration: 0.0069234371185302734
# Step: 2350 Loss: 0.0017454378539696336 KL_div:0.06644444912672043 current_lr:0.01 Time taken per iteration: 0.006567955017089844
# Step: 2360 Loss: 0.0017446896526962519 KL_div:0.06643453240394592 current_lr:0.01 Time taken per iteration: 0.006619930267333984
# Step: 2370 Loss: 0.001743991393595934 KL_div:0.06642602384090424 current_lr:0.01 Time taken per iteration: 0.0062024593353271484
# Step: 2380 Loss: 0.0017432509921491146 KL_div:0.06641602516174316 current_lr:0.01 Time taken per iteration: 0.0074193477630615234
# Step: 2390 Loss: 0.0017426543636247516 KL_div:0.06641045957803726 current_lr:0.01 Time taken per iteration: 0.007287740707397461
# Step: 2400 Loss: 0.0017420405056327581 KL_div:0.06640414893627167 current_lr:0.01 Time taken per iteration: 0.0071561336517333984
# Step: 2410 Loss: 0.0017413604073226452 KL_div:0.06639555841684341 current_lr:0.01 Time taken per iteration: 0.009451866149902344
# Step: 2420 Loss: 0.001740786130540073 KL_div:0.06639017164707184 current_lr:0.01 Time taken per iteration: 0.006644725799560547
# Step: 2430 Loss: 0.0017402413068339229 KL_div:0.06638552248477936 current_lr:0.01 Time taken per iteration: 0.00632166862487793
# Step: 2440 Loss: 0.0017396846087649465 KL_div:0.06638030707836151 current_lr:0.01 Time taken per iteration: 0.008349180221557617
# Step: 2450 Loss: 0.0017391387373209 KL_div:0.06637521833181381 current_lr:0.01 Time taken per iteration: 0.008977174758911133
# Step: 2460 Loss: 0.0017386287217959762 KL_div:0.06637105345726013 current_lr:0.01 Time taken per iteration: 0.006635189056396484
# Step: 2470 Loss: 0.0017381389625370502 KL_div:0.06636731326580048 current_lr:0.01 Time taken per iteration: 0.006950855255126953
# Step: 2480 Loss: 0.0017376086907461286 KL_div:0.06636209785938263 current_lr:0.01 Time taken per iteration: 0.008103132247924805
# Step: 2490 Loss: 0.0017371086869388819 KL_div:0.06635767221450806 current_lr:0.01 Time taken per iteration: 0.005827665328979492
# Step: 2500 Loss: 0.0017366375541314483 KL_div:0.0663539320230484 current_lr:0.01 Time taken per iteration: 0.0073201656341552734
# Step: 2510 Loss: 0.001736232778057456 KL_div:0.06635209918022156 current_lr:0.01 Time taken per iteration: 0.00598907470703125
# Step: 2520 Loss: 0.0017357772449031472 KL_div:0.06634847819805145 current_lr:0.01 Time taken per iteration: 0.0065174102783203125
# Step: 2530 Loss: 0.0017353470902889967 KL_div:0.06634540855884552 current_lr:0.01 Time taken per iteration: 0.007032632827758789
# Step: 2540 Loss: 0.001734912395477295 KL_div:0.06634203344583511 current_lr:0.01 Time taken per iteration: 0.011793136596679688
# Step: 2550 Loss: 0.0017345380038022995 KL_div:0.06634032726287842 current_lr:0.01 Time taken per iteration: 0.007277727127075195
# Step: 2560 Loss: 0.0017340707127004862 KL_div:0.066335529088974 current_lr:0.01 Time taken per iteration: 0.006611347198486328
# Step: 2570 Loss: 0.0017337200697511435 KL_div:0.06633424758911133 current_lr:0.01 Time taken per iteration: 0.007140159606933594
# Step: 2580 Loss: 0.0017333123832941055 KL_div:0.0663309320807457 current_lr:0.01 Time taken per iteration: 0.006911039352416992
# Step: 2590 Loss: 0.0017329392721876502 KL_div:0.06632854044437408 current_lr:0.01 Time taken per iteration: 0.00688934326171875
# Step: 2600 Loss: 0.0017326280940324068 KL_div:0.06632799655199051 current_lr:0.01 Time taken per iteration: 0.006916046142578125
# Step: 2610 Loss: 0.0017322091152891517 KL_div:0.06632381677627563 current_lr:0.01 Time taken per iteration: 0.007282733917236328
# Step: 2620 Loss: 0.001731896074488759 KL_div:0.06632277369499207 current_lr:0.01 Time taken per iteration: 0.007104396820068359
# Step: 2630 Loss: 0.0017315172590315342 KL_div:0.06631946563720703 current_lr:0.01 Time taken per iteration: 0.010360240936279297
# Step: 2640 Loss: 0.0017311623087152839 KL_div:0.06631682068109512 current_lr:0.01 Time taken per iteration: 0.0071506500244140625
# Step: 2650 Loss: 0.0017308263340964913 KL_div:0.06631455570459366 current_lr:0.01 Time taken per iteration: 0.006647586822509766
# Step: 2660 Loss: 0.001730519812554121 KL_div:0.06631308794021606 current_lr:0.01 Time taken per iteration: 0.007456541061401367
# Step: 2670 Loss: 0.0017301735933870077 KL_div:0.06631019711494446 current_lr:0.01 Time taken per iteration: 0.006761074066162109
# Step: 2680 Loss: 0.0017298426246270537 KL_div:0.06630761921405792 current_lr:0.01 Time taken per iteration: 0.006582021713256836
# Step: 2690 Loss: 0.001729525625705719 KL_div:0.06630535423755646 current_lr:0.01 Time taken per iteration: 0.006751060485839844
# Step: 2700 Loss: 0.0017292810371145606 KL_div:0.0663052424788475 current_lr:0.01 Time taken per iteration: 0.006706714630126953
# Step: 2710 Loss: 0.0017289621755480766 KL_div:0.06630260497331619 current_lr:0.01 Time taken per iteration: 0.006999969482421875
# Step: 2720 Loss: 0.0017286326037719846 KL_div:0.06629946827888489 current_lr:0.01 Time taken per iteration: 0.006587505340576172
# Step: 2730 Loss: 0.001728341681882739 KL_div:0.06629744917154312 current_lr:0.01 Time taken per iteration: 0.009871244430541992
# Step: 2740 Loss: 0.0017280825413763523 KL_div:0.0662962943315506 current_lr:0.01 Time taken per iteration: 0.008693456649780273
# Step: 2750 Loss: 0.0017278592567890882 KL_div:0.06629611551761627 current_lr:0.01 Time taken per iteration: 0.007895231246948242
# Step: 2760 Loss: 0.0017275458667427301 KL_div:0.06629298627376556 current_lr:0.01 Time taken per iteration: 0.01132965087890625
# Step: 2770 Loss: 0.0017272942932322621 KL_div:0.06629164516925812 current_lr:0.01 Time taken per iteration: 0.00953531265258789
# Step: 2780 Loss: 0.001727025955915451 KL_div:0.06628961861133575 current_lr:0.01 Time taken per iteration: 0.007916450500488281
# Step: 2790 Loss: 0.0017267378279939294 KL_div:0.06628686189651489 current_lr:0.01 Time taken per iteration: 0.009955644607543945
# Step: 2800 Loss: 0.0017264713533222675 KL_div:0.06628471612930298 current_lr:0.01 Time taken per iteration: 0.016468048095703125
# Step: 2810 Loss: 0.0017262075562030077 KL_div:0.06628251075744629 current_lr:0.01 Time taken per iteration: 0.011085033416748047
# Step: 2820 Loss: 0.001726025016978383 KL_div:0.06628276407718658 current_lr:0.01 Time taken per iteration: 0.007405996322631836
# Step: 2830 Loss: 0.0017257359577342868 KL_div:0.06627951562404633 current_lr:0.01 Time taken per iteration: 0.007845640182495117
# Step: 2840 Loss: 0.0017254549311473966 KL_div:0.0662764459848404 current_lr:0.01 Time taken per iteration: 0.007081031799316406
# Step: 2850 Loss: 0.001725219190120697 KL_div:0.06627467274665833 current_lr:0.01 Time taken per iteration: 0.007206439971923828
# Step: 2860 Loss: 0.001725008012726903 KL_div:0.06627357751131058 current_lr:0.01 Time taken per iteration: 0.00724339485168457
# Step: 2870 Loss: 0.0017247432842850685 KL_div:0.06627063453197479 current_lr:0.01 Time taken per iteration: 0.007103681564331055
# Step: 2880 Loss: 0.0017245607450604439 KL_div:0.06627027690410614 current_lr:0.01 Time taken per iteration: 0.008879423141479492
# Step: 2890 Loss: 0.0017242667963728309 KL_div:0.06626622378826141 current_lr:0.01 Time taken per iteration: 0.011854410171508789
# Step: 2900 Loss: 0.0017241009045392275 KL_div:0.06626611202955246 current_lr:0.01 Time taken per iteration: 0.007761240005493164
# Step: 2910 Loss: 0.0017239040462300181 KL_div:0.06626495718955994 current_lr:0.01 Time taken per iteration: 0.007928848266601562
# Step: 2920 Loss: 0.0017236353596672416 KL_div:0.0662613958120346 current_lr:0.01 Time taken per iteration: 0.0093536376953125
# Step: 2930 Loss: 0.001723419758491218 KL_div:0.06625943630933762 current_lr:0.01 Time taken per iteration: 0.009243965148925781
# Step: 2940 Loss: 0.0017232041573151946 KL_div:0.06625741720199585 current_lr:0.01 Time taken per iteration: 0.007995843887329102
# Step: 2950 Loss: 0.0017229905351996422 KL_div:0.06625533849000931 current_lr:0.01 Time taken per iteration: 0.011409997940063477
# Step: 2960 Loss: 0.0017228506039828062 KL_div:0.06625553220510483 current_lr:0.01 Time taken per iteration: 0.007246732711791992
# Step: 2970 Loss: 0.0017225632909685373 KL_div:0.06625092774629593 current_lr:0.01 Time taken per iteration: 0.013193607330322266
# Step: 2980 Loss: 0.0017224053153768182 KL_div:0.06625038385391235 current_lr:0.01 Time taken per iteration: 0.008539676666259766
# Step: 2990 Loss: 0.0017221771413460374 KL_div:0.06624750047922134 current_lr:0.01 Time taken per iteration: 0.0066301822662353516
# Step: 3000 Loss: 0.0017220026347786188 KL_div:0.06624622642993927 current_lr:0.01 Time taken per iteration: 0.006512880325317383
# Step: 3010 Loss: 0.0017217606073245406 KL_div:0.06624272465705872 current_lr:0.01 Time taken per iteration: 0.0066874027252197266
# Step: 3020 Loss: 0.0017216645646840334 KL_div:0.06624378263950348 current_lr:0.01 Time taken per iteration: 0.006804227828979492
# Step: 3030 Loss: 0.0017214685212820768 KL_div:0.06624158471822739 current_lr:0.01 Time taken per iteration: 0.006601095199584961
# Step: 3040 Loss: 0.001721276668831706 KL_div:0.06623944640159607 current_lr:0.01 Time taken per iteration: 0.0069239139556884766
# Step: 3050 Loss: 0.0017211157828569412 KL_div:0.06623822450637817 current_lr:0.01 Time taken per iteration: 0.006706714630126953
# Step: 3060 Loss: 0.001720902626402676 KL_div:0.06623521447181702 current_lr:0.01 Time taken per iteration: 0.0070497989654541016
# Step: 3070 Loss: 0.0017207413911819458 KL_div:0.0662338137626648 current_lr:0.01 Time taken per iteration: 0.0065958499908447266
# Step: 3080 Loss: 0.0017205947078764439 KL_div:0.06623278558254242 current_lr:0.01 Time taken per iteration: 0.0070302486419677734
# Step: 3090 Loss: 0.001720412285067141 KL_div:0.06623058021068573 current_lr:0.01 Time taken per iteration: 0.008414745330810547
# Step: 3100 Loss: 0.0017202409217134118 KL_div:0.06622862070798874 current_lr:0.01 Time taken per iteration: 0.006839275360107422
# Step: 3110 Loss: 0.001720035681501031 KL_div:0.0662255585193634 current_lr:0.01 Time taken per iteration: 0.0067484378814697266
# Step: 3120 Loss: 0.0017199155408889055 KL_div:0.0662250816822052 current_lr:0.01 Time taken per iteration: 0.006919145584106445
# Step: 3130 Loss: 0.0017197448760271072 KL_div:0.06622293591499329 current_lr:0.01 Time taken per iteration: 0.0069310665130615234
# Step: 3140 Loss: 0.0017195632681250572 KL_div:0.06622036546468735 current_lr:0.01 Time taken per iteration: 0.0067005157470703125
# Step: 3150 Loss: 0.0017194155370816588 KL_div:0.06621883809566498 current_lr:0.01 Time taken per iteration: 0.006802082061767578
# Step: 3160 Loss: 0.0017192700179293752 KL_div:0.0662173181772232 current_lr:0.01 Time taken per iteration: 0.009413480758666992
# Step: 3170 Loss: 0.0017191432416439056 KL_div:0.06621634215116501 current_lr:0.01 Time taken per iteration: 0.010510444641113281
# Step: 3180 Loss: 0.0017189342761412263 KL_div:0.06621265411376953 current_lr:0.01 Time taken per iteration: 0.007246732711791992
# Step: 3190 Loss: 0.0017188215861096978 KL_div:0.066211998462677 current_lr:0.01 Time taken per iteration: 0.007103919982910156
# Step: 3200 Loss: 0.0017187062185257673 KL_div:0.06621114909648895 current_lr:0.01 Time taken per iteration: 0.006918668746948242
# Step: 3210 Loss: 0.0017185506876558065 KL_div:0.06620900332927704 current_lr:0.01 Time taken per iteration: 0.008286714553833008
# Step: 3220 Loss: 0.0017183810705319047 KL_div:0.06620631366968155 current_lr:0.01 Time taken per iteration: 0.006725311279296875
# Step: 3230 Loss: 0.0017182412557303905 KL_div:0.06620454043149948 current_lr:0.01 Time taken per iteration: 0.016939163208007812
# Step: 3240 Loss: 0.0017181007424369454 KL_div:0.06620264798402786 current_lr:0.01 Time taken per iteration: 0.006948232650756836
# Step: 3250 Loss: 0.0017179482383653522 KL_div:0.06620031595230103 current_lr:0.01 Time taken per iteration: 0.007862329483032227
# Step: 3260 Loss: 0.0017178291454911232 KL_div:0.06619904190301895 current_lr:0.01 Time taken per iteration: 0.011317729949951172
# Step: 3270 Loss: 0.001717674545943737 KL_div:0.06619653105735779 current_lr:0.01 Time taken per iteration: 0.007037639617919922
# Step: 3280 Loss: 0.0017175704706460238 KL_div:0.06619562208652496 current_lr:0.01 Time taken per iteration: 0.009629487991333008
# Step: 3290 Loss: 0.001717455335892737 KL_div:0.06619428098201752 current_lr:0.01 Time taken per iteration: 0.017259597778320312
# Step: 3300 Loss: 0.0017173115629702806 KL_div:0.06619195640087128 current_lr:0.01 Time taken per iteration: 0.010138750076293945
# Step: 3310 Loss: 0.0017171953804790974 KL_div:0.06619049608707428 current_lr:0.01 Time taken per iteration: 0.0072021484375
# Step: 3320 Loss: 0.0017171138897538185 KL_div:0.06619007885456085 current_lr:0.01 Time taken per iteration: 0.007156848907470703
# Step: 3330 Loss: 0.0017169381026178598 KL_div:0.0661865770816803 current_lr:0.01 Time taken per iteration: 0.008631229400634766
# Step: 3340 Loss: 0.0017168157501146197 KL_div:0.06618474423885345 current_lr:0.01 Time taken per iteration: 0.007349967956542969
# Step: 3350 Loss: 0.0017167145851999521 KL_div:0.06618352979421616 current_lr:0.01 Time taken per iteration: 0.007245302200317383
# Step: 3360 Loss: 0.0017165786121040583 KL_div:0.06618114560842514 current_lr:0.01 Time taken per iteration: 0.011861801147460938
# Step: 3370 Loss: 0.001716482569463551 KL_div:0.06617999076843262 current_lr:0.01 Time taken per iteration: 0.006886482238769531
# Step: 3380 Loss: 0.0017163672018796206 KL_div:0.06617821753025055 current_lr:0.01 Time taken per iteration: 0.010436058044433594
# Step: 3390 Loss: 0.0017162556760013103 KL_div:0.06617644429206848 current_lr:0.01 Time taken per iteration: 0.006791591644287109
# Step: 3400 Loss: 0.0017161722062155604 KL_div:0.06617553532123566 current_lr:0.01 Time taken per iteration: 0.01050424575805664
# Step: 3410 Loss: 0.0017160328570753336 KL_div:0.06617284566164017 current_lr:0.01 Time taken per iteration: 0.006455421447753906
# Step: 3420 Loss: 0.0017158990958705544 KL_div:0.06617027521133423 current_lr:0.01 Time taken per iteration: 0.0067217350006103516
# Step: 3430 Loss: 0.0017158552072942257 KL_div:0.06617053598165512 current_lr:0.01 Time taken per iteration: 0.006483554840087891
# Step: 3440 Loss: 0.0017157277325168252 KL_div:0.06616808474063873 current_lr:0.01 Time taken per iteration: 0.007229328155517578
# Step: 3450 Loss: 0.0017155923414975405 KL_div:0.0661652684211731 current_lr:0.01 Time taken per iteration: 0.008343935012817383
# Step: 3460 Loss: 0.0017155184177681804 KL_div:0.06616448611021042 current_lr:0.01 Time taken per iteration: 0.007552385330200195
# Step: 3470 Loss: 0.001715406309813261 KL_div:0.06616239994764328 current_lr:0.01 Time taken per iteration: 0.006417512893676758
# Step: 3480 Loss: 0.0017153031658381224 KL_div:0.06616057455539703 current_lr:0.01 Time taken per iteration: 0.007115840911865234
# Step: 3490 Loss: 0.0017152716172859073 KL_div:0.06616095453500748 current_lr:0.01 Time taken per iteration: 0.006062030792236328
# Step: 3500 Loss: 0.0017151272622868419 KL_div:0.06615764647722244 current_lr:0.01 Time taken per iteration: 0.008339166641235352
# Step: 3510 Loss: 0.0017150192288681865 KL_div:0.06615550816059113 current_lr:0.01 Time taken per iteration: 0.006968975067138672
# Step: 3520 Loss: 0.001714929356239736 KL_div:0.06615392118692398 current_lr:0.01 Time taken per iteration: 0.006326436996459961
# Step: 3530 Loss: 0.0017148785991594195 KL_div:0.06615356355905533 current_lr:0.01 Time taken per iteration: 0.009952545166015625
# Step: 3540 Loss: 0.0017148212064057589 KL_div:0.0661529004573822 current_lr:0.01 Time taken per iteration: 0.006084918975830078
# Step: 3550 Loss: 0.0017146888421848416 KL_div:0.06614983826875687 current_lr:0.01 Time taken per iteration: 0.009539604187011719
# Step: 3560 Loss: 0.0017145844176411629 KL_div:0.06614764034748077 current_lr:0.01 Time taken per iteration: 0.0064411163330078125
# Step: 3570 Loss: 0.0017144492594525218 KL_div:0.06614439189434052 current_lr:0.01 Time taken per iteration: 0.0060236454010009766
# Step: 3580 Loss: 0.001714379875920713 KL_div:0.06614323705434799 current_lr:0.01 Time taken per iteration: 0.007901906967163086
# Step: 3590 Loss: 0.0017143207369372249 KL_div:0.06614238768815994 current_lr:0.01 Time taken per iteration: 0.010803937911987305
# Step: 3600 Loss: 0.0017142556607723236 KL_div:0.0661412924528122 current_lr:0.01 Time taken per iteration: 0.007319927215576172
# Step: 3610 Loss: 0.001714143669232726 KL_div:0.06613866239786148 current_lr:0.01 Time taken per iteration: 0.009732484817504883
# Step: 3620 Loss: 0.0017141113057732582 KL_div:0.06613855063915253 current_lr:0.01 Time taken per iteration: 0.00719141960144043
# Step: 3630 Loss: 0.001714009209536016 KL_div:0.06613616645336151 current_lr:0.01 Time taken per iteration: 0.006456136703491211
# Step: 3640 Loss: 0.0017139125848188996 KL_div:0.06613396108150482 current_lr:0.01 Time taken per iteration: 0.006117343902587891
# Step: 3650 Loss: 0.00171388010494411 KL_div:0.06613373756408691 current_lr:0.01 Time taken per iteration: 0.007636070251464844
# Step: 3660 Loss: 0.0017137686954811215 KL_div:0.06613091379404068 current_lr:0.01 Time taken per iteration: 0.0065920352935791016
# Step: 3670 Loss: 0.0017136861570179462 KL_div:0.06612902134656906 current_lr:0.01 Time taken per iteration: 0.006804943084716797
# Step: 3680 Loss: 0.0017136132810264826 KL_div:0.06612743437290192 current_lr:0.01 Time taken per iteration: 0.0072422027587890625
# Step: 3690 Loss: 0.0017135635716840625 KL_div:0.06612652540206909 current_lr:0.01 Time taken per iteration: 0.006429195404052734
# Step: 3700 Loss: 0.0017134451773017645 KL_div:0.06612340360879898 current_lr:0.01 Time taken per iteration: 0.006390571594238281
# Step: 3710 Loss: 0.0017133670626208186 KL_div:0.06612157076597214 current_lr:0.01 Time taken per iteration: 0.007305145263671875
# Step: 3720 Loss: 0.0017133597284555435 KL_div:0.06612195074558258 current_lr:0.01 Time taken per iteration: 0.0059356689453125
# Step: 3730 Loss: 0.0017132526263594627 KL_div:0.06611913442611694 current_lr:0.01 Time taken per iteration: 0.006165742874145508
# Step: 3740 Loss: 0.0017132218927145004 KL_div:0.06611865758895874 current_lr:0.01 Time taken per iteration: 0.00618290901184082
# Step: 3750 Loss: 0.0017132015200331807 KL_div:0.06611855328083038 current_lr:0.01 Time taken per iteration: 0.007429361343383789
# Step: 3760 Loss: 0.0017130497144535184 KL_div:0.06611419469118118 current_lr:0.01 Time taken per iteration: 0.005530357360839844
# Step: 3770 Loss: 0.0017130395863205194 KL_div:0.06611433625221252 current_lr:0.01 Time taken per iteration: 0.007207155227661133
# Step: 3780 Loss: 0.001712963217869401 KL_div:0.06611237674951553 current_lr:0.01 Time taken per iteration: 0.006420612335205078
# Step: 3790 Loss: 0.0017129118787124753 KL_div:0.06611116230487823 current_lr:0.01 Time taken per iteration: 0.0065364837646484375
# Step: 3800 Loss: 0.001712805824354291 KL_div:0.06610815972089767 current_lr:0.01 Time taken per iteration: 0.00928187370300293
# Step: 3810 Loss: 0.0017127556493505836 KL_div:0.06610694527626038 current_lr:0.01 Time taken per iteration: 0.006294727325439453
# Step: 3820 Loss: 0.0017126809107139707 KL_div:0.06610486656427383 current_lr:0.01 Time taken per iteration: 0.006276845932006836
# Step: 3830 Loss: 0.0017126600723713636 KL_div:0.06610450893640518 current_lr:0.01 Time taken per iteration: 0.007250547409057617
# Step: 3840 Loss: 0.0017125577433034778 KL_div:0.0661015659570694 current_lr:0.01 Time taken per iteration: 0.006798267364501953
# Step: 3850 Loss: 0.0017125181620940566 KL_div:0.0661005973815918 current_lr:0.01 Time taken per iteration: 0.0064008235931396484
# Step: 3860 Loss: 0.001712464145384729 KL_div:0.0660991370677948 current_lr:0.01 Time taken per iteration: 0.00787973403930664
# Step: 3870 Loss: 0.0017124114092439413 KL_div:0.0660976767539978 current_lr:0.01 Time taken per iteration: 0.00576329231262207
# Step: 3880 Loss: 0.0017123164143413305 KL_div:0.06609485298395157 current_lr:0.01 Time taken per iteration: 0.00601506233215332
# Step: 3890 Loss: 0.0017122409772127867 KL_div:0.06609265506267548 current_lr:0.01 Time taken per iteration: 0.0071947574615478516
# Step: 3900 Loss: 0.001712263561785221 KL_div:0.06609359383583069 current_lr:0.01 Time taken per iteration: 0.006561994552612305
# Step: 3910 Loss: 0.0017122364370152354 KL_div:0.06609287112951279 current_lr:0.01 Time taken per iteration: 0.0058765411376953125
# Step: 3920 Loss: 0.00171216344460845 KL_div:0.0660906657576561 current_lr:0.01 Time taken per iteration: 0.006304264068603516
# Step: 3930 Loss: 0.0017120784614235163 KL_div:0.06608803570270538 current_lr:0.01 Time taken per iteration: 0.0061991214752197266
# Step: 3940 Loss: 0.001712029566988349 KL_div:0.06608656793832779 current_lr:0.01 Time taken per iteration: 0.005869626998901367
# Step: 3950 Loss: 0.0017119740368798375 KL_div:0.0660848617553711 current_lr:0.01 Time taken per iteration: 0.0063419342041015625
# Step: 3960 Loss: 0.0017119338735938072 KL_div:0.0660836473107338 current_lr:0.01 Time taken per iteration: 0.006532907485961914
# Step: 3970 Loss: 0.0017118484247475863 KL_div:0.06608095020055771 current_lr:0.01 Time taken per iteration: 0.005601406097412109
# Step: 3980 Loss: 0.0017118527321144938 KL_div:0.06608108431100845 current_lr:0.01 Time taken per iteration: 0.006088972091674805
# Step: 3990 Loss: 0.0017118258401751518 KL_div:0.066080242395401 current_lr:0.01 Time taken per iteration: 0.006376743316650391
# Step: 4000 Loss: 0.0017117687966674566 KL_div:0.06607840955257416 current_lr:0.01 Time taken per iteration: 0.010925531387329102
# Step: 4010 Loss: 0.001711712684482336 KL_div:0.06607657670974731 current_lr:0.01 Time taken per iteration: 0.016951560974121094
# Step: 4020 Loss: 0.0017116731032729149 KL_div:0.06607529520988464 current_lr:0.01 Time taken per iteration: 0.005922555923461914
# Step: 4030 Loss: 0.0017115912633016706 KL_div:0.06607259809970856 current_lr:0.01 Time taken per iteration: 0.005500316619873047
# Step: 4040 Loss: 0.0017115718219429255 KL_div:0.06607193499803543 current_lr:0.01 Time taken per iteration: 0.006173133850097656
# Step: 4050 Loss: 0.0017115322407335043 KL_div:0.06607060134410858 current_lr:0.01 Time taken per iteration: 0.006046295166015625
# Step: 4060 Loss: 0.0017115025548264384 KL_div:0.06606956571340561 current_lr:0.01 Time taken per iteration: 0.005913734436035156
# Step: 4070 Loss: 0.0017114661168307066 KL_div:0.06606828421354294 current_lr:0.01 Time taken per iteration: 0.005825996398925781
# Step: 4080 Loss: 0.0017114040674641728 KL_div:0.0660662055015564 current_lr:0.01 Time taken per iteration: 0.005432844161987305
# Step: 4090 Loss: 0.0017113015055656433 KL_div:0.06606277078390121 current_lr:0.01 Time taken per iteration: 0.009146690368652344
# Step: 4100 Loss: 0.001711304415948689 KL_div:0.06606272608041763 current_lr:0.01 Time taken per iteration: 0.00652766227722168
# Step: 4110 Loss: 0.001711288932710886 KL_div:0.0660620629787445 current_lr:0.01 Time taken per iteration: 0.005953311920166016
# Step: 4120 Loss: 0.0017112154746428132 KL_div:0.06605955213308334 current_lr:0.01 Time taken per iteration: 0.006088972091674805
# Step: 4130 Loss: 0.001711175311356783 KL_div:0.06605808436870575 current_lr:0.01 Time taken per iteration: 0.00607609748840332
# Step: 4140 Loss: 0.001711141667328775 KL_div:0.06605680286884308 current_lr:0.01 Time taken per iteration: 0.0060882568359375
# Step: 4150 Loss: 0.0017111077904701233 KL_div:0.066055528819561 current_lr:0.01 Time taken per iteration: 0.005740165710449219
# Step: 4160 Loss: 0.0017111372435465455 KL_div:0.06605622172355652 current_lr:0.01 Time taken per iteration: 0.007069587707519531
# Step: 4170 Loss: 0.0017110740300267935 KL_div:0.06605395674705505 current_lr:0.01 Time taken per iteration: 0.0064661502838134766
# Step: 4180 Loss: 0.0017109866021201015 KL_div:0.06605088710784912 current_lr:0.01 Time taken per iteration: 0.00604557991027832
# Step: 4190 Loss: 0.0017110105836763978 KL_div:0.06605146080255508 current_lr:0.01 Time taken per iteration: 0.008862495422363281
# Step: 4200 Loss: 0.001710957265459001 KL_div:0.0660495012998581 current_lr:0.01 Time taken per iteration: 0.0055196285247802734
# Step: 4210 Loss: 0.0017109347973018885 KL_div:0.0660485252737999 current_lr:0.01 Time taken per iteration: 0.006361722946166992
# Step: 4220 Loss: 0.0017109084874391556 KL_div:0.06604737043380737 current_lr:0.01 Time taken per iteration: 0.007626533508300781
# Step: 4230 Loss: 0.0017108480678871274 KL_div:0.06604516506195068 current_lr:0.01 Time taken per iteration: 0.005971431732177734
# Step: 4240 Loss: 0.001710853772237897 KL_div:0.06604506075382233 current_lr:0.01 Time taken per iteration: 0.02696990966796875
# Step: 4250 Loss: 0.0017107779858633876 KL_div:0.06604230403900146 current_lr:0.01 Time taken per iteration: 0.008203506469726562
# Step: 4260 Loss: 0.0017107499297708273 KL_div:0.06604114174842834 current_lr:0.01 Time taken per iteration: 0.006383180618286133
# Step: 4270 Loss: 0.0017107179155573249 KL_div:0.0660398006439209 current_lr:0.01 Time taken per iteration: 0.006094455718994141
# Step: 4280 Loss: 0.0017106897430494428 KL_div:0.066038578748703 current_lr:0.01 Time taken per iteration: 0.008359670639038086
# Step: 4290 Loss: 0.0017106124432757497 KL_div:0.06603576242923737 current_lr:0.01 Time taken per iteration: 0.007306575775146484
# Step: 4300 Loss: 0.0017106219893321395 KL_div:0.06603577733039856 current_lr:0.01 Time taken per iteration: 0.009319782257080078
# Step: 4310 Loss: 0.0017105835722759366 KL_div:0.06603418290615082 current_lr:0.01 Time taken per iteration: 0.0076787471771240234
# Step: 4320 Loss: 0.001710533513687551 KL_div:0.06603223085403442 current_lr:0.01 Time taken per iteration: 0.006034135818481445
# Step: 4330 Loss: 0.001710562501102686 KL_div:0.06603279709815979 current_lr:0.01 Time taken per iteration: 0.005530595779418945
# Step: 4340 Loss: 0.0017104792641475797 KL_div:0.06602978706359863 current_lr:0.01 Time taken per iteration: 0.006564140319824219
# Step: 4350 Loss: 0.0017104854341596365 KL_div:0.0660296231508255 current_lr:0.01 Time taken per iteration: 0.006562232971191406
# Step: 4360 Loss: 0.0017104949802160263 KL_div:0.06602957099676132 current_lr:0.01 Time taken per iteration: 0.006615400314331055
# Step: 4370 Loss: 0.0017104358412325382 KL_div:0.06602730602025986 current_lr:0.01 Time taken per iteration: 0.00935983657836914
# Step: 4380 Loss: 0.0017104119760915637 KL_div:0.06602615118026733 current_lr:0.01 Time taken per iteration: 0.006507396697998047
# Step: 4390 Loss: 0.0017103722784668207 KL_div:0.06602449715137482 current_lr:0.01 Time taken per iteration: 0.007317543029785156
# Step: 4400 Loss: 0.0017103658756241202 KL_div:0.06602395325899124 current_lr:0.01 Time taken per iteration: 0.010268449783325195
# Step: 4410 Loss: 0.0017103349091485143 KL_div:0.06602255254983902 current_lr:0.01 Time taken per iteration: 0.007345914840698242
# Step: 4420 Loss: 0.0017103463178500533 KL_div:0.06602250039577484 current_lr:0.01 Time taken per iteration: 0.006081819534301758
# Step: 4430 Loss: 0.001710250275209546 KL_div:0.06601899862289429 current_lr:0.01 Time taken per iteration: 0.006858348846435547
# Step: 4440 Loss: 0.0017102702986449003 KL_div:0.06601925939321518 current_lr:0.01 Time taken per iteration: 0.008878946304321289
# Step: 4450 Loss: 0.0017102562123909593 KL_div:0.06601841002702713 current_lr:0.01 Time taken per iteration: 0.006266117095947266
# Step: 4460 Loss: 0.001710206619463861 KL_div:0.06601639091968536 current_lr:0.01 Time taken per iteration: 0.006590127944946289
# Step: 4470 Loss: 0.001710131298750639 KL_div:0.06601357460021973 current_lr:0.01 Time taken per iteration: 0.008619070053100586
# Step: 4480 Loss: 0.0017101329285651445 KL_div:0.06601320952177048 current_lr:0.01 Time taken per iteration: 0.005641937255859375
# Step: 4490 Loss: 0.0017101190751418471 KL_div:0.06601236015558243 current_lr:0.01 Time taken per iteration: 0.008864402770996094
# Step: 4500 Loss: 0.0017101039411500096 KL_div:0.06601151078939438 current_lr:0.01 Time taken per iteration: 0.006009101867675781
# Step: 4510 Loss: 0.001710084150545299 KL_div:0.06601040810346603 current_lr:0.01 Time taken per iteration: 0.005645275115966797
# Step: 4520 Loss: 0.0017100939294323325 KL_div:0.0660102367401123 current_lr:0.01 Time taken per iteration: 0.0071485042572021484
# Step: 4530 Loss: 0.0017100124387070537 KL_div:0.06600723415613174 current_lr:0.01 Time taken per iteration: 0.005891323089599609
# Step: 4540 Loss: 0.0017100811237469316 KL_div:0.06600897014141083 current_lr:0.01 Time taken per iteration: 0.005807161331176758
# Step: 4550 Loss: 0.0017100541153922677 KL_div:0.06600768864154816 current_lr:0.01 Time taken per iteration: 0.006432056427001953
# Step: 4560 Loss: 0.001709948992356658 KL_div:0.06600388139486313 current_lr:0.01 Time taken per iteration: 0.005547046661376953
# Step: 4570 Loss: 0.001709969132207334 KL_div:0.06600407510995865 current_lr:0.01 Time taken per iteration: 0.005989551544189453
# Step: 4580 Loss: 0.0017099571414291859 KL_div:0.06600328534841537 current_lr:0.01 Time taken per iteration: 0.006242275238037109
# Step: 4590 Loss: 0.0017098927637562156 KL_div:0.06600083410739899 current_lr:0.01 Time taken per iteration: 0.005808830261230469
# Step: 4600 Loss: 0.0017099088290706277 KL_div:0.06600090116262436 current_lr:0.01 Time taken per iteration: 0.009082317352294922
# Step: 4610 Loss: 0.0017098786775022745 KL_div:0.06599950045347214 current_lr:0.01 Time taken per iteration: 0.006880760192871094
# Step: 4620 Loss: 0.0017098888056352735 KL_div:0.06599938869476318 current_lr:0.01 Time taken per iteration: 0.0062084197998046875
# Step: 4630 Loss: 0.0017098865937441587 KL_div:0.06599884480237961 current_lr:0.01 Time taken per iteration: 0.006087779998779297
# Step: 4640 Loss: 0.0017098616808652878 KL_div:0.06599762290716171 current_lr:0.01 Time taken per iteration: 0.007002115249633789
# Step: 4650 Loss: 0.001709816395305097 KL_div:0.0659957230091095 current_lr:0.01 Time taken per iteration: 0.006108522415161133
# Step: 4660 Loss: 0.0017097836825996637 KL_div:0.0659942552447319 current_lr:0.01 Time taken per iteration: 0.006188631057739258
# Step: 4670 Loss: 0.0017097435193136334 KL_div:0.06599254161119461 current_lr:0.01 Time taken per iteration: 0.006265878677368164
# Step: 4680 Loss: 0.0017097506206482649 KL_div:0.06599236279726028 current_lr:0.01 Time taken per iteration: 0.008945226669311523
# Step: 4690 Loss: 0.001709765405394137 KL_div:0.06599243730306625 current_lr:0.01 Time taken per iteration: 0.005930423736572266
# Step: 4700 Loss: 0.0017097028903663158 KL_div:0.06598998606204987 current_lr:0.01 Time taken per iteration: 0.0071370601654052734
# Step: 4710 Loss: 0.0017097173258662224 KL_div:0.06598999351263046 current_lr:0.01 Time taken per iteration: 0.006154775619506836
# Step: 4720 Loss: 0.0017097204690799117 KL_div:0.06598969548940659 current_lr:0.01 Time taken per iteration: 0.007009983062744141
# Step: 4730 Loss: 0.0017096968367695808 KL_div:0.06598847359418869 current_lr:0.01 Time taken per iteration: 0.008444786071777344
# Step: 4740 Loss: 0.001709615346044302 KL_div:0.06598540395498276 current_lr:0.01 Time taken per iteration: 0.006068229675292969
# Step: 4750 Loss: 0.001709653646685183 KL_div:0.06598621606826782 current_lr:0.01 Time taken per iteration: 0.006359577178955078
# Step: 4760 Loss: 0.001709583099000156 KL_div:0.06598351150751114 current_lr:0.01 Time taken per iteration: 0.006098747253417969
# Step: 4770 Loss: 0.0017096262890845537 KL_div:0.06598444283008575 current_lr:0.01 Time taken per iteration: 0.005731105804443359
# Step: 4780 Loss: 0.0017095766961574554 KL_div:0.06598248332738876 current_lr:0.01 Time taken per iteration: 0.008209228515625
# Step: 4790 Loss: 0.00170956552028656 KL_div:0.06598169356584549 current_lr:0.01 Time taken per iteration: 0.009238958358764648
# Step: 4800 Loss: 0.0017095664516091347 KL_div:0.06598132848739624 current_lr:0.01 Time taken per iteration: 0.0057871341705322266
# Step: 4810 Loss: 0.001709531992673874 KL_div:0.06597980111837387 current_lr:0.01 Time taken per iteration: 0.008896350860595703
# Step: 4820 Loss: 0.001709501026198268 KL_div:0.06597839295864105 current_lr:0.01 Time taken per iteration: 0.014342069625854492
# Step: 4830 Loss: 0.0017095478251576424 KL_div:0.06597945094108582 current_lr:0.01 Time taken per iteration: 0.007200002670288086
# Step: 4840 Loss: 0.00170955341309309 KL_div:0.06597921252250671 current_lr:0.01 Time taken per iteration: 0.016020536422729492
# Step: 4850 Loss: 0.0017095132498070598 KL_div:0.06597749888896942 current_lr:0.01 Time taken per iteration: 0.005977630615234375
# Step: 4860 Loss: 0.0017095296643674374 KL_div:0.0659775659441948 current_lr:0.01 Time taken per iteration: 0.006500959396362305
# Step: 4870 Loss: 0.001709453179500997 KL_div:0.06597468256950378 current_lr:0.01 Time taken per iteration: 0.010520458221435547
# Step: 4880 Loss: 0.0017094360664486885 KL_div:0.06597370654344559 current_lr:0.01 Time taken per iteration: 0.0058765411376953125
# Step: 4890 Loss: 0.0017094071954488754 KL_div:0.06597241759300232 current_lr:0.01 Time taken per iteration: 0.005884647369384766
# Step: 4900 Loss: 0.001709381933324039 KL_div:0.0659712553024292 current_lr:0.01 Time taken per iteration: 0.006344318389892578
# Step: 4910 Loss: 0.0017093955539166927 KL_div:0.06597132235765457 current_lr:0.01 Time taken per iteration: 0.006231784820556641
# Step: 4920 Loss: 0.0017093465430662036 KL_div:0.06596936285495758 current_lr:0.01 Time taken per iteration: 0.006331205368041992
# Step: 4930 Loss: 0.001709330128505826 KL_div:0.06596851348876953 current_lr:0.01 Time taken per iteration: 0.006138324737548828
# Step: 4940 Loss: 0.001709328149445355 KL_div:0.06596808135509491 current_lr:0.01 Time taken per iteration: 0.009177207946777344
# Step: 4950 Loss: 0.0017093068454414606 KL_div:0.06596697866916656 current_lr:0.01 Time taken per iteration: 0.0061686038970947266
# Step: 4960 Loss: 0.0017093439819291234 KL_div:0.06596779078245163 current_lr:0.01 Time taken per iteration: 0.008028745651245117
# Step: 4970 Loss: 0.0017093204660341144 KL_div:0.06596662849187851 current_lr:0.01 Time taken per iteration: 0.006127595901489258
# Step: 4980 Loss: 0.0017093417700380087 KL_div:0.0659668818116188 current_lr:0.01 Time taken per iteration: 0.007803440093994141
# Step: 4990 Loss: 0.001709286356344819 KL_div:0.06596473604440689 current_lr:0.01 Time taken per iteration: 0.00625300407409668
# Step: 5000 Loss: 0.0017093061469495296 KL_div:0.06596504896879196 current_lr:0.01 Time taken per iteration: 0.0066220760345458984

# %%
fig, axs = plt.subplots(1,2,figsize=(15,8))
axs[0].plot(divs)
axs[0].title.set_text('KL Divergence')

axs[1].plot(history)
axs[1].title.set_text('loss')

# %%
optimal_params = parameters[np.argmin(divs)]
qcbm_probs = circuit(optimal_params)
x_full = jnp.arange(0,2**n_qubits,dtype=jnp.float64)

fig, axs = plt.subplots(1,2,figsize=(15,5))
axs[0].bar(x_full,qcbm_probs[0],color='green',alpha=0.5,label='Obtained Distribution')
axs[0].plot(x_full,target_distribution1,color='blue',alpha=0.5,label='Target Distribution')
axs[0].legend()
axs[0].set_title('1111 Distribution')
axs[0].set_xlabel('Hilbert Space')
axs[0].set_ylabel('Probability Distribution')

axs[1].bar(x_full,qcbm_probs[1],color='red',alpha=0.5,label='Obtained Distribution')
axs[1].plot(x_full,target_distribution2,color='blue',alpha=0.5,label='Target Distribution')
axs[1].legend()
axs[1].set_title('0000 Distribution')
axs[1].set_xlabel('Hilbert Space')
axs[1].set_ylabel('Probability Distribution')
# Out:
# Text(0, 0.5, 'Probability Distribution')

# %%
print(f"Minimum KL Divergence obtained is {np.min(divs)}")
# Out:
# Minimum KL Divergence obtained is 0.065963014960289

# %%
dev = qml.device("default.qubit",wires=n_qubits)

@qml.qnode(dev,interface='jax')
def output_vqc_circuit(input_params,n_qubits=4):
    uniform_init(num_qubits,cat_pre_training,seed=0)
    params = input_params[0]
    for i in range(vqc_folds):
        vqc_circuit(params[i])
    return qml.probs(wires=range(n_qubits))

qml.draw_mpl(output_vqc_circuit)(optimal_params)
plt.show()

# %%
hybrid_output = output_vqc_circuit(optimal_params,n_qubits)

# %%
fig, axs = plt.subplots(1,2,figsize=(15,5))
axs[0].plot(x_full,hybrid_output,label='Generated Cat')
axs[0].legend()
axs[0].set_title('Generated Cat Distribution')
axs[0].set_xlabel('Hilbert Space')
axs[0].set_ylabel('Probability Distribution')

axs[1].plot(x_full,cat_data,label='Original Cat')
axs[1].legend()
axs[1].set_title('Original Cat Distribution')
axs[1].set_xlabel('Hilbert Space')
axs[1].set_ylabel('Probability Distribution')
# Out:
# Text(0, 0.5, 'Probability Distribution')

# %%
x = jnp.arange(0,n_qubits+1,dtype=jnp.float64)
fig, axs = plt.subplots(1,2,figsize=(15,5))
axs[0].bar(x,pnumber_distribution(hybrid_output,n_qubits),color='green',alpha=0.5,label='Generated Cat')
axs[0].legend()
axs[0].set_title('Generated Cat Distribution')
axs[0].set_xlabel('Particle Number')
axs[0].set_ylabel('Particle Number Distribution')

axs[1].bar(x,pnumber_distribution(cat_data,n_qubits),color='red',alpha=0.5,label='Original Cat')
axs[1].legend()
axs[1].set_title('Original Cat Distribution')
axs[1].set_xlabel('Particle Number')
axs[1].set_ylabel('Particle Number Distribution')
# Out:
# Text(0, 0.5, 'Particle Number Distribution')

# %%
# #Save Checkpoint
# checkpoint = {"final_epoch":i,
#               "history":history,
#               "divs":divs,
#               "parameters":parameters}

# with open(f'model_cat_anticat_distribution.pkl','wb') as file:
#     pickle.dump(checkpoint,file)
    
# print("Model saved successfully")
