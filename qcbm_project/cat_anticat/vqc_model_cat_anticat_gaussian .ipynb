# %%
from vqc_model_gaussian import *

from jax.lib import xla_bridge
jax.experimental.enable_x64()
print("JAX Backend:", xla_bridge.get_backend().platform)
# Out:
# JAX Backend: gpu

# %%
# Visualizing Original Cat Distribution
plt.plot(cat_data, label='Target Distribution')
plt.xlabel("Hilbert Space",fontsize=12)
plt.ylabel("Probability Distribution",fontsize=12)
plt.title("Gaussian Distribution",fontsize=14)
plt.legend()

# %%
# Visualizing Original AntiCat Distribution
plt.plot(anticat_data, label='Anticat Distribution')
plt.xlabel("Hilbert Space")
plt.ylabel("Probability Distribution")
plt.title("Anticat of Gaussian Distribution")
plt.legend()

# %%
qml.draw_mpl(circuit,device='default')(input_params=initial_params)
plt.show()

# %% [markdown]
# ### Cells to be run if the target_distribution corresponds to superposition of all half filled states

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations


# Number of qubits
num_qubits = 8

# Generate all binary states with exactly 4 ones
valid_states = ["".join("1" if i in comb else "0" for i in range(num_qubits)) 
                for comb in combinations(range(num_qubits), 4)]

# Convert binary states to decimal indices
valid_indices = [int(state, 2) for state in valid_states]

# Create target distribution
target_distribution = np.zeros(2**num_qubits)
for index in valid_indices:
    target_distribution[index] = 1  # Assign probability 1 to valid states

# Normalize the distribution
target_distribution /= np.sum(target_distribution)

# Plot the target distribution
plt.figure(figsize=(10, 5))
plt.plot(target_distribution, linestyle="-", label="Superposition of 4 Ones & 4 Zeros")
plt.xlabel("State Index")
plt.ylabel("Probability")
plt.title("Target Distribution for 4-Ones-4-Zeros Superposition")
plt.legend()
plt.show()

# %%
class MMD:
    def __init__(self,scales,space):
        gammas = 1/(2*(scales**2)).reshape(-1,1,1)
        sq_dists = jnp.abs(space[:,None] - space[None,:])**2
        self.K = jnp.sum(jnp.exp(-gammas * sq_dists), axis=0)/len(scales)
        self.scales = scales
        
    def k_expval(self,px,py):
        return px @ self.K @ py
    
    def __call__(self,px,py):
        pxy = px-py
        return self.k_expval(pxy,pxy)
    
class QCBM:
    def __init__(self,circ,mmd,py):
        self.circ = circ
        self.mmd = mmd
        self.py = py
    
    def mmd_loss(self,params):
        px = self.circ(params)
        loss = self.mmd(px,self.py)

        return loss, px
    

#Model Training
@jit
def update_step(params,opt_state):
    
    (total_loss_val,qcbm_probs), grads = jax.value_and_grad(qcbm.mmd_loss,has_aux=True)(params)

    updates,opt_state = opt.update(grads,opt_state)
    params = optax.apply_updates(params,updates)
    
    qcbm_probs = jnp.asarray(qcbm_probs, dtype=jnp.float64)
    
    kl_div = -jnp.sum(target_distribution * jnp.nan_to_num(jnp.log(qcbm_probs) - jnp.log(target_distribution)))
    
    total_kl_div = kl_div
    
    return params, opt_state, total_loss_val, total_kl_div

# %%
#Calling MMD class
bandwidth = jnp.array([0.25,60],dtype=jnp.float64)
space = jnp.arange(0,2**total_qubits,dtype=jnp.float64)
mmd = MMD(bandwidth,space=space)


#Calling QCBM class to run the previous built circuit with random weights
qcbm = QCBM(circuit,mmd=mmd,py=target_distribution)


#Initial parameters
weights = initial_params
lr = optax.exponential_decay(init_value=0.1,transition_steps=10,decay_rate=0.99,transition_begin=300,end_value=0.025,staircase=True)
# lr = 0.01
opt = optax.adam(learning_rate=lr)
opt_state = opt.init(weights)


history = []
divs = []
parameters = []


kl_div = 1
i = 0
# i = start_epoch

# while kl_div > 10^-3:
while i < 5001:
    i+=1
    current_lr = lr(i)
    # current_lr = lr
    start_time = time.time()
    weights, opt_state, loss_val, kl_div = update_step(params=weights,opt_state=opt_state)
    end_time = time.time()
    
    if i%10==0:
        print(f"Step: {i} Loss: {loss_val} KL_div:{kl_div} current_lr:{current_lr} Time taken per iteration: {end_time-start_time}")
    
    history.append(loss_val)
    divs.append(kl_div)
    parameters.append(weights)
# Out:
# ---------------------------------------------------------------------------
# TracerArrayConversionError                Traceback (most recent call last)
# Cell In[8], line 34
#      32 # current_lr = lr
#      33 start_time = time.time()
# ---> 34 weights, opt_state, loss_val, kl_div = update_step(params=weights,opt_state=opt_state)
#      35 end_time = time.time()
#      37 if i%10==0:
#
#     [... skipping hidden 13 frame]
#
# Cell In[7], line 32, in update_step(params, opt_state)
#      29 @jit
#      30 def update_step(params,opt_state):
# ---> 32     (total_loss_val,qcbm_probs), grads = jax.value_and_grad(qcbm.mmd_loss,has_aux=True)(params)
#      34     updates,opt_state = opt.update(grads,opt_state)
#      35     params = optax.apply_updates(params,updates)
#
#     [... skipping hidden 16 frame]
#
# Cell In[7], line 23, in QCBM.mmd_loss(self, params)
#      21 def mmd_loss(self,params):
#      22     px = self.circ(params)
# ---> 23     loss = self.mmd(px,self.py)
#      25     return loss, px
#
# Cell In[7], line 12, in MMD.__call__(self, px, py)
#      11 def __call__(self,px,py):
# ---> 12     pxy = px-py
#      13     return self.k_expval(pxy,pxy)
#
# File ~/mambaforge/envs/pennylane/lib/python3.12/site-packages/jax/_src/core.py:756, in Tracer.__array__(self, *args, **kw)
#     755 def __array__(self, *args, **kw):
# --> 756   raise TracerArrayConversionError(self)
#
# TracerArrayConversionError: The numpy.ndarray conversion method __array__() was called on traced array with shape float32[16]
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.TracerArrayConversionError

# %%
print(f"Minimum KL Divergence obtained is {np.min(divs)}")
# Out:
# Minimum KL Divergence obtained is 0.49561136960983276

# %%
fig, axs = plt.subplots(1,2,figsize=(15,8))
axs[0].plot(divs)
axs[0].title.set_text('KL Divergence')

axs[1].plot(history)
axs[1].title.set_text('loss')

# %%
optimal_params = parameters[np.argmin(divs)]

qcbm_probs = circuit(optimal_params)
x_array = jnp.arange(0,2**(total_qubits),dtype=jnp.float64)


plt.bar(x_array,qcbm_probs,color='green',alpha=0.5,label='Obtained Cat')
plt.plot(x_array,target_distribution,color='blue',alpha=0.5,label='Original Cat')
plt.xlabel("Hilbert Space")
plt.ylabel("Probability Distribution")
plt.title("Cat Distribution")
plt.legend()
plt.show()

# %% [markdown]
# ### Cells to be run if target_distribution is only 10101010

# %%
# import numpy as np

# Target binary pattern
target_binary = "10101010"

#Odd Numbered Qubits
target_binary1 = '1111'

#Even Numbered Qubits
target_binary2 = '0000'

# Convert binary to decimal index
target_index1 = int(target_binary1, 2)
target_index2 = int(target_binary2, 2)

# Create a one-hot encoded target distribution
num_qubits = 4
target_distribution1 = np.zeros(2**num_qubits)
target_distribution1[target_index1] = 1

target_distribution2 = np.zeros(2**num_qubits)
target_distribution2[target_index2] = 1

# plt.subplot(1, 2, 1)
plt.plot(target_distribution1)
# plt.plot(target_distribution2)

# %%
class MMD:
    def __init__(self,scales,space):
        gammas = 1/(2*(scales**2)).reshape(-1,1,1)
        sq_dists = jnp.abs(space[:,None] - space[None,:])**2
        self.K = jnp.sum(jnp.exp(-gammas * sq_dists), axis=0)/len(scales)
        self.scales = scales
        
    def k_expval(self,px,py):
        return px @ self.K @ py
    
    def __call__(self,px,py):
        pxy = px-py
        return self.k_expval(pxy,pxy)
    
class QCBM:
    def __init__(self,circ,mmd1,mmd2,py1,py2):
        self.circ = circ
        self.mmd1 = mmd1
        self.mmd2 = mmd2
        self.py1 = py1
        self.py2 = py2
    
    def mmd_loss(self,params):
        px = self.circ(params)
        loss1 = self.mmd1(px[0],self.py1)
        loss2 = self.mmd2(px[1],self.py2)
        
        return loss1+loss2, px
    

#Model Training
@jit
def update_step(params,opt_state):
    
    (total_loss_val,qcbm_probs), grads = jax.value_and_grad(qcbm.mmd_loss,has_aux=True)(params)

    updates,opt_state = opt.update(grads,opt_state)
    params = optax.apply_updates(params,updates)
    
    qcbm_probs1 = jnp.asarray(qcbm_probs[0], dtype=jnp.float64)
    qcbm_probs2 = jnp.asarray(qcbm_probs[1], dtype=jnp.float64)
    
    kl_div1 = -jnp.sum(target_distribution1 * jnp.nan_to_num(jnp.log(qcbm_probs1) - jnp.log(target_distribution1)))
    kl_div2 = -jnp.sum(target_distribution2 * jnp.nan_to_num(jnp.log(qcbm_probs2) - jnp.log(target_distribution2)))
    
    total_kl_div = kl_div1 + kl_div2
    
    return params, opt_state, total_loss_val, total_kl_div

# %%
#Calling MMD class
bandwidth = jnp.array([0.25,60],dtype=jnp.float64)
space = jnp.arange(0,2**n_qubits,dtype=jnp.float64)
mmd1 = MMD(bandwidth,space=space)
mmd2 = MMD(bandwidth,space=space)


#Calling QCBM class to run the previous built circuit with random weights
qcbm = QCBM(circuit,mmd1=mmd1,mmd2=mmd2,py1=target_distribution1,py2=target_distribution2)


#Initial parameters
weights = initial_params
# lr = optax.exponential_decay(init_value=0.1,transition_steps=10,decay_rate=0.99,transition_begin=300,end_value=0.005,staircase=True)
lr = 0.01
opt = optax.adam(learning_rate=lr)
opt_state = opt.init(weights)


history = []
divs = []
parameters = []


kl_div = 1
i = 0
# i = start_epoch

# while kl_div > 10^-3:
while i < 5001:
    i+=1
    # current_lr = lr(i)
    current_lr = lr
    start_time = time.time()
    weights, opt_state, loss_val, kl_div = update_step(params=weights,opt_state=opt_state)
    end_time = time.time()
    
    if i%10==0:
        print(f"Step: {i} Loss: {loss_val} KL_div:{kl_div} current_lr:{current_lr} Time taken per iteration: {end_time-start_time}")
    
    history.append(loss_val)
    divs.append(kl_div)
    parameters.append(weights)
# Out:
# Step: 10 Loss: 0.4410027861595154 KL_div:1.9597824811935425 current_lr:0.1 Time taken per iteration: 0.009086847305297852
# Step: 20 Loss: 0.07663119584321976 KL_div:0.6013734340667725 current_lr:0.1 Time taken per iteration: 0.009226083755493164
# Step: 30 Loss: 0.034517839550971985 KL_div:0.37927794456481934 current_lr:0.1 Time taken per iteration: 0.01482701301574707
# Step: 40 Loss: 0.018546773120760918 KL_div:0.2668481171131134 current_lr:0.1 Time taken per iteration: 0.006789445877075195
# Step: 50 Loss: 0.01317049190402031 KL_div:0.22092431783676147 current_lr:0.1 Time taken per iteration: 0.008359670639038086
# Step: 60 Loss: 0.011624068021774292 KL_div:0.20797093212604523 current_lr:0.1 Time taken per iteration: 0.012250900268554688
# Step: 70 Loss: 0.010307671502232552 KL_div:0.1957683563232422 current_lr:0.1 Time taken per iteration: 0.009757041931152344
# Step: 80 Loss: 0.00994608923792839 KL_div:0.19216346740722656 current_lr:0.1 Time taken per iteration: 0.008651494979858398
# Step: 90 Loss: 0.00973777286708355 KL_div:0.19020289182662964 current_lr:0.1 Time taken per iteration: 0.008355379104614258
# Step: 100 Loss: 0.009590578265488148 KL_div:0.1887306272983551 current_lr:0.1 Time taken per iteration: 0.014237403869628906
# Step: 110 Loss: 0.009474968537688255 KL_div:0.1876065731048584 current_lr:0.1 Time taken per iteration: 0.008240938186645508
# Step: 120 Loss: 0.009359823539853096 KL_div:0.18640321493148804 current_lr:0.1 Time taken per iteration: 0.00912165641784668
# Step: 130 Loss: 0.009237885475158691 KL_div:0.18501286208629608 current_lr:0.1 Time taken per iteration: 0.007653951644897461
# Step: 140 Loss: 0.009106150828301907 KL_div:0.18341073393821716 current_lr:0.1 Time taken per iteration: 0.013217926025390625
# Step: 150 Loss: 0.008964935317635536 KL_div:0.1815413534641266 current_lr:0.1 Time taken per iteration: 0.020012617111206055
# Step: 160 Loss: 0.00881743524223566 KL_div:0.1794809103012085 current_lr:0.1 Time taken per iteration: 0.00759434700012207
# Step: 170 Loss: 0.008667465299367905 KL_div:0.17724812030792236 current_lr:0.1 Time taken per iteration: 0.01336979866027832
# Step: 180 Loss: 0.008516374044120312 KL_div:0.1749071180820465 current_lr:0.1 Time taken per iteration: 0.012054443359375
# Step: 190 Loss: 0.008353200741112232 KL_div:0.17237666249275208 current_lr:0.1 Time taken per iteration: 0.010331392288208008
# Step: 200 Loss: 0.008131655864417553 KL_div:0.1691892147064209 current_lr:0.1 Time taken per iteration: 0.030945539474487305
# Step: 210 Loss: 0.007721686270087957 KL_div:0.1637723594903946 current_lr:0.1 Time taken per iteration: 0.03398847579956055
# Step: 220 Loss: 0.006957978941500187 KL_div:0.15363898873329163 current_lr:0.1 Time taken per iteration: 0.025216102600097656
# Step: 230 Loss: 0.00623487401753664 KL_div:0.143357053399086 current_lr:0.1 Time taken per iteration: 0.05279231071472168
# Step: 240 Loss: 0.005839790217578411 KL_div:0.13773223757743835 current_lr:0.1 Time taken per iteration: 0.011746644973754883
# Step: 250 Loss: 0.005186640657484531 KL_div:0.12934185564517975 current_lr:0.1 Time taken per iteration: 0.010889768600463867
# Step: 260 Loss: 0.004119004122912884 KL_div:0.1142345666885376 current_lr:0.1 Time taken per iteration: 0.012338638305664062
# Step: 270 Loss: 0.0029565871227532625 KL_div:0.09363175928592682 current_lr:0.1 Time taken per iteration: 0.01810741424560547
# Step: 280 Loss: 0.0022380792070180178 KL_div:0.07774319499731064 current_lr:0.1 Time taken per iteration: 0.010766744613647461
# Step: 290 Loss: 0.001969072036445141 KL_div:0.07025045156478882 current_lr:0.1 Time taken per iteration: 0.01777338981628418
# Step: 300 Loss: 0.0018908248748630285 KL_div:0.06737454980611801 current_lr:0.1 Time taken per iteration: 0.010604143142700195
# Step: 310 Loss: 0.0018601054325699806 KL_div:0.06594043225049973 current_lr:0.1 Time taken per iteration: 0.010459423065185547
# Step: 320 Loss: 0.001843028818257153 KL_div:0.06507032364606857 current_lr:0.1 Time taken per iteration: 0.007730722427368164
# Step: 330 Loss: 0.0018313098698854446 KL_div:0.06461450457572937 current_lr:0.1 Time taken per iteration: 0.01036834716796875
# Step: 340 Loss: 0.0018228383269160986 KL_div:0.06447328627109528 current_lr:0.1 Time taken per iteration: 0.009637832641601562
# Step: 350 Loss: 0.0018166216323152184 KL_div:0.06450353562831879 current_lr:0.1 Time taken per iteration: 0.011637687683105469
# Step: 360 Loss: 0.0018115101847797632 KL_div:0.06458592414855957 current_lr:0.1 Time taken per iteration: 0.01071476936340332
# Step: 370 Loss: 0.001807130640372634 KL_div:0.06467289477586746 current_lr:0.1 Time taken per iteration: 0.01714634895324707
# Step: 380 Loss: 0.001803265418857336 KL_div:0.06474994122982025 current_lr:0.1 Time taken per iteration: 0.007365703582763672
# Step: 390 Loss: 0.0017997330287471414 KL_div:0.06481161713600159 current_lr:0.1 Time taken per iteration: 0.012063980102539062
# Step: 400 Loss: 0.00179637735709548 KL_div:0.06485697627067566 current_lr:0.1 Time taken per iteration: 0.008517026901245117
# Step: 410 Loss: 0.0017933103954419494 KL_div:0.0648966133594513 current_lr:0.1 Time taken per iteration: 0.007668972015380859
# Step: 420 Loss: 0.001790318638086319 KL_div:0.06493048369884491 current_lr:0.1 Time taken per iteration: 0.007854938507080078
# Step: 430 Loss: 0.0017875318881124258 KL_div:0.06496725976467133 current_lr:0.1 Time taken per iteration: 0.009964704513549805
# Step: 440 Loss: 0.0017848160350695252 KL_div:0.06500383466482162 current_lr:0.1 Time taken per iteration: 0.008127212524414062
# Step: 450 Loss: 0.0017821768997237086 KL_div:0.06503986567258835 current_lr:0.1 Time taken per iteration: 0.009034872055053711
# Step: 460 Loss: 0.0017797757172957063 KL_div:0.06507991254329681 current_lr:0.1 Time taken per iteration: 0.014779806137084961
# Step: 470 Loss: 0.0017773439176380634 KL_div:0.0651148185133934 current_lr:0.1 Time taken per iteration: 0.010193347930908203
# Step: 480 Loss: 0.0017750750994309783 KL_div:0.0651506707072258 current_lr:0.1 Time taken per iteration: 0.007041215896606445
# Step: 490 Loss: 0.0017728907987475395 KL_div:0.06518489122390747 current_lr:0.1 Time taken per iteration: 0.008864164352416992
# Step: 500 Loss: 0.0017707180231809616 KL_div:0.06521494686603546 current_lr:0.1 Time taken per iteration: 0.00878286361694336
# Step: 510 Loss: 0.001768812071532011 KL_div:0.06524910032749176 current_lr:0.1 Time taken per iteration: 0.010447502136230469
# Step: 520 Loss: 0.0017667997162789106 KL_div:0.0652751550078392 current_lr:0.1 Time taken per iteration: 0.009253978729248047
# Step: 530 Loss: 0.0017649770015850663 KL_div:0.06530265510082245 current_lr:0.1 Time taken per iteration: 0.02292919158935547
# Step: 540 Loss: 0.0017631954979151487 KL_div:0.0653267428278923 current_lr:0.1 Time taken per iteration: 0.012943029403686523
# Step: 550 Loss: 0.001761529128998518 KL_div:0.0653497576713562 current_lr:0.1 Time taken per iteration: 0.013318538665771484
# Step: 560 Loss: 0.0017599541461095214 KL_div:0.06537088751792908 current_lr:0.1 Time taken per iteration: 0.011539220809936523
# Step: 570 Loss: 0.0017584004672244191 KL_div:0.06538786739110947 current_lr:0.1 Time taken per iteration: 0.007896661758422852
# Step: 580 Loss: 0.0017570509808138013 KL_div:0.06540678441524506 current_lr:0.1 Time taken per iteration: 0.008832454681396484
# Step: 590 Loss: 0.0017556832171976566 KL_div:0.06542032212018967 current_lr:0.1 Time taken per iteration: 0.010152578353881836
# Step: 600 Loss: 0.0017544976435601711 KL_div:0.0654352456331253 current_lr:0.1 Time taken per iteration: 0.008358478546142578
# Step: 610 Loss: 0.0017533106729388237 KL_div:0.06544569879770279 current_lr:0.1 Time taken per iteration: 0.007562875747680664
# Step: 620 Loss: 0.0017521831905469298 KL_div:0.06545390188694 current_lr:0.1 Time taken per iteration: 0.009977340698242188
# Step: 630 Loss: 0.001751174684613943 KL_div:0.06546195596456528 current_lr:0.1 Time taken per iteration: 0.010797262191772461
# Step: 640 Loss: 0.0017502286937087774 KL_div:0.06546823680400848 current_lr:0.1 Time taken per iteration: 0.010654449462890625
# Step: 650 Loss: 0.001749275834299624 KL_div:0.06547079980373383 current_lr:0.1 Time taken per iteration: 0.009159564971923828
# Step: 660 Loss: 0.0017484751297160983 KL_div:0.06547503918409348 current_lr:0.1 Time taken per iteration: 0.00850677490234375
# Step: 670 Loss: 0.0017477043438702822 KL_div:0.06547720730304718 current_lr:0.1 Time taken per iteration: 0.010978460311889648
# Step: 680 Loss: 0.0017469377489760518 KL_div:0.06547675281763077 current_lr:0.1 Time taken per iteration: 0.010545015335083008
# Step: 690 Loss: 0.0017462740652263165 KL_div:0.06547711044549942 current_lr:0.1 Time taken per iteration: 0.009033918380737305
# Step: 700 Loss: 0.0017456156201660633 KL_div:0.06547532975673676 current_lr:0.1 Time taken per iteration: 0.010258197784423828
# Step: 710 Loss: 0.0017449649749323726 KL_div:0.06547170877456665 current_lr:0.1 Time taken per iteration: 0.008420705795288086
# Step: 720 Loss: 0.0017444267868995667 KL_div:0.0654698833823204 current_lr:0.1 Time taken per iteration: 0.0087890625
# Step: 730 Loss: 0.001743909204378724 KL_div:0.06546702980995178 current_lr:0.1 Time taken per iteration: 0.007391214370727539
# Step: 740 Loss: 0.0017434157198294997 KL_div:0.06546343863010406 current_lr:0.1 Time taken per iteration: 0.008225679397583008
# Step: 750 Loss: 0.0017428952269256115 KL_div:0.06545770168304443 current_lr:0.1 Time taken per iteration: 0.009424686431884766
# Step: 760 Loss: 0.00174245098605752 KL_div:0.06545326858758926 current_lr:0.1 Time taken per iteration: 0.01126718521118164
# Step: 770 Loss: 0.0017419949872419238 KL_div:0.0654473602771759 current_lr:0.1 Time taken per iteration: 0.007200956344604492
# Step: 780 Loss: 0.0017415978945791721 KL_div:0.06544237583875656 current_lr:0.1 Time taken per iteration: 0.02154231071472168
# Step: 790 Loss: 0.0017412106972187757 KL_div:0.06543684750795364 current_lr:0.1 Time taken per iteration: 0.007436037063598633
# Step: 800 Loss: 0.0017408225685358047 KL_div:0.06543058156967163 current_lr:0.1 Time taken per iteration: 0.008938312530517578
# Step: 810 Loss: 0.0017405108083039522 KL_div:0.06542609632015228 current_lr:0.1 Time taken per iteration: 0.007758378982543945
# Step: 820 Loss: 0.0017401407239958644 KL_div:0.06541909277439117 current_lr:0.1 Time taken per iteration: 0.010194063186645508
# Step: 830 Loss: 0.001739820116199553 KL_div:0.06541313976049423 current_lr:0.1 Time taken per iteration: 0.0069732666015625
# Step: 840 Loss: 0.0017395354807376862 KL_div:0.06540786474943161 current_lr:0.1 Time taken per iteration: 0.008975982666015625
# Step: 850 Loss: 0.001739162253215909 KL_div:0.06539932638406754 current_lr:0.1 Time taken per iteration: 0.0076465606689453125
# Step: 860 Loss: 0.0017389177810400724 KL_div:0.06539460271596909 current_lr:0.1 Time taken per iteration: 0.007853984832763672
# Step: 870 Loss: 0.0017386625986546278 KL_div:0.06538920104503632 current_lr:0.1 Time taken per iteration: 0.014888763427734375
# Step: 880 Loss: 0.0017383801750838757 KL_div:0.06538257002830505 current_lr:0.1 Time taken per iteration: 0.007819890975952148
# Step: 890 Loss: 0.0017381341895088553 KL_div:0.06537686288356781 current_lr:0.1 Time taken per iteration: 0.008793354034423828
# Step: 900 Loss: 0.001737874699756503 KL_div:0.06537048518657684 current_lr:0.1 Time taken per iteration: 0.01053476333618164
# Step: 910 Loss: 0.001737641985528171 KL_div:0.06536471098661423 current_lr:0.1 Time taken per iteration: 0.007971763610839844
# Step: 920 Loss: 0.0017373752780258656 KL_div:0.06535758078098297 current_lr:0.1 Time taken per iteration: 0.008738040924072266
# Step: 930 Loss: 0.0017372013535350561 KL_div:0.06535334885120392 current_lr:0.1 Time taken per iteration: 0.009117603302001953
# Step: 940 Loss: 0.001736988197080791 KL_div:0.0653475821018219 current_lr:0.1 Time taken per iteration: 0.009690284729003906
# Step: 950 Loss: 0.0017367672407999635 KL_div:0.06534144282341003 current_lr:0.1 Time taken per iteration: 0.008620738983154297
# Step: 960 Loss: 0.001736641163006425 KL_div:0.06533825397491455 current_lr:0.1 Time taken per iteration: 0.0077512264251708984
# Step: 970 Loss: 0.0017364603700116277 KL_div:0.06533309072256088 current_lr:0.1 Time taken per iteration: 0.011506080627441406
# Step: 980 Loss: 0.0017362125217914581 KL_div:0.06532570719718933 current_lr:0.1 Time taken per iteration: 0.010417461395263672
# Step: 990 Loss: 0.001736063975840807 KL_div:0.06532147526741028 current_lr:0.1 Time taken per iteration: 0.007227659225463867
# Step: 1000 Loss: 0.00173586152959615 KL_div:0.06531532108783722 current_lr:0.1 Time taken per iteration: 0.010123968124389648
# Step: 1010 Loss: 0.0017356803873553872 KL_div:0.0653097927570343 current_lr:0.1 Time taken per iteration: 0.012428522109985352
# Step: 1020 Loss: 0.0017355779418721795 KL_div:0.06530678272247314 current_lr:0.1 Time taken per iteration: 0.0077440738677978516
# Step: 1030 Loss: 0.0017353916773572564 KL_div:0.06530087441205978 current_lr:0.1 Time taken per iteration: 0.011150121688842773
# Step: 1040 Loss: 0.0017352381255477667 KL_div:0.06529588997364044 current_lr:0.1 Time taken per iteration: 0.012994050979614258
# Step: 1050 Loss: 0.0017351575661450624 KL_div:0.06529324501752853 current_lr:0.1 Time taken per iteration: 0.008418798446655273
# Step: 1060 Loss: 0.0017349554691463709 KL_div:0.06528659909963608 current_lr:0.1 Time taken per iteration: 0.010711193084716797
# Step: 1070 Loss: 0.0017348492983728647 KL_div:0.06528303027153015 current_lr:0.1 Time taken per iteration: 0.007506132125854492
# Step: 1080 Loss: 0.0017346976092085242 KL_div:0.06527785956859589 current_lr:0.1 Time taken per iteration: 0.016344547271728516
# Step: 1090 Loss: 0.0017345580272376537 KL_div:0.06527311354875565 current_lr:0.1 Time taken per iteration: 0.0158083438873291
# Step: 1100 Loss: 0.001734460238367319 KL_div:0.06526966392993927 current_lr:0.1 Time taken per iteration: 0.015391111373901367
# Step: 1110 Loss: 0.0017343157669529319 KL_div:0.06526461243629456 current_lr:0.1 Time taken per iteration: 0.01917266845703125
# Step: 1120 Loss: 0.0017342375358566642 KL_div:0.06526165455579758 current_lr:0.1 Time taken per iteration: 0.01882004737854004
# Step: 1130 Loss: 0.0017341198399662971 KL_div:0.06525739282369614 current_lr:0.1 Time taken per iteration: 0.008765459060668945
# Step: 1140 Loss: 0.0017340328777208924 KL_div:0.06525412946939468 current_lr:0.1 Time taken per iteration: 0.009971141815185547
# Step: 1150 Loss: 0.0017339573241770267 KL_div:0.06525116413831711 current_lr:0.1 Time taken per iteration: 0.009654760360717773
# Step: 1160 Loss: 0.001733801793307066 KL_div:0.06524549424648285 current_lr:0.1 Time taken per iteration: 0.010097026824951172
# Step: 1170 Loss: 0.0017337172757834196 KL_div:0.0652422159910202 current_lr:0.1 Time taken per iteration: 0.01420903205871582
# Step: 1180 Loss: 0.0017336505698040128 KL_div:0.06523943692445755 current_lr:0.1 Time taken per iteration: 0.01088571548461914
# Step: 1190 Loss: 0.0017335560405626893 KL_div:0.06523573398590088 current_lr:0.1 Time taken per iteration: 0.010134220123291016
# Step: 1200 Loss: 0.0017334051663056016 KL_div:0.06523005664348602 current_lr:0.1 Time taken per iteration: 0.009334564208984375
# Step: 1210 Loss: 0.001733335549943149 KL_div:0.06522708386182785 current_lr:0.1 Time taken per iteration: 0.009672164916992188
# Step: 1220 Loss: 0.0017332880524918437 KL_div:0.06522491574287415 current_lr:0.1 Time taken per iteration: 0.009395122528076172
# Step: 1230 Loss: 0.0017332378774881363 KL_div:0.06522250175476074 current_lr:0.1 Time taken per iteration: 0.019701004028320312
# Step: 1240 Loss: 0.0017331490525975823 KL_div:0.06521879136562347 current_lr:0.1 Time taken per iteration: 0.008660078048706055
# Step: 1250 Loss: 0.0017330459086224437 KL_div:0.06521464884281158 current_lr:0.1 Time taken per iteration: 0.008035421371459961
# Step: 1260 Loss: 0.0017329839756712317 KL_div:0.06521174311637878 current_lr:0.1 Time taken per iteration: 0.0070078372955322266
# Step: 1270 Loss: 0.0017328816466033459 KL_div:0.0652076005935669 current_lr:0.1 Time taken per iteration: 0.011032819747924805
# Step: 1280 Loss: 0.0017328744288533926 KL_div:0.06520653516054153 current_lr:0.1 Time taken per iteration: 0.00975942611694336
# Step: 1290 Loss: 0.0017327540554106236 KL_div:0.06520171463489532 current_lr:0.1 Time taken per iteration: 0.010448455810546875
# Step: 1300 Loss: 0.0017326705856248736 KL_div:0.06519818305969238 current_lr:0.1 Time taken per iteration: 0.010327339172363281
# Step: 1310 Loss: 0.0017326842062175274 KL_div:0.06519778817892075 current_lr:0.1 Time taken per iteration: 0.012236833572387695
# Step: 1320 Loss: 0.0017326544038951397 KL_div:0.06519591808319092 current_lr:0.1 Time taken per iteration: 0.009475231170654297
# Step: 1330 Loss: 0.0017325608059763908 KL_div:0.06519195437431335 current_lr:0.1 Time taken per iteration: 0.010097265243530273
# Step: 1340 Loss: 0.001732503529638052 KL_div:0.06518910080194473 current_lr:0.1 Time taken per iteration: 0.011040687561035156
# Step: 1350 Loss: 0.001732410048134625 KL_div:0.0651850774884224 current_lr:0.1 Time taken per iteration: 0.02218914031982422
# Step: 1360 Loss: 0.0017323943320661783 KL_div:0.06518369913101196 current_lr:0.1 Time taken per iteration: 0.010805130004882812
# Step: 1370 Loss: 0.0017322999192401767 KL_div:0.06517966836690903 current_lr:0.1 Time taken per iteration: 0.009543180465698242
# Step: 1380 Loss: 0.0017323102802038193 KL_div:0.06517903506755829 current_lr:0.1 Time taken per iteration: 0.012238025665283203
# Step: 1390 Loss: 0.001732210977934301 KL_div:0.0651748776435852 current_lr:0.1 Time taken per iteration: 0.009078264236450195
# Step: 1400 Loss: 0.0017321943305432796 KL_div:0.06517337262630463 current_lr:0.1 Time taken per iteration: 0.016117572784423828
# Step: 1410 Loss: 0.0017321790801361203 KL_div:0.06517186760902405 current_lr:0.1 Time taken per iteration: 0.008812904357910156
# Step: 1420 Loss: 0.0017321346094831824 KL_div:0.06516943871974945 current_lr:0.1 Time taken per iteration: 0.013851165771484375
# Step: 1430 Loss: 0.001732048112899065 KL_div:0.06516565382480621 current_lr:0.1 Time taken per iteration: 0.01824784278869629
# Step: 1440 Loss: 0.0017320102779194713 KL_div:0.06516341120004654 current_lr:0.1 Time taken per iteration: 0.015206098556518555
# Step: 1450 Loss: 0.0017319816397503018 KL_div:0.06516153365373611 current_lr:0.1 Time taken per iteration: 0.011596441268920898
# Step: 1460 Loss: 0.0017319538164883852 KL_div:0.06515965610742569 current_lr:0.1 Time taken per iteration: 0.016632795333862305
# Step: 1470 Loss: 0.0017319309990853071 KL_div:0.06515789777040482 current_lr:0.1 Time taken per iteration: 0.012570619583129883
# Step: 1480 Loss: 0.00173185917083174 KL_div:0.0651545450091362 current_lr:0.1 Time taken per iteration: 0.012326717376708984
# Step: 1490 Loss: 0.0017318533500656486 KL_div:0.0651533454656601 current_lr:0.1 Time taken per iteration: 0.011810779571533203
# Step: 1500 Loss: 0.0017318291356787086 KL_div:0.06515158712863922 current_lr:0.1 Time taken per iteration: 0.008016109466552734
# Step: 1510 Loss: 0.001731826108880341 KL_div:0.06515050679445267 current_lr:0.1 Time taken per iteration: 0.009305953979492188
# Step: 1520 Loss: 0.0017317275051027536 KL_div:0.06514622271060944 current_lr:0.1 Time taken per iteration: 0.007483959197998047
# Step: 1530 Loss: 0.0017317149322479963 KL_div:0.06514477729797363 current_lr:0.1 Time taken per iteration: 0.009826898574829102
# Step: 1540 Loss: 0.0017316993325948715 KL_div:0.06514327228069305 current_lr:0.1 Time taken per iteration: 0.00789952278137207
# Step: 1550 Loss: 0.001731682801619172 KL_div:0.06514181196689606 current_lr:0.1 Time taken per iteration: 0.008247852325439453
# Step: 1560 Loss: 0.0017316716257482767 KL_div:0.06514054536819458 current_lr:0.1 Time taken per iteration: 0.0067479610443115234
# Step: 1570 Loss: 0.0017316052690148354 KL_div:0.06513737142086029 current_lr:0.1 Time taken per iteration: 0.010128498077392578
# Step: 1580 Loss: 0.001731600728817284 KL_div:0.06513623148202896 current_lr:0.1 Time taken per iteration: 0.009900331497192383
# Step: 1590 Loss: 0.0017315817531198263 KL_div:0.06513458490371704 current_lr:0.1 Time taken per iteration: 0.00963902473449707
# Step: 1600 Loss: 0.0017315398436039686 KL_div:0.06513221561908722 current_lr:0.1 Time taken per iteration: 0.010016918182373047
# Step: 1610 Loss: 0.0017315729055553675 KL_div:0.06513229757547379 current_lr:0.1 Time taken per iteration: 0.007502555847167969
# Step: 1620 Loss: 0.0017315145814791322 KL_div:0.06512948870658875 current_lr:0.1 Time taken per iteration: 0.007047176361083984
# Step: 1630 Loss: 0.0017315290169790387 KL_div:0.06512901932001114 current_lr:0.1 Time taken per iteration: 0.0100860595703125
# Step: 1640 Loss: 0.001731472322717309 KL_div:0.0651262104511261 current_lr:0.1 Time taken per iteration: 0.011590719223022461
# Step: 1650 Loss: 0.0017314419383183122 KL_div:0.0651242583990097 current_lr:0.1 Time taken per iteration: 0.009551763534545898
# Step: 1660 Loss: 0.001731431926600635 KL_div:0.065123051404953 current_lr:0.1 Time taken per iteration: 0.009821891784667969
# Step: 1670 Loss: 0.0017314186552539468 KL_div:0.06512172520160675 current_lr:0.1 Time taken per iteration: 0.008562088012695312
# Step: 1680 Loss: 0.0017313684802502394 KL_div:0.06511922180652618 current_lr:0.1 Time taken per iteration: 0.009641647338867188
# Step: 1690 Loss: 0.0017313952557742596 KL_div:0.06511911749839783 current_lr:0.1 Time taken per iteration: 0.019209623336791992
# Step: 1700 Loss: 0.0017313793068751693 KL_div:0.06511765718460083 current_lr:0.1 Time taken per iteration: 0.007965803146362305
# Step: 1710 Loss: 0.0017313349526375532 KL_div:0.06511527299880981 current_lr:0.1 Time taken per iteration: 0.009329080581665039
# Step: 1720 Loss: 0.0017313509015366435 KL_div:0.06511493027210236 current_lr:0.1 Time taken per iteration: 0.010129213333129883
# Step: 1730 Loss: 0.0017313300631940365 KL_div:0.06511335074901581 current_lr:0.1 Time taken per iteration: 0.010449409484863281
# Step: 1740 Loss: 0.0017312669660896063 KL_div:0.06511034816503525 current_lr:0.1 Time taken per iteration: 0.009110212326049805
# Step: 1750 Loss: 0.0017312925774604082 KL_div:0.06511030346155167 current_lr:0.1 Time taken per iteration: 0.010236024856567383
# Step: 1760 Loss: 0.0017312773270532489 KL_div:0.06510891020298004 current_lr:0.1 Time taken per iteration: 0.009247064590454102
# Step: 1770 Loss: 0.0017312262207269669 KL_div:0.06510646641254425 current_lr:0.1 Time taken per iteration: 0.009859323501586914
# Step: 1780 Loss: 0.0017313427524641156 KL_div:0.06510943174362183 current_lr:0.1 Time taken per iteration: 0.021632909774780273
# Step: 1790 Loss: 0.0017312229610979557 KL_div:0.0651046559214592 current_lr:0.1 Time taken per iteration: 0.011586904525756836
# Step: 1800 Loss: 0.0017312172567471862 KL_div:0.06510362029075623 current_lr:0.1 Time taken per iteration: 0.010753393173217773
# Step: 1810 Loss: 0.0017312084091827273 KL_div:0.06510253250598907 current_lr:0.1 Time taken per iteration: 0.012916326522827148
# Step: 1820 Loss: 0.0017312329728156328 KL_div:0.06510242819786072 current_lr:0.1 Time taken per iteration: 0.011034011840820312
# Step: 1830 Loss: 0.0017312344862148166 KL_div:0.06510170549154282 current_lr:0.1 Time taken per iteration: 0.009867668151855469
# Step: 1840 Loss: 0.0017312074778601527 KL_div:0.06509999185800552 current_lr:0.1 Time taken per iteration: 0.012356281280517578
# Step: 1850 Loss: 0.001731179654598236 KL_div:0.06509840488433838 current_lr:0.1 Time taken per iteration: 0.010277748107910156
# Step: 1860 Loss: 0.0017312021227553487 KL_div:0.0650983601808548 current_lr:0.1 Time taken per iteration: 0.010413646697998047
# Step: 1870 Loss: 0.0017311837291345 KL_div:0.0650968998670578 current_lr:0.1 Time taken per iteration: 0.007960319519042969
# Step: 1880 Loss: 0.001731152180582285 KL_div:0.06509506702423096 current_lr:0.1 Time taken per iteration: 0.008665800094604492
# Step: 1890 Loss: 0.001731207361444831 KL_div:0.06509619206190109 current_lr:0.1 Time taken per iteration: 0.010142326354980469
# Step: 1900 Loss: 0.0017311959527432919 KL_div:0.06509503722190857 current_lr:0.1 Time taken per iteration: 0.01210927963256836
# Step: 1910 Loss: 0.0017311236588284373 KL_div:0.06509190797805786 current_lr:0.1 Time taken per iteration: 0.010256052017211914
# Step: 1920 Loss: 0.0017311290139332414 KL_div:0.06509143114089966 current_lr:0.1 Time taken per iteration: 0.011147022247314453
# Step: 1930 Loss: 0.0017311759293079376 KL_div:0.06509224325418472 current_lr:0.1 Time taken per iteration: 0.0073244571685791016
# Step: 1940 Loss: 0.0017311250558122993 KL_div:0.06508991867303848 current_lr:0.1 Time taken per iteration: 0.008225202560424805
# Step: 1950 Loss: 0.0017311155097559094 KL_div:0.06508888304233551 current_lr:0.1 Time taken per iteration: 0.009035348892211914
# Step: 1960 Loss: 0.0017310837283730507 KL_div:0.06508716940879822 current_lr:0.1 Time taken per iteration: 0.007722616195678711
# Step: 1970 Loss: 0.001731128548271954 KL_div:0.06508804857730865 current_lr:0.1 Time taken per iteration: 0.008493900299072266
# Step: 1980 Loss: 0.0017311042174696922 KL_div:0.06508651375770569 current_lr:0.1 Time taken per iteration: 0.011513471603393555
# Step: 1990 Loss: 0.0017311061965301633 KL_div:0.06508591026067734 current_lr:0.1 Time taken per iteration: 0.009419918060302734
# Step: 2000 Loss: 0.0017311176052317023 KL_div:0.06508561968803406 current_lr:0.1 Time taken per iteration: 0.010627031326293945
# Step: 2010 Loss: 0.0017310603288933635 KL_div:0.06508316844701767 current_lr:0.1 Time taken per iteration: 0.00904226303100586
# Step: 2020 Loss: 0.0017310527618974447 KL_div:0.06508231163024902 current_lr:0.1 Time taken per iteration: 0.007548332214355469
# Step: 2030 Loss: 0.0017310908297076821 KL_div:0.06508293747901917 current_lr:0.1 Time taken per iteration: 0.011469125747680664
# Step: 2040 Loss: 0.0017311021219938993 KL_div:0.06508263945579529 current_lr:0.1 Time taken per iteration: 0.008849859237670898
# Step: 2050 Loss: 0.0017310366965830326 KL_div:0.06507988274097443 current_lr:0.1 Time taken per iteration: 0.010320663452148438
# Step: 2060 Loss: 0.0017310607945546508 KL_div:0.06508013606071472 current_lr:0.1 Time taken per iteration: 0.009081363677978516
# Step: 2070 Loss: 0.0017310802359133959 KL_div:0.06508021056652069 current_lr:0.1 Time taken per iteration: 0.010278940200805664
# Step: 2080 Loss: 0.001731096301227808 KL_div:0.06508009880781174 current_lr:0.1 Time taken per iteration: 0.01012873649597168
# Step: 2090 Loss: 0.0017310590483248234 KL_div:0.06507832556962967 current_lr:0.1 Time taken per iteration: 0.008239507675170898
# Step: 2100 Loss: 0.0017310793045908213 KL_div:0.06507845222949982 current_lr:0.1 Time taken per iteration: 0.008516788482666016
# Step: 2110 Loss: 0.0017310502007603645 KL_div:0.065077044069767 current_lr:0.1 Time taken per iteration: 0.007012128829956055
# Step: 2120 Loss: 0.001731016905978322 KL_div:0.06507545709609985 current_lr:0.1 Time taken per iteration: 0.008407115936279297
# Step: 2130 Loss: 0.0017310258699581027 KL_div:0.06507521867752075 current_lr:0.1 Time taken per iteration: 0.009401559829711914
# Step: 2140 Loss: 0.0017310224939137697 KL_div:0.06507454812526703 current_lr:0.1 Time taken per iteration: 0.009603500366210938
# Step: 2150 Loss: 0.0017310318071395159 KL_div:0.0650743767619133 current_lr:0.1 Time taken per iteration: 0.010292291641235352
# Step: 2160 Loss: 0.0017310563707724214 KL_div:0.0650746300816536 current_lr:0.1 Time taken per iteration: 0.00995635986328125
# Step: 2170 Loss: 0.0017310554394498467 KL_div:0.0650741457939148 current_lr:0.1 Time taken per iteration: 0.009578227996826172
# Step: 2180 Loss: 0.001731018302962184 KL_div:0.0650724321603775 current_lr:0.1 Time taken per iteration: 0.01186513900756836
# Step: 2190 Loss: 0.001730998046696186 KL_div:0.06507126241922379 current_lr:0.1 Time taken per iteration: 0.009670257568359375
# Step: 2200 Loss: 0.0017310499679297209 KL_div:0.06507256627082825 current_lr:0.1 Time taken per iteration: 0.007456779479980469
# Step: 2210 Loss: 0.0017310285475105047 KL_div:0.0650714635848999 current_lr:0.1 Time taken per iteration: 0.007922887802124023
# Step: 2220 Loss: 0.0017310077091678977 KL_div:0.06507030129432678 current_lr:0.1 Time taken per iteration: 0.01186680793762207
# Step: 2230 Loss: 0.0017310528783127666 KL_div:0.06507129967212677 current_lr:0.1 Time taken per iteration: 0.018255233764648438
# Step: 2240 Loss: 0.0017310434486716986 KL_div:0.06507056206464767 current_lr:0.1 Time taken per iteration: 0.00948786735534668
# Step: 2250 Loss: 0.0017310070106759667 KL_div:0.06506896764039993 current_lr:0.1 Time taken per iteration: 0.010581493377685547
# Step: 2260 Loss: 0.00173102505505085 KL_div:0.06506922096014023 current_lr:0.1 Time taken per iteration: 0.008646011352539062
# Step: 2270 Loss: 0.0017310172552242875 KL_div:0.06506861001253128 current_lr:0.1 Time taken per iteration: 0.010057449340820312
# Step: 2280 Loss: 0.0017310227267444134 KL_div:0.06506843119859695 current_lr:0.1 Time taken per iteration: 0.006860971450805664
# Step: 2290 Loss: 0.0017310030525550246 KL_div:0.06506739556789398 current_lr:0.1 Time taken per iteration: 0.008292913436889648
# Step: 2300 Loss: 0.001731040421873331 KL_div:0.06506820023059845 current_lr:0.1 Time taken per iteration: 0.009435415267944336
# Step: 2310 Loss: 0.00173102761618793 KL_div:0.06506740301847458 current_lr:0.1 Time taken per iteration: 0.010937690734863281
# Step: 2320 Loss: 0.0017310302937403321 KL_div:0.06506716459989548 current_lr:0.1 Time taken per iteration: 0.00928044319152832
# Step: 2330 Loss: 0.0017309754621237516 KL_div:0.06506501138210297 current_lr:0.1 Time taken per iteration: 0.010415792465209961
# Step: 2340 Loss: 0.0017310593975707889 KL_div:0.065067358314991 current_lr:0.1 Time taken per iteration: 0.010951757431030273
# Step: 2350 Loss: 0.0017310504335910082 KL_div:0.06506674736738205 current_lr:0.1 Time taken per iteration: 0.009410619735717773
# Step: 2360 Loss: 0.0017310030525550246 KL_div:0.06506484746932983 current_lr:0.1 Time taken per iteration: 0.00870203971862793
# Step: 2370 Loss: 0.0017310339026153088 KL_div:0.06506559252738953 current_lr:0.1 Time taken per iteration: 0.009739398956298828
# Step: 2380 Loss: 0.0017310365801677108 KL_div:0.06506534665822983 current_lr:0.1 Time taken per iteration: 0.01125025749206543
# Step: 2390 Loss: 0.0017310208640992641 KL_div:0.06506454944610596 current_lr:0.1 Time taken per iteration: 0.023899078369140625
# Step: 2400 Loss: 0.0017310013063251972 KL_div:0.06506363302469254 current_lr:0.1 Time taken per iteration: 0.007312297821044922
# Step: 2410 Loss: 0.0017310240073129535 KL_div:0.06506413221359253 current_lr:0.1 Time taken per iteration: 0.010920286178588867
# Step: 2420 Loss: 0.0017309963004663587 KL_div:0.06506290286779404 current_lr:0.1 Time taken per iteration: 0.008149862289428711
# Step: 2430 Loss: 0.0017310305265709758 KL_div:0.06506383419036865 current_lr:0.1 Time taken per iteration: 0.010303735733032227
# Step: 2440 Loss: 0.001730999443680048 KL_div:0.06506253778934479 current_lr:0.1 Time taken per iteration: 0.007893085479736328
# Step: 2450 Loss: 0.001731021679006517 KL_div:0.0650629773736 current_lr:0.1 Time taken per iteration: 0.00958108901977539
# Step: 2460 Loss: 0.0017310400726273656 KL_div:0.0650632232427597 current_lr:0.1 Time taken per iteration: 0.007972240447998047
# Step: 2470 Loss: 0.0017309788381680846 KL_div:0.06506095826625824 current_lr:0.1 Time taken per iteration: 0.009051322937011719
# Step: 2480 Loss: 0.0017309978138655424 KL_div:0.06506139039993286 current_lr:0.1 Time taken per iteration: 0.007086515426635742
# Step: 2490 Loss: 0.0017309701070189476 KL_div:0.06506040692329407 current_lr:0.1 Time taken per iteration: 0.021130084991455078
# Step: 2500 Loss: 0.001731027034111321 KL_div:0.0650620087981224 current_lr:0.1 Time taken per iteration: 0.008192300796508789
# Step: 2510 Loss: 0.0017310228431597352 KL_div:0.0650615245103836 current_lr:0.1 Time taken per iteration: 0.008659839630126953
# Step: 2520 Loss: 0.0017310261027887464 KL_div:0.06506134569644928 current_lr:0.1 Time taken per iteration: 0.008540153503417969
# Step: 2530 Loss: 0.0017310072435066104 KL_div:0.06506048142910004 current_lr:0.1 Time taken per iteration: 0.006997585296630859
# Step: 2540 Loss: 0.0017310063121840358 KL_div:0.06506024301052094 current_lr:0.1 Time taken per iteration: 0.01041555404663086
# Step: 2550 Loss: 0.001731021562591195 KL_div:0.06506054848432541 current_lr:0.1 Time taken per iteration: 0.010141372680664062
# Step: 2560 Loss: 0.0017309943214058876 KL_div:0.06505944579839706 current_lr:0.1 Time taken per iteration: 0.009652853012084961
# Step: 2570 Loss: 0.00173097662627697 KL_div:0.06505870819091797 current_lr:0.1 Time taken per iteration: 0.00915217399597168
# Step: 2580 Loss: 0.0017310070106759667 KL_div:0.06505963206291199 current_lr:0.1 Time taken per iteration: 0.00796055793762207
# Step: 2590 Loss: 0.0017310562543570995 KL_div:0.06506111472845078 current_lr:0.1 Time taken per iteration: 0.009301185607910156
# Step: 2600 Loss: 0.001731021562591195 KL_div:0.06505969911813736 current_lr:0.1 Time taken per iteration: 0.012160062789916992
# Step: 2610 Loss: 0.0017309908289462328 KL_div:0.06505846977233887 current_lr:0.1 Time taken per iteration: 0.010036706924438477
# Step: 2620 Loss: 0.0017310052644461393 KL_div:0.06505884230136871 current_lr:0.1 Time taken per iteration: 0.009332418441772461
# Step: 2630 Loss: 0.001731020980514586 KL_div:0.06505921483039856 current_lr:0.1 Time taken per iteration: 0.008143424987792969
# Step: 2640 Loss: 0.001730978605337441 KL_div:0.06505762040615082 current_lr:0.1 Time taken per iteration: 0.02585148811340332
# Step: 2650 Loss: 0.0017310699913650751 KL_div:0.06506039202213287 current_lr:0.1 Time taken per iteration: 0.00981903076171875
# Step: 2660 Loss: 0.0017310087569057941 KL_div:0.06505823880434036 current_lr:0.1 Time taken per iteration: 0.010212182998657227
# Step: 2670 Loss: 0.0017310240073129535 KL_div:0.06505861133337021 current_lr:0.1 Time taken per iteration: 0.009981632232666016
# Step: 2680 Loss: 0.0017310044495388865 KL_div:0.06505787372589111 current_lr:0.1 Time taken per iteration: 0.010048389434814453
# Step: 2690 Loss: 0.001730981282889843 KL_div:0.0650569498538971 current_lr:0.1 Time taken per iteration: 0.009722471237182617
# Step: 2700 Loss: 0.0017310003750026226 KL_div:0.06505744159221649 current_lr:0.1 Time taken per iteration: 0.00937652587890625
# Step: 2710 Loss: 0.0017310200491920114 KL_div:0.06505794078111649 current_lr:0.1 Time taken per iteration: 0.008555889129638672
# Step: 2720 Loss: 0.0017309847753494978 KL_div:0.065056711435318 current_lr:0.1 Time taken per iteration: 0.008494853973388672
# Step: 2730 Loss: 0.0017310231924057007 KL_div:0.06505794078111649 current_lr:0.1 Time taken per iteration: 0.009592771530151367
# Step: 2740 Loss: 0.0017309854738414288 KL_div:0.0650564655661583 current_lr:0.1 Time taken per iteration: 0.0064373016357421875
# Step: 2750 Loss: 0.001730950316414237 KL_div:0.0650552362203598 current_lr:0.1 Time taken per iteration: 0.02053046226501465
# Step: 2760 Loss: 0.0017310235416516662 KL_div:0.06505751609802246 current_lr:0.1 Time taken per iteration: 0.008952856063842773
# Step: 2770 Loss: 0.0017309888498857617 KL_div:0.06505628675222397 current_lr:0.1 Time taken per iteration: 0.010131597518920898
# Step: 2780 Loss: 0.0017309774411842227 KL_div:0.06505580246448517 current_lr:0.1 Time taken per iteration: 0.009146928787231445
# Step: 2790 Loss: 0.001731022377498448 KL_div:0.06505715847015381 current_lr:0.1 Time taken per iteration: 0.008178472518920898
# Step: 2800 Loss: 0.0017310302937403321 KL_div:0.06505727767944336 current_lr:0.1 Time taken per iteration: 0.007960319519042969
# Step: 2810 Loss: 0.0017310454277321696 KL_div:0.06505759060382843 current_lr:0.1 Time taken per iteration: 0.010335445404052734
# Step: 2820 Loss: 0.0017310152761638165 KL_div:0.06505654007196426 current_lr:0.1 Time taken per iteration: 0.006936788558959961
# Step: 2830 Loss: 0.0017310152761638165 KL_div:0.06505654007196426 current_lr:0.1 Time taken per iteration: 0.0071315765380859375
# Step: 2840 Loss: 0.0017309645190835 KL_div:0.06505487859249115 current_lr:0.1 Time taken per iteration: 0.008026838302612305
# Step: 2850 Loss: 0.0017310110852122307 KL_div:0.06505635380744934 current_lr:0.1 Time taken per iteration: 0.00941610336303711
# Step: 2860 Loss: 0.0017309957183897495 KL_div:0.0650557428598404 current_lr:0.1 Time taken per iteration: 0.010417461395263672
# Step: 2870 Loss: 0.0017309916438534856 KL_div:0.06505550444126129 current_lr:0.1 Time taken per iteration: 0.00984954833984375
# Step: 2880 Loss: 0.0017310110852122307 KL_div:0.06505611538887024 current_lr:0.1 Time taken per iteration: 0.010027408599853516
# Step: 2890 Loss: 0.0017310064285993576 KL_div:0.06505587697029114 current_lr:0.1 Time taken per iteration: 0.008181571960449219
# Step: 2900 Loss: 0.00173099129460752 KL_div:0.06505525857210159 current_lr:0.1 Time taken per iteration: 0.00964212417602539
# Step: 2910 Loss: 0.0017310417024418712 KL_div:0.06505686044692993 current_lr:0.1 Time taken per iteration: 0.007287740707397461
# Step: 2920 Loss: 0.0017310100374743342 KL_div:0.06505575031042099 current_lr:0.1 Time taken per iteration: 0.009556770324707031
# Step: 2930 Loss: 0.0017309654504060745 KL_div:0.0650542750954628 current_lr:0.1 Time taken per iteration: 0.010393381118774414
# Step: 2940 Loss: 0.0017309882678091526 KL_div:0.0650550127029419 current_lr:0.1 Time taken per iteration: 0.009443044662475586
# Step: 2950 Loss: 0.0017309843096882105 KL_div:0.06505483388900757 current_lr:0.1 Time taken per iteration: 0.010035276412963867
# Step: 2960 Loss: 0.0017310117837041616 KL_div:0.06505563110113144 current_lr:0.1 Time taken per iteration: 0.0072040557861328125
# Step: 2970 Loss: 0.0017310272669419646 KL_div:0.06505606323480606 current_lr:0.1 Time taken per iteration: 0.010274410247802734
# Step: 2980 Loss: 0.0017309841932728887 KL_div:0.06505458801984787 current_lr:0.1 Time taken per iteration: 0.009306192398071289
# Step: 2990 Loss: 0.0017310043331235647 KL_div:0.06505520641803741 current_lr:0.1 Time taken per iteration: 0.009939908981323242
# Step: 3000 Loss: 0.0017309885006397963 KL_div:0.06505464762449265 current_lr:0.1 Time taken per iteration: 0.009885549545288086
# Step: 3010 Loss: 0.0017309724353253841 KL_div:0.06505409628152847 current_lr:0.1 Time taken per iteration: 0.010067462921142578
# Step: 3020 Loss: 0.001731011550873518 KL_div:0.06505538523197174 current_lr:0.1 Time taken per iteration: 0.008981704711914062
# Step: 3030 Loss: 0.0017310036346316338 KL_div:0.06505514681339264 current_lr:0.1 Time taken per iteration: 0.009601116180419922
# Step: 3040 Loss: 0.0017309954855591059 KL_div:0.06505483388900757 current_lr:0.1 Time taken per iteration: 0.007547140121459961
# Step: 3050 Loss: 0.0017309535760432482 KL_div:0.06505341827869415 current_lr:0.1 Time taken per iteration: 0.008291959762573242
# Step: 3060 Loss: 0.001731019001454115 KL_div:0.06505551189184189 current_lr:0.1 Time taken per iteration: 0.007021427154541016
# Step: 3070 Loss: 0.0017309847753494978 KL_div:0.06505422294139862 current_lr:0.1 Time taken per iteration: 0.008469104766845703
# Step: 3080 Loss: 0.0017309542745351791 KL_div:0.06505323946475983 current_lr:0.1 Time taken per iteration: 0.009140968322753906
# Step: 3090 Loss: 0.0017309802351519465 KL_div:0.0650540366768837 current_lr:0.1 Time taken per iteration: 0.009226560592651367
# Step: 3100 Loss: 0.0017309958348050714 KL_div:0.0650545284152031 current_lr:0.1 Time taken per iteration: 0.009004592895507812
# Step: 3110 Loss: 0.001730983960442245 KL_div:0.06505410373210907 current_lr:0.1 Time taken per iteration: 0.008164405822753906
# Step: 3120 Loss: 0.0017311135306954384 KL_div:0.0650579184293747 current_lr:0.1 Time taken per iteration: 0.010083675384521484
# Step: 3130 Loss: 0.0017470987513661385 KL_div:0.06553423404693604 current_lr:0.1 Time taken per iteration: 0.009227514266967773
# Step: 3140 Loss: 0.49571138620376587 KL_div:2.1583786010742188 current_lr:0.1 Time taken per iteration: 0.010140657424926758
# Step: 3150 Loss: 0.11456440389156342 KL_div:0.7767795324325562 current_lr:0.1 Time taken per iteration: 0.0070340633392333984
# Step: 3160 Loss: 0.032091643661260605 KL_div:0.3704427480697632 current_lr:0.1 Time taken per iteration: 0.008003473281860352
# Step: 3170 Loss: 0.01351228915154934 KL_div:0.2285090833902359 current_lr:0.1 Time taken per iteration: 0.0063550472259521484
# Step: 3180 Loss: 0.008052011951804161 KL_div:0.1739049106836319 current_lr:0.1 Time taken per iteration: 0.008332252502441406
# Step: 3190 Loss: 0.006622824817895889 KL_div:0.1559440791606903 current_lr:0.1 Time taken per iteration: 0.00727391242980957
# Step: 3200 Loss: 0.005999005399644375 KL_div:0.14629781246185303 current_lr:0.1 Time taken per iteration: 0.021165132522583008
# Step: 3210 Loss: 0.0057270340621471405 KL_div:0.14213448762893677 current_lr:0.1 Time taken per iteration: 0.008008718490600586
# Step: 3220 Loss: 0.005614772439002991 KL_div:0.13947007060050964 current_lr:0.1 Time taken per iteration: 0.008421659469604492
# Step: 3230 Loss: 0.005571851506829262 KL_div:0.13858720660209656 current_lr:0.1 Time taken per iteration: 0.009146451950073242
# Step: 3240 Loss: 0.005541343241930008 KL_div:0.13784538209438324 current_lr:0.1 Time taken per iteration: 0.008113622665405273
# Step: 3250 Loss: 0.0055219512432813644 KL_div:0.13740569353103638 current_lr:0.1 Time taken per iteration: 0.00725245475769043
# Step: 3260 Loss: 0.005504700355231762 KL_div:0.1371821165084839 current_lr:0.1 Time taken per iteration: 0.010415077209472656
# Step: 3270 Loss: 0.005488488357514143 KL_div:0.13692906498908997 current_lr:0.1 Time taken per iteration: 0.006724119186401367
# Step: 3280 Loss: 0.005472777411341667 KL_div:0.13672494888305664 current_lr:0.1 Time taken per iteration: 0.00888204574584961
# Step: 3290 Loss: 0.005457072518765926 KL_div:0.13651397824287415 current_lr:0.1 Time taken per iteration: 0.007986307144165039
# Step: 3300 Loss: 0.00544097600504756 KL_div:0.13631238043308258 current_lr:0.1 Time taken per iteration: 0.007342338562011719
# Step: 3310 Loss: 0.005424529779702425 KL_div:0.13611668348312378 current_lr:0.1 Time taken per iteration: 0.009130239486694336
# Step: 3320 Loss: 0.005407439544796944 KL_div:0.13590684533119202 current_lr:0.1 Time taken per iteration: 0.009359598159790039
# Step: 3330 Loss: 0.0053895642049610615 KL_div:0.1356831192970276 current_lr:0.1 Time taken per iteration: 0.0077855587005615234
# Step: 3340 Loss: 0.005370641592890024 KL_div:0.13543733954429626 current_lr:0.1 Time taken per iteration: 0.012697696685791016
# Step: 3350 Loss: 0.005350450053811073 KL_div:0.1351650208234787 current_lr:0.1 Time taken per iteration: 0.007845401763916016
# Step: 3360 Loss: 0.0053288983181118965 KL_div:0.1348627656698227 current_lr:0.1 Time taken per iteration: 0.007627248764038086
# Step: 3370 Loss: 0.005305733531713486 KL_div:0.13452377915382385 current_lr:0.1 Time taken per iteration: 0.010371685028076172
# Step: 3380 Loss: 0.0052805873565375805 KL_div:0.1341397613286972 current_lr:0.1 Time taken per iteration: 0.008825540542602539
# Step: 3390 Loss: 0.005253013223409653 KL_div:0.13370096683502197 current_lr:0.1 Time taken per iteration: 0.008488178253173828
# Step: 3400 Loss: 0.005223022773861885 KL_div:0.1332058310508728 current_lr:0.1 Time taken per iteration: 0.008672237396240234
# Step: 3410 Loss: 0.005189498420804739 KL_div:0.132634699344635 current_lr:0.1 Time taken per iteration: 0.0069272518157958984
# Step: 3420 Loss: 0.005152290686964989 KL_div:0.13198554515838623 current_lr:0.1 Time taken per iteration: 0.00745081901550293
# Step: 3430 Loss: 0.005110274069011211 KL_div:0.1312425136566162 current_lr:0.1 Time taken per iteration: 0.009933233261108398
# Step: 3440 Loss: 0.005061732605099678 KL_div:0.13038396835327148 current_lr:0.1 Time taken per iteration: 0.008577585220336914
# Step: 3450 Loss: 0.00500470120459795 KL_div:0.12939073145389557 current_lr:0.1 Time taken per iteration: 0.009865283966064453
# Step: 3460 Loss: 0.004935691133141518 KL_div:0.12822815775871277 current_lr:0.1 Time taken per iteration: 0.006963253021240234
# Step: 3470 Loss: 0.0048494297079741955 KL_div:0.126846581697464 current_lr:0.1 Time taken per iteration: 0.009582042694091797
# Step: 3480 Loss: 0.004738654009997845 KL_div:0.12518274784088135 current_lr:0.1 Time taken per iteration: 0.009428739547729492
# Step: 3490 Loss: 0.004593410529196262 KL_div:0.12314421683549881 current_lr:0.1 Time taken per iteration: 0.006728649139404297
# Step: 3500 Loss: 0.004404892213642597 KL_div:0.12064389884471893 current_lr:0.1 Time taken per iteration: 0.008092403411865234
# Step: 3510 Loss: 0.004176028072834015 KL_div:0.11769698560237885 current_lr:0.1 Time taken per iteration: 0.0197446346282959
# Step: 3520 Loss: 0.003935873042792082 KL_div:0.11458859592676163 current_lr:0.1 Time taken per iteration: 0.007662057876586914
# Step: 3530 Loss: 0.0037320759147405624 KL_div:0.11190548539161682 current_lr:0.1 Time taken per iteration: 0.01047515869140625
# Step: 3540 Loss: 0.0035879830829799175 KL_div:0.1100950688123703 current_lr:0.1 Time taken per iteration: 0.021445512771606445
# Step: 3550 Loss: 0.0034932480193674564 KL_div:0.10913973301649094 current_lr:0.1 Time taken per iteration: 0.006890058517456055
# Step: 3560 Loss: 0.003429429605603218 KL_div:0.10871085524559021 current_lr:0.1 Time taken per iteration: 0.00883030891418457
# Step: 3570 Loss: 0.003384778741747141 KL_div:0.10852324962615967 current_lr:0.1 Time taken per iteration: 0.0063059329986572266
# Step: 3580 Loss: 0.003353261621668935 KL_div:0.10844698548316956 current_lr:0.1 Time taken per iteration: 0.007483720779418945
# Step: 3590 Loss: 0.0033303312957286835 KL_div:0.10840476304292679 current_lr:0.1 Time taken per iteration: 0.0078582763671875
# Step: 3600 Loss: 0.003314336994662881 KL_div:0.10837940871715546 current_lr:0.1 Time taken per iteration: 0.009726524353027344
# Step: 3610 Loss: 0.0033030901104211807 KL_div:0.10835455358028412 current_lr:0.1 Time taken per iteration: 0.019082069396972656
# Step: 3620 Loss: 0.0032957084476947784 KL_div:0.10833781212568283 current_lr:0.1 Time taken per iteration: 0.009943962097167969
# Step: 3630 Loss: 0.003290913300588727 KL_div:0.10832472145557404 current_lr:0.1 Time taken per iteration: 0.00719451904296875
# Step: 3640 Loss: 0.0032879244536161423 KL_div:0.10831572860479355 current_lr:0.1 Time taken per iteration: 0.0076770782470703125
# Step: 3650 Loss: 0.0032861651852726936 KL_div:0.10831087827682495 current_lr:0.1 Time taken per iteration: 0.013975381851196289
# Step: 3660 Loss: 0.0032852250151336193 KL_div:0.10830987989902496 current_lr:0.1 Time taken per iteration: 0.00928640365600586
# Step: 3670 Loss: 0.003284530946984887 KL_div:0.1083064153790474 current_lr:0.1 Time taken per iteration: 0.01119232177734375
# Step: 3680 Loss: 0.0032841116189956665 KL_div:0.1083042174577713 current_lr:0.1 Time taken per iteration: 0.007531642913818359
# Step: 3690 Loss: 0.0032838552724570036 KL_div:0.10830289125442505 current_lr:0.1 Time taken per iteration: 0.008626699447631836
# Step: 3700 Loss: 0.0032837148755788803 KL_div:0.1083025187253952 current_lr:0.1 Time taken per iteration: 0.006852865219116211
# Step: 3710 Loss: 0.0032835067249834538 KL_div:0.10830000042915344 current_lr:0.1 Time taken per iteration: 0.011307716369628906
# Step: 3720 Loss: 0.003283399622887373 KL_div:0.10829898715019226 current_lr:0.1 Time taken per iteration: 0.008096933364868164
# Step: 3730 Loss: 0.003283281344920397 KL_div:0.10829741507768631 current_lr:0.1 Time taken per iteration: 0.02135324478149414
# Step: 3740 Loss: 0.003283220110461116 KL_div:0.10829678922891617 current_lr:0.1 Time taken per iteration: 0.011623859405517578
# Step: 3750 Loss: 0.00328318914398551 KL_div:0.10829660296440125 current_lr:0.1 Time taken per iteration: 0.007665157318115234
# Step: 3760 Loss: 0.0032831188291311264 KL_div:0.10829553008079529 current_lr:0.1 Time taken per iteration: 0.006594657897949219
# Step: 3770 Loss: 0.0032830648124217987 KL_div:0.10829471051692963 current_lr:0.1 Time taken per iteration: 0.009904146194458008
# Step: 3780 Loss: 0.003282956313341856 KL_div:0.10829275846481323 current_lr:0.1 Time taken per iteration: 0.010290861129760742
# Step: 3790 Loss: 0.003282979829236865 KL_div:0.10829339176416397 current_lr:0.1 Time taken per iteration: 0.01915431022644043
# Step: 3800 Loss: 0.003282888326793909 KL_div:0.10829169303178787 current_lr:0.1 Time taken per iteration: 0.010883331298828125
# Step: 3810 Loss: 0.0032829237170517445 KL_div:0.10829250514507294 current_lr:0.1 Time taken per iteration: 0.009732484817504883
# Step: 3820 Loss: 0.0032827546820044518 KL_div:0.10828924179077148 current_lr:0.1 Time taken per iteration: 0.00970458984375
# Step: 3830 Loss: 0.0032827225513756275 KL_div:0.10828866809606552 current_lr:0.1 Time taken per iteration: 0.008376836776733398
# Step: 3840 Loss: 0.003282801015302539 KL_div:0.10829030722379684 current_lr:0.1 Time taken per iteration: 0.011857986450195312
# Step: 3850 Loss: 0.0032827104441821575 KL_div:0.10828854888677597 current_lr:0.1 Time taken per iteration: 0.012402057647705078
# Step: 3860 Loss: 0.003282656893134117 KL_div:0.10828754305839539 current_lr:0.1 Time taken per iteration: 0.009506702423095703
# Step: 3870 Loss: 0.0032827090471982956 KL_div:0.10828860849142075 current_lr:0.1 Time taken per iteration: 0.007441282272338867
# Step: 3880 Loss: 0.0032826685346663 KL_div:0.10828785598278046 current_lr:0.1 Time taken per iteration: 0.007298469543457031
# Step: 3890 Loss: 0.003282541176304221 KL_div:0.1082853376865387 current_lr:0.1 Time taken per iteration: 0.009252309799194336
# Step: 3900 Loss: 0.00328257423825562 KL_div:0.10828603059053421 current_lr:0.1 Time taken per iteration: 0.008440732955932617
# Step: 3910 Loss: 0.0032826545648276806 KL_div:0.10828766226768494 current_lr:0.1 Time taken per iteration: 0.008322954177856445
# Step: 3920 Loss: 0.0032825435046106577 KL_div:0.10828545689582825 current_lr:0.1 Time taken per iteration: 0.009991168975830078
# Step: 3930 Loss: 0.0032825986854732037 KL_div:0.10828658938407898 current_lr:0.1 Time taken per iteration: 0.007355213165283203
# Step: 3940 Loss: 0.0032825437374413013 KL_div:0.10828552395105362 current_lr:0.1 Time taken per iteration: 0.00980234146118164
# Step: 3950 Loss: 0.0032824166119098663 KL_div:0.10828301310539246 current_lr:0.1 Time taken per iteration: 0.0076141357421875
# Step: 3960 Loss: 0.0032824850641191006 KL_div:0.10828439146280289 current_lr:0.1 Time taken per iteration: 0.009108543395996094
# Step: 3970 Loss: 0.0032824089284986258 KL_div:0.10828287899494171 current_lr:0.1 Time taken per iteration: 0.007642507553100586
# Step: 3980 Loss: 0.0032824587542563677 KL_div:0.1082838922739029 current_lr:0.1 Time taken per iteration: 0.008953094482421875
# Step: 3990 Loss: 0.0032824580557644367 KL_div:0.1082838922739029 current_lr:0.1 Time taken per iteration: 0.007190227508544922
# Step: 4000 Loss: 0.003282485529780388 KL_div:0.10828445851802826 current_lr:0.1 Time taken per iteration: 0.009982824325561523
# Step: 4010 Loss: 0.003282340243458748 KL_div:0.10828156024217606 current_lr:0.1 Time taken per iteration: 0.015792131423950195
# Step: 4020 Loss: 0.003282484132796526 KL_div:0.10828445851802826 current_lr:0.1 Time taken per iteration: 0.006918191909790039
# Step: 4030 Loss: 0.003282432910054922 KL_div:0.10828344523906708 current_lr:0.1 Time taken per iteration: 0.007125377655029297
# Step: 4040 Loss: 0.00328241428360343 KL_div:0.10828307271003723 current_lr:0.1 Time taken per iteration: 0.01019597053527832
# Step: 4050 Loss: 0.0032823621295392513 KL_div:0.10828206688165665 current_lr:0.1 Time taken per iteration: 0.01009058952331543
# Step: 4060 Loss: 0.003282280173152685 KL_div:0.10828042775392532 current_lr:0.1 Time taken per iteration: 0.009607791900634766
# Step: 4070 Loss: 0.0032823425717651844 KL_div:0.1082816869020462 current_lr:0.1 Time taken per iteration: 0.010358095169067383
# Step: 4080 Loss: 0.003282238030806184 KL_div:0.10827961564064026 current_lr:0.1 Time taken per iteration: 0.006971120834350586
# Step: 4090 Loss: 0.003282306483015418 KL_div:0.10828100144863129 current_lr:0.1 Time taken per iteration: 0.0075531005859375
# Step: 4100 Loss: 0.0032822811044752598 KL_div:0.1082804948091507 current_lr:0.1 Time taken per iteration: 0.007220745086669922
# Step: 4110 Loss: 0.0032823251094669104 KL_div:0.10828137397766113 current_lr:0.1 Time taken per iteration: 0.007301807403564453
# Step: 4120 Loss: 0.0032823248766362667 KL_div:0.10828137397766113 current_lr:0.1 Time taken per iteration: 0.007645845413208008
# Step: 4130 Loss: 0.003282261313870549 KL_div:0.10828011482954025 current_lr:0.1 Time taken per iteration: 0.007618427276611328
# Step: 4140 Loss: 0.0032822799403220415 KL_div:0.1082804948091507 current_lr:0.1 Time taken per iteration: 0.010187864303588867
# Step: 4150 Loss: 0.0032822100911289454 KL_div:0.10827910900115967 current_lr:0.1 Time taken per iteration: 0.010251522064208984
# Step: 4160 Loss: 0.0032822354696691036 KL_div:0.10827961564064026 current_lr:0.1 Time taken per iteration: 0.009932994842529297
# Step: 4170 Loss: 0.003282155841588974 KL_div:0.10827803611755371 current_lr:0.1 Time taken per iteration: 0.007290840148925781
# Step: 4180 Loss: 0.0032821237109601498 KL_div:0.10827741026878357 current_lr:0.1 Time taken per iteration: 0.010088205337524414
# Step: 4190 Loss: 0.003282255958765745 KL_div:0.10828004777431488 current_lr:0.1 Time taken per iteration: 0.009300947189331055
# Step: 4200 Loss: 0.0032821986824274063 KL_div:0.10827891528606415 current_lr:0.1 Time taken per iteration: 0.006665468215942383
# Step: 4210 Loss: 0.0032822079956531525 KL_div:0.10827910900115967 current_lr:0.1 Time taken per iteration: 0.009515762329101562
# Step: 4220 Loss: 0.003282188670709729 KL_div:0.10827873647212982 current_lr:0.1 Time taken per iteration: 0.009901762008666992
# Step: 4230 Loss: 0.0032822578214108944 KL_div:0.10828011482954025 current_lr:0.1 Time taken per iteration: 0.020569801330566406
# Step: 4240 Loss: 0.0032821372151374817 KL_div:0.10827772319316864 current_lr:0.1 Time taken per iteration: 0.008443117141723633
# Step: 4250 Loss: 0.003282149787992239 KL_div:0.10827797651290894 current_lr:0.1 Time taken per iteration: 0.010244369506835938
# Step: 4260 Loss: 0.003282143734395504 KL_div:0.10827784985303879 current_lr:0.1 Time taken per iteration: 0.006620168685913086
# Step: 4270 Loss: 0.0032820925116539 KL_div:0.1082768440246582 current_lr:0.1 Time taken per iteration: 0.007847785949707031
# Step: 4280 Loss: 0.003282105317339301 KL_div:0.1082770973443985 current_lr:0.1 Time taken per iteration: 0.009231328964233398
# Step: 4290 Loss: 0.0032820925116539 KL_div:0.1082768440246582 current_lr:0.1 Time taken per iteration: 0.00780034065246582
# Step: 4300 Loss: 0.0032821549102663994 KL_div:0.10827809572219849 current_lr:0.1 Time taken per iteration: 0.008329629898071289
# Step: 4310 Loss: 0.003282098099589348 KL_div:0.10827696323394775 current_lr:0.1 Time taken per iteration: 0.018559932708740234
# Step: 4320 Loss: 0.0032821428030729294 KL_div:0.10827784985303879 current_lr:0.1 Time taken per iteration: 0.006842851638793945
# Step: 4330 Loss: 0.0032820915803313255 KL_div:0.1082768440246582 current_lr:0.1 Time taken per iteration: 0.009274721145629883
# Step: 4340 Loss: 0.0032820473425090313 KL_div:0.10827596485614777 current_lr:0.1 Time taken per iteration: 0.008639335632324219
# Step: 4350 Loss: 0.003282091347500682 KL_div:0.1082768440246582 current_lr:0.1 Time taken per iteration: 0.010718584060668945
# Step: 4360 Loss: 0.0032820338383316994 KL_div:0.10827571153640747 current_lr:0.1 Time taken per iteration: 0.007531404495239258
# Step: 4370 Loss: 0.0032820659689605236 KL_div:0.10827633738517761 current_lr:0.1 Time taken per iteration: 0.022155046463012695
# Step: 4380 Loss: 0.0032820403575897217 KL_div:0.10827583074569702 current_lr:0.1 Time taken per iteration: 0.01003575325012207
# Step: 4390 Loss: 0.0032821097411215305 KL_div:0.10827721655368805 current_lr:0.1 Time taken per iteration: 0.01025390625
# Step: 4400 Loss: 0.003282128134742379 KL_div:0.10827759653329849 current_lr:0.1 Time taken per iteration: 0.008587360382080078
# Step: 4410 Loss: 0.003282077144831419 KL_div:0.10827659070491791 current_lr:0.1 Time taken per iteration: 0.006880760192871094
# Step: 4420 Loss: 0.0032820706255733967 KL_div:0.10827646404504776 current_lr:0.1 Time taken per iteration: 0.008301258087158203
# Step: 4430 Loss: 0.0032821460627019405 KL_div:0.10827797651290894 current_lr:0.1 Time taken per iteration: 0.009971141815185547
# Step: 4440 Loss: 0.0032821025233715773 KL_div:0.1082770973443985 current_lr:0.1 Time taken per iteration: 0.007483243942260742
# Step: 4450 Loss: 0.0032820641063153744 KL_div:0.10827633738517761 current_lr:0.1 Time taken per iteration: 0.011659860610961914
# Step: 4460 Loss: 0.003282064339146018 KL_div:0.10827633738517761 current_lr:0.1 Time taken per iteration: 0.012807846069335938
# Step: 4470 Loss: 0.0032820641063153744 KL_div:0.10827633738517761 current_lr:0.1 Time taken per iteration: 0.0166168212890625
# Step: 4480 Loss: 0.003281981684267521 KL_div:0.10827469825744629 current_lr:0.1 Time taken per iteration: 0.009566545486450195
# Step: 4490 Loss: 0.003282069694250822 KL_div:0.10827646404504776 current_lr:0.1 Time taken per iteration: 0.012373208999633789
# Step: 4500 Loss: 0.0032821393106132746 KL_div:0.10827784985303879 current_lr:0.1 Time taken per iteration: 0.01859760284423828
# Step: 4510 Loss: 0.0032820822671055794 KL_div:0.10827671736478806 current_lr:0.1 Time taken per iteration: 0.009199380874633789
# Step: 4520 Loss: 0.003282031510025263 KL_div:0.10827571153640747 current_lr:0.1 Time taken per iteration: 0.007558107376098633
# Step: 4530 Loss: 0.003282012650743127 KL_div:0.10827533155679703 current_lr:0.1 Time taken per iteration: 0.009564638137817383
# Step: 4540 Loss: 0.0032819900661706924 KL_div:0.10827489197254181 current_lr:0.1 Time taken per iteration: 0.008600711822509766
# Step: 4550 Loss: 0.0032820343039929867 KL_div:0.10827577114105225 current_lr:0.1 Time taken per iteration: 0.012120723724365234
# Step: 4560 Loss: 0.0032819965854287148 KL_div:0.10827501863241196 current_lr:0.1 Time taken per iteration: 0.008077621459960938
# Step: 4570 Loss: 0.0032820026390254498 KL_div:0.1082751452922821 current_lr:0.1 Time taken per iteration: 0.009535551071166992
# Step: 4580 Loss: 0.003281951881945133 KL_div:0.10827413946390152 current_lr:0.1 Time taken per iteration: 0.01026296615600586
# Step: 4590 Loss: 0.0032820086926221848 KL_div:0.10827527195215225 current_lr:0.1 Time taken per iteration: 0.008317232131958008
# Step: 4600 Loss: 0.003282071789726615 KL_div:0.10827653110027313 current_lr:0.1 Time taken per iteration: 0.008190631866455078
# Step: 4610 Loss: 0.003282052930444479 KL_div:0.10827615112066269 current_lr:0.1 Time taken per iteration: 0.008593559265136719
# Step: 4620 Loss: 0.003281970974057913 KL_div:0.10827451199293137 current_lr:0.1 Time taken per iteration: 0.010312795639038086
# Step: 4630 Loss: 0.003282058984041214 KL_div:0.10827627778053284 current_lr:0.1 Time taken per iteration: 0.008338212966918945
# Step: 4640 Loss: 0.0032820082269608974 KL_div:0.10827527195215225 current_lr:0.1 Time taken per iteration: 0.0099639892578125
# Step: 4650 Loss: 0.0032819267362356186 KL_div:0.10827363282442093 current_lr:0.1 Time taken per iteration: 0.01044464111328125
# Step: 4660 Loss: 0.003281989600509405 KL_div:0.10827489197254181 current_lr:0.1 Time taken per iteration: 0.0102691650390625
# Step: 4670 Loss: 0.0032820329070091248 KL_div:0.10827577114105225 current_lr:0.1 Time taken per iteration: 0.00995326042175293
# Step: 4680 Loss: 0.003281977027654648 KL_div:0.10827463865280151 current_lr:0.1 Time taken per iteration: 0.009525537490844727
# Step: 4690 Loss: 0.0032820275519043207 KL_div:0.1082756444811821 current_lr:0.1 Time taken per iteration: 0.010560989379882812
# Step: 4700 Loss: 0.003282020566985011 KL_div:0.10827551782131195 current_lr:0.1 Time taken per iteration: 0.019736528396606445
# Step: 4710 Loss: 0.003281976096332073 KL_div:0.10827463865280151 current_lr:0.1 Time taken per iteration: 0.011287927627563477
# Step: 4720 Loss: 0.003281976329162717 KL_div:0.10827463865280151 current_lr:0.1 Time taken per iteration: 0.00979161262512207
# Step: 4730 Loss: 0.0032820585183799267 KL_div:0.10827627778053284 current_lr:0.1 Time taken per iteration: 0.0071451663970947266
# Step: 4740 Loss: 0.0032820329070091248 KL_div:0.10827577114105225 current_lr:0.1 Time taken per iteration: 0.011208295822143555
# Step: 4750 Loss: 0.003281925804913044 KL_div:0.10827363282442093 current_lr:0.1 Time taken per iteration: 0.008276700973510742
# Step: 4760 Loss: 0.00328200776129961 KL_div:0.10827527195215225 current_lr:0.1 Time taken per iteration: 0.00820016860961914
# Step: 4770 Loss: 0.0032820962369441986 KL_div:0.10827703028917313 current_lr:0.1 Time taken per iteration: 0.008463621139526367
# Step: 4780 Loss: 0.003281969577074051 KL_div:0.10827451199293137 current_lr:0.1 Time taken per iteration: 0.007529258728027344
# Step: 4790 Loss: 0.0032819886691868305 KL_div:0.10827489197254181 current_lr:0.1 Time taken per iteration: 0.00866556167602539
# Step: 4800 Loss: 0.003281963523477316 KL_div:0.10827438533306122 current_lr:0.1 Time taken per iteration: 0.00732111930847168
# Step: 4810 Loss: 0.0032819758635014296 KL_div:0.10827463865280151 current_lr:0.1 Time taken per iteration: 0.007820606231689453
# Step: 4820 Loss: 0.003282007295638323 KL_div:0.10827527195215225 current_lr:0.1 Time taken per iteration: 0.009122848510742188
# Step: 4830 Loss: 0.003281994489952922 KL_div:0.10827501863241196 current_lr:0.1 Time taken per iteration: 0.0072667598724365234
# Step: 4840 Loss: 0.0032819625921547413 KL_div:0.10827438533306122 current_lr:0.1 Time taken per iteration: 0.009436607360839844
# Step: 4850 Loss: 0.003282032674178481 KL_div:0.10827577114105225 current_lr:0.1 Time taken per iteration: 0.009886980056762695
# Step: 4860 Loss: 0.003282001009210944 KL_div:0.1082751452922821 current_lr:0.1 Time taken per iteration: 0.010563850402832031
# Step: 4870 Loss: 0.0032819812186062336 KL_div:0.10827476531267166 current_lr:0.1 Time taken per iteration: 0.011068582534790039
# Step: 4880 Loss: 0.0032819502521306276 KL_div:0.10827413946390152 current_lr:0.1 Time taken per iteration: 0.009873390197753906
# Step: 4890 Loss: 0.0032820196356624365 KL_div:0.10827551782131195 current_lr:0.1 Time taken per iteration: 0.01061105728149414
# Step: 4900 Loss: 0.003281937213614583 KL_div:0.10827388614416122 current_lr:0.1 Time taken per iteration: 0.008100509643554688
# Step: 4910 Loss: 0.003281981684267521 KL_div:0.10827476531267166 current_lr:0.1 Time taken per iteration: 0.007479190826416016
# Step: 4920 Loss: 0.003281909041106701 KL_div:0.10827331244945526 current_lr:0.1 Time taken per iteration: 0.011546134948730469
# Step: 4930 Loss: 0.003281965386122465 KL_div:0.108274444937706 current_lr:0.1 Time taken per iteration: 0.009142398834228516
# Step: 4940 Loss: 0.00328195933252573 KL_div:0.10827432572841644 current_lr:0.1 Time taken per iteration: 0.009369611740112305
# Step: 4950 Loss: 0.0032819402404129505 KL_div:0.1082739531993866 current_lr:0.1 Time taken per iteration: 0.009413719177246094
# Step: 4960 Loss: 0.0032819085754454136 KL_div:0.10827331244945526 current_lr:0.1 Time taken per iteration: 0.00933694839477539
# Step: 4970 Loss: 0.0032818648032844067 KL_div:0.10827243328094482 current_lr:0.1 Time taken per iteration: 0.00903177261352539
# Step: 4980 Loss: 0.0032820096239447594 KL_div:0.10827533900737762 current_lr:0.1 Time taken per iteration: 0.010777950286865234
# Step: 4990 Loss: 0.003281990997493267 KL_div:0.10827495157718658 current_lr:0.1 Time taken per iteration: 0.00862884521484375
# Step: 5000 Loss: 0.003281921148300171 KL_div:0.10827356576919556 current_lr:0.1 Time taken per iteration: 0.010246992111206055

# %%
fig, axs = plt.subplots(1,2,figsize=(15,8))
axs[0].plot(divs)
axs[0].title.set_text('KL Divergence')

axs[1].plot(history)
axs[1].title.set_text('loss')

# %%
optimal_params = parameters[np.argmin(divs)]
qcbm_probs = circuit(optimal_params)
x_full = jnp.arange(0,2**n_qubits,dtype=jnp.float64)

fig, axs = plt.subplots(1,2,figsize=(15,5))
axs[0].bar(x_full,qcbm_probs[0],color='green',alpha=0.5,label='Obtained Distribution')
axs[0].plot(x_full,target_distribution1,color='blue',alpha=0.5,label='Target Distribution')
axs[0].legend()
axs[0].set_title('1111 Distribution')
axs[0].set_xlabel('Hilbert Space')
axs[0].set_ylabel('Probability Distribution')

axs[1].bar(x_full,qcbm_probs[1],color='red',alpha=0.5,label='Obtained Distribution')
axs[1].plot(x_full,target_distribution2,color='blue',alpha=0.5,label='Target Distribution')
axs[1].legend()
axs[1].set_title('0000 Distribution')
axs[1].set_xlabel('Hilbert Space')
axs[1].set_ylabel('Probability Distribution')
# Out:
# Text(0, 0.5, 'Probability Distribution')

# %%
print(f"Minimum KL Divergence obtained is {np.min(divs)}")
# Out:
# Minimum KL Divergence obtained is 0.06447096168994904

# %%
print(f"Minimum KL Divergence obtained is {np.min(divs)}")
# Out:
# Minimum KL Divergence obtained is 0.0546211302280426

# %%
dev = qml.device("default.qubit",wires=n_qubits)

@qml.qnode(dev,interface='jax')
def output_vqc_circuit(input_params,n_qubits=4):
    # uniform_init(num_qubits,cat_pre_training,seed=0)
    params = input_params[0]
    for i in range(vqc_folds):
        vqc_circuit(params[i])
    return qml.probs(wires=range(n_qubits))

qml.draw_mpl(output_vqc_circuit)(optimal_params)
plt.show()

# %%
hybrid_output = output_vqc_circuit(optimal_params,n_qubits)

# %%
fig, axs = plt.subplots(1,2,figsize=(15,5))
axs[0].plot(x_full,hybrid_output,label='Generated Cat')
axs[0].legend()
axs[0].set_title('Generated Cat Distribution')
axs[0].set_xlabel('Hilbert Space')
axs[0].set_ylabel('Probability Distribution')

axs[1].plot(x_full,cat_data,label='Original Cat')
axs[1].legend()
axs[1].set_title('Original Cat Distribution')
axs[1].set_xlabel('Hilbert Space')
axs[1].set_ylabel('Probability Distribution')
# Out:
# Text(0, 0.5, 'Probability Distribution')

# %%
x = jnp.arange(0,n_qubits+1,dtype=jnp.float64)
fig, axs = plt.subplots(1,2,figsize=(15,5))
axs[0].bar(x,pnumber_distribution(hybrid_output,n_qubits),color='green',alpha=0.5,label='Generated Cat')
axs[0].legend()
axs[0].set_title('Generated Cat Distribution')
axs[0].set_xlabel('Particle Number')
axs[0].set_ylabel('Particle Number Distribution')

axs[1].bar(x,pnumber_distribution(cat_data,n_qubits),color='red',alpha=0.5,label='Original Cat')
axs[1].legend()
axs[1].set_title('Original Cat Distribution')
axs[1].set_xlabel('Particle Number')
axs[1].set_ylabel('Particle Number Distribution')
# Out:
# Text(0, 0.5, 'Particle Number Distribution')

# %%
fig, axs = plt.subplots(1,2,figsize=(15,5))
axs[0].plot(x_full,hybrid_output,label='Generated Cat')
axs[0].legend()
axs[0].set_title('Generated Cat Distribution')
axs[0].set_xlabel('Hilbert Space')
axs[0].set_ylabel('Probability Distribution')

axs[1].plot(x_full,cat_data,label='Original Cat')
axs[1].legend()
axs[1].set_title('Original Cat Distribution')
axs[1].set_xlabel('Hilbert Space')
axs[1].set_ylabel('Probability Distribution')
# Out:
# Text(0, 0.5, 'Probability Distribution')

# %%
x = jnp.arange(0,n_qubits+1,dtype=jnp.float64)
fig, axs = plt.subplots(1,2,figsize=(15,5))
axs[0].bar(x,pnumber_distribution(hybrid_output,n_qubits),color='green',alpha=0.5,label='Generated Cat')
axs[0].legend()
axs[0].set_title('Generated Cat Distribution')
axs[0].set_xlabel('Particle Number')
axs[0].set_ylabel('Particle Number Distribution')

axs[1].bar(x,pnumber_distribution(cat_data,n_qubits),color='red',alpha=0.5,label='Original Cat')
axs[1].legend()
axs[1].set_title('Original Cat Distribution')
axs[1].set_xlabel('Particle Number')
axs[1].set_ylabel('Particle Number Distribution')
# Out:
# Text(0, 0.5, 'Particle Number Distribution')

# %%
# #Save Checkpoint
# checkpoint = {"final_epoch":i,
#               "history":history,
#               "divs":divs,
#               "parameters":parameters}

# with open(f'model_cat_anticat_distribution.pkl','wb') as file:
#     pickle.dump(checkpoint,file)
    
# print("Model saved successfully")
