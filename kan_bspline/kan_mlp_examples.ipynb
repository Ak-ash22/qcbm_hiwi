# %%
# %run general_neuron.ipynb

# %%
# 1D Regression problem

n_iter_train_1d  = 500
loss_tol_1d = 0.05
seed = 1234

x_train = np.linspace(-1,1,50).reshape(-1,1)   #column vector
y_train = 0.5* np.sin(4*x_train) * np.exp(-(x_train+1)) + 0.5  #exponentially damped sinusoidal

#KAN training
# kan_1d = FeedForward([1,2,2,1],  #layer_size
#                      eps=0.01,   #gradient descent parameter
#                      n_weights_per_edge=7,   #no of edge functions
#                      neuron_class = NeuronKAN,
#                      x_bounds = [-1,1],  #input domain
#                      get_edge_fun = get_bsplines,
#                      seed = seed,
#                      weights_range = [-1,1])

# kan_1d.train(x_train, y_train, n_iter_max=n_iter_train_1d, loss_tol= loss_tol_1d)


#MLP training
mlp_1d = FeedForward([1,13,1],      #layer size
                     eps = 0.005,   #gradient descent parameter
                     activation = relu,
                     neuron_class = NeuronNN,
                     weights_range = [-0.5,0.5],
                     seed = seed)

mlp_1d.train(x_train,y_train,n_iter_train_1d,loss_tol=loss_tol_1d)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 31
#      10 #KAN training
#      11 # kan_1d = FeedForward([1,2,2,1],  #layer_size
#      12 #                      eps=0.01,   #gradient descent parameter
#    (...)
#      22
#      23 #MLP training
#      24 mlp_1d = FeedForward([1,13,1],      #layer size
#      25                      eps = 0.005,   #gradient descent parameter
#      26                      activation = relu,
#      27                      neuron_class = NeuronNN,
#      28                      weights_range = [-0.5,0.5],
#      29                      seed = seed)
# ---> 31 mlp_1d.train(x_train,y_train,n_iter_train_1d,loss_tol=loss_tol_1d)
#
# File /tmp/ipykernel_15278/3442886410.py:53, in FeedForward.train(self, x_train, y_train, n_iter_max, loss_tol)
#      51 for ii in range(x_train.shape[0]):
# ...

# %%
np.zeros((1,7))
# Out:
# array([[0., 0., 0., 0., 0., 0., 0.]])
